# %%
import cga_utils
import prompt_versions_g3
import pandas as pd
# %load_ext autoreload
# %autoreload 2

# %%
from langchain.globals import set_llm_cache
from langchain_community.cache import SQLiteCache

set_llm_cache(SQLiteCache(database_path=".langchain.v18_gemma3.db"))

# %%
from langchain_community.chat_models import ChatOllama
llm = ChatOllama(model="gemma3:4b", temperature = 0.0, top_p = 1, repeat_penalty=1, presence_penalty=0, frequency_penalty=0)  # vagy bármely más elérhető Ollama modell

# %%
import pandas as pd
messages = prompt_versions_g3.prompt_versions['V20b']
#messages = [(a, t.replace('/no_think','')) for (a,t)  in messages]
#messages[-1] = ( messages[-1][0],  messages[-1][1] + "/no_think" )

# %% [markdown]
# ## Calc fix performance

# %%
import os
os.environ["CGA_TRACE_RESP"] = 'True'
cga_utils.calc_fix_mcnemar_performance(llm, messages,
                                       'res/gemma3_v19a.csv',
                                       'res/errors_19a_cv1_2_1.csv', 
                                       trace_messages = True, 
                                       error_cluster_id=28)
# Out:
# 1770461913.7118874
# 0it [00:00, ?it/s]
# 1238d807-aa57-48a3-93b6-591873788625
# What was the increase / (decrease) in the Statutory federal income tax (benefit) from 2018 to 2019?R:  ```python
# def run(value_list):
#     """
#     Calculates the increase/decrease in Statutory federal income tax (benefit) from 2018 to 2019.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#
#     # Extract data for 2018 and 2019
#     try:
#         tax_2018 = next(item for item in value_list if item['header1'] == 'June 2, 2018')['number_value']
#         tax_2019 = next(item for item in value_list if item['header1'] == 'June 1, 2019')['number_value']
#     except StopIteration:
#         return (0.00, "")
#
#     # Calculate the difference
#     difference = tax_2019 - tax_2018
#
#     # Determine the scale
#     scale = ""
#     for item in value_list:
#         if item['header1'] == 'June 1, 2019':
#             if item['number_value'] > 0 and item['number_value'] < 1000000:
#                 scale = 'thousand'
#             elif item['number_value'] >= 1000000 and item['number_value'] < 10000000:
#                 scale = 'million'
#             elif item['number_value'] >= 10000000 and item['number_value'] < 100000000:
#                 scale = 'billion'
#             break
#
#     return (round(difference, 2), scale)
# ```|||
#  failure: -19411.0 good answer:  -19411
# << 14,694 - 34,105 || [34105.0, 14694.0, -19411.0] || [14694.0, 34105.0] || True >>
# b8afd327-b836-4276-8556-eac89746b09f
# What is the change in the Combustion of fuel and operation of facilities (Scope 1) from FY18 to FY19 for UK and Ireland only?R:  ```python
# def run(value_list):
#     """
#     Calculates the change in emissions for Scope 1 (Combustion of fuel and operation of facilities)
#     from FY18 to FY19 for UK and Ireland only.
#     """
#     fy18_value = None
#     fy19_value = None
#
#     for item in value_list:
#         if item['category'] == 'Combustion of fuel and operation of facilities (Scope 1)' and item['header1'] == 'FY18**':
#             fy18_value = item['number_value']
#         elif item['category'] == 'Combustion of fuel and operation of facilities (Scope 1)' and item['header1'] == 'FY19**':
#             fy19_value = item['number_value']
#
#     if fy18_value is not None and fy19_value is not None:
#         change = fy19_value - fy18_value
#         scale = item['scale']
#         return (round(change, 2), scale)
#     else:
#         return (None, None)
# ```|||
#  Success: -6841.0
# << 59,495 - 66,336 || [66336.0, 59495.0, -6841.0] || [59495.0, 66336.0] || True >>
# 4ba37f67-0474-4e5c-8f45-da51a2873072
# What is the change in the Expected volatility from 2018 to 2019?R:  ```python
# def run(value_list):
#     """
#     Calculates the change in the Expected volatility from 2018 to 2019.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#     volatility_2018 = None
#     volatility_2019 = None
#
#     for item in value_list:
#         if item['category'] == 'Expected volatility' and item['header1'] == '2018':
#             volatility_2018 = float(item['number_value'])
#         elif item['category'] == 'Expected volatility' and item['header1'] == '2019':
#             volatility_2019 = float(item['number_value'])
#
#     if volatility_2019 is not None and volatility_2018 is not None:
#         change = volatility_2019 - volatility_2018
#         return (round(change, 2), 'thousand')
#     else:
#         return (None, None)
# ```|||
#  Success: 6.1
# << 51.9 - 45.8 || [45.8, 51.9, 6.100000000000001] || [51.9, 45.8] || True >>
# bfb033dc-19dc-41cc-9253-aa7e03b61a62
# What was the difference in the Weighted-Average Useful Lives between Trademarks and tradenames and Other intangible assets?R:  ```python
# def run(value_list):
#     """
#     Calculates the difference in the Weighted-Average Useful Lives between Trademarks and tradenames and Other intangible assets.
#     """
#     trademarks_lives = None
#     other_lives = None
#
#     for item in value_list:
#         if item['category'] == 'Trademarks and tradenames' and item['header1'] == 'Weighted-Average Useful Lives (in years)':
#             trademarks_lives = float(item['number_value'])
#         if item['category'] == 'Other' and item['header1'] == 'Weighted-Average Useful Lives (in years)':
#             other_lives = float(item['number_value'])
#
#     if trademarks_lives is not None and other_lives is not None:
#         difference = abs(trademarks_lives - other_lives)
#         return (round(difference, 2), 'thousand')
#     else:
#         return (0.00, '')
# ```|||
#  Success: 3.0
# << 5.0-2.0 || [5.0, 2.0, 3.0] || [5.0, 2.0] || True >>
# 4cee3e03-ed30-4e2c-8718-e65ad795d4e8
# What is the increase / (decrease) in the Gross Profit from 2018 to 2019?R:  ```python
# def run(value_list):
#     """
#     Calculates the increase/decrease in Gross Profit from 2018 to 2019.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#     gross_profit_2018 = 0
#     gross_profit_2019 = 0
#
#     for item in value_list:
#         if item['category'] == 'Gross profit (in thousands)':
#             if item['header1'] == 'June 2, 2018':
#                 gross_profit_2018 = float(item['number_value'])
#             elif item['header1'] == 'June 1, 2019':
#                 gross_profit_2019 = float(item['number_value'])
#
#     increase = gross_profit_2019 - gross_profit_2018
#
#     return (round(increase, 2), '')
# ```|||
#  Success: -138187.0
# << 222,859 - 361,046 || [361046.0, 222859.0, -138187.0] || [222859.0, 361046.0] || True >>
# c91ad938-6ad1-4481-8f6b-43ccd2f69926
# What is the nominal difference for ROFE between F19 and F18?R:  ```python
# def run(value_list):
#     """
#     Calculates the nominal difference for ROFE between F19 and F18.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#     f19_rofe = None
#     f18_rofe = None
#
#     for item in value_list:
#         if item['category'] == 'ROFE (%)' and item['header1'] == '53 WEEKS' and item['header2'] == 'F19':
#             f19_rofe = item['number_value']
#         if item['category'] == 'ROFE (%)' and item['header1'] == '52 WEEKS' and item['header2'] == 'F18 (3)':
#             f18_rofe = item['number_value']
#
#     if f19_rofe is not None and f18_rofe is not None:
#         difference = abs(f19_rofe - f18_rofe)
#         return (round(difference, 2), 'million')
#     else:
#         return (None, None)
# ```|||
#  Success: 1.9
# << 17.1 - 15.2  || [15.2, 17.1, 1.9000000000000021] || [17.1, 15.2] || True >>
# ff71e762-7a3d-4b9e-aa75-3ab148d8154c
# What was the change in the average life expectancy for a male member aged 65 in 2019 from 2018?R:  ```python
# def run(value_list):
#     """
#     Calculates the change in the average life expectancy for a male member aged 65 in 2019 from 2018.
#     """
#     men_65_2019 = next((item for item in value_list if item['category'] == 'Member aged 65 (current life expectancy)' and item['header2'] == 'Men' and item['header3'] == '2019'), None)
#     men_65_2018 = next((item for item in value_list if item['category'] == 'Member aged 65 (current life expectancy)' and item['header2'] == 'Men' and item['header3'] == '2018'), None)
#
#     if men_65_2019 and men_65_2018:
#         change = men_65_2019['number_value'] - men_65_2018['number_value']
#         return (round(change, 2), 'thousand')
#     else:
#         return (None, '')
# ```|||
#  Success: -0.5
# << 86.8-87.3 || [-0.5] || [86.8, 87.3] || False >>
# *** Overall EM:  0.2857142857142857 / 130
# 0339e2bb-4a63-4f23-aaea-b9fa3cb29737
# From fiscal year 2020 - 2024, what is the difference in the number of ground leases and land and building leases expiring?R:  ```python
# def run(value_list):
#     ground_leases_2020_2024 = 0
#     land_building_leases_2020_2024 = 0
#
#     for item in value_list:
#         if item['category'] == '2020 – 2024' and item['header2'] == 'Ground':
#             ground_leases_2020_2024 += item['number_value']
#         if item['category'] == '2020 – 2024' and item['header2'] == 'Building':
#             land_building_leases_2020_2024 += item['number_value']
#
#     difference = abs(ground_leases_2020_2024 - land_building_leases_2020_2024)
#
#     scale = 'thousand'
#
#     return (round(difference, 2), scale)
# ```|||
#  Success: 316.0
# << 697 - 381  || [381.0, 697.0, 316.0] || [697.0, 381.0] || True >>
# 34144864-790c-4733-8323-91347f68f5ef
# What is the global increase / (decrease) in the hindi films from 2018 to 2019?R:  ```python
# def run(value_list):
#     """
#     Calculates the global increase/decrease in Hindi films from 2018 to 2019.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#     hindi_films_2018 = 0
#     hindi_films_2019 = 0
#
#     for item in value_list:
#         if item['category'] == 'Hindi films' and item['header2'] == '2018':
#             hindi_films_2018 = item['number_value']
#         elif item['category'] == 'Hindi films' and item['header2'] == '2019':
#             hindi_films_2019 = item['number_value']
#
#     increase_decrease = hindi_films_2019 - hindi_films_2018
#
#     if increase_decrease == 0:
#         return (0.00, "")
#
#     scale = ""
#     for item in value_list:
#         if item['category'] == 'Hindi films' and item['header2'] == '2019':
#             if item['number_value'] == 10.0:
#                 scale = "million"
#                 break
#             elif item['number_value'] == 7.0:
#                 scale = "thousand"
#                 break
#             elif item['number_value'] == 12.0:
#                 scale = "thousand"
#                 break
#             elif item['number_value'] == 3.0:
#                 scale = "thousand"
#                 break
#             elif item['number_value'] == 1.0:
#                 scale = "thousand"
#                 break
#             elif item['number_value'] == 5.0:
#                 scale = "thousand"
#                 break
#             elif item['number_value'] == 6.0:
#                 scale = "thousand"
#                 break
#             elif item['number_value'] == 72.0:
#                 scale = "thousand"
#                 break
#             elif item['number_value'] == 24.0:
#                 scale = "thousand"
#                 break
#             elif item['number_value'] == 45.0:
#                 scale = "thousand"
#                 break
#
#     number = increase_decrease / (10**len(scale)) if scale else increase_decrease
#     return (round(number, 2), scale)
# ```|||
#  Success: -0.0
# << 7 - 10 || [3.0, 1.0, -2.0, -2e-08] || [7.0, 10.0] || False >>
# 8414474d-b00d-4231-8973-9c76f29d3e1c
# What was the change in the dividend shares awarded in 2019 from 2018?R:  ```python
# def run(value_list):
#     """
#     Calculates the change in the dividend shares awarded in 2019 from 2018.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#
#     award_2019 = 0
#     for item in value_list:
#         if item['category'] == 'Dividend shares awarded' and item['header2'] == '2019':
#             award_2019 = item['number_value']
#
#     award_2018 = 0
#     for item in value_list:
#         if item['category'] == 'Dividend shares awarded' and item['header2'] == '2018':
#             award_2018 = item['number_value']
#
#     change = award_2019 - award_2018
#
#     scale = ''
#     for item in value_list:
#         if item['category'] == 'Outstanding at 1 April' and item['header2'] == '2019':
#             scale = item['scale']
#         if item['category'] == 'Outstanding at 1 April' and item['header2'] == '2018':
#             scale = item['scale']
#         if item['category'] == 'Dividend shares awarded' and item['header2'] == '2019':
#             scale = item['scale']
#         if item['category'] == 'Dividend shares awarded' and item['header2'] == '2018':
#             scale = item['scale']
#
#     return (round(change, 2), scale)
# ```|||
#  Success: -5260.0
# << 4,518-9,778 || [4518.0, 9778.0, -5260.0] || [4518.0, 9778.0] || True >>
# 017d15d5-93f1-4f9a-b7c3-08cd59292dd6
# What was the change in the amount Outstanding at 31 March in 2019 from 2018?R:  ```python
# def run(value_list):
#     """
#     Calculates the change in the amount Outstanding at 31 March in 2019 from 2018.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#     outstanding_2019 = next((item for item in value_list if item['category'] == 'Outstanding at 31 March' and item['header2'] == '2019'), None)
#     outstanding_2018 = next((item for item in value_list if item['category'] == 'Outstanding at 31 March' and item['header2'] == '2018'), None)
#
#     if outstanding_2018 and outstanding_2019:
#         change = outstanding_2019['number_value'] - outstanding_2018['number_value']
#         scale = outstanding_2019.get('scale', '').lower()
#         if 'thousand' in scale:
#             return (round(change / 1000, 2), 'thousand')
#         elif 'million' in scale:
#             return (round(change / 1000000, 2), 'million')
#         elif 'billion' in scale:
#             return (round(change / 1000000000, 2), 'billion')
#         else:
#             return (round(change, 2), '')
#     else:
#         return (None, None)
# ```|||
#  Success: -369919.0
# << 320,872-690,791 || [-369919.0] || [320872.0, 690791.0] || False >>
# 24cd1ddb-a87d-4fde-9129-770a5fb65657
# What is the change between indirect energy consumption (MWh) in 2018 and 2019 year end?R:  ```python
# def run(value_list):
#     """
#     Calculates the change between indirect energy consumption (MWh) in 2018 and 2019 year end.
#
#     Args:
#         value_list: A list of dictionaries containing financial report data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#     year_2018_value = 0
#     year_2019_value = 0
#
#     for item in value_list:
#         if item['header1'] == '2018':
#             year_2018_value = item['number_value']
#         elif item['header1'] == '2019':
#             year_2019_value = item['number_value']
#
#     change = year_2019_value - year_2018_value
#
#     if change == 0:
#         return (0.00, '')
#
#     scale = ''
#     for item in value_list:
#         if item['header1'] == '2019':
#             if item['number_value'] > 1000000:
#                 scale = 'million'
#             elif item['number_value'] > 100000:
#                 scale = 'thousand'
#             elif item['number_value'] > 1000:
#                 scale = 'hundred'
#             elif item['number_value'] > 100:
#                 scale = 'ten'
#             elif item['number_value'] > 10:
#                 scale = 'nine'
#             elif item['number_value'] > 1:
#                 scale = 'eight'
#             else:
#                 scale = 'seven'
#
#     return (round(change, 2), scale)
# ```|||
#  Success: -1385.0
# Invalid  hundred
# << 185,948.09-154,636.44 || [5461.0, 4076.0, -1385.0] || [185948.09, 154636.44] || False >>
# ec696158-f93d-4608-903d-a6b9c4e7bfd5
# What is the increase / (decrease) in the telecommunication maintenance from 2018 to 2019?R:  ```python
# def run(value_list):
#     """
#     Calculates the increase/decrease in telecommunication maintenance from 2018 to 2019.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#     telecommunication_maintenance_2018 = None
#     telecommunication_maintenance_2019 = None
#
#     for item in value_list:
#         if item['category'] == 'Telecommunication - Maintenance':
#             if item['header1'] == '2018':
#                 telecommunication_maintenance_2018 = item['number_value']
#             elif item['header1'] == '2019':
#                 telecommunication_maintenance_2019 = item['number_value']
#
#     if telecommunication_maintenance_2018 is not None and telecommunication_maintenance_2019 is not None:
#         increase_decrease = telecommunication_maintenance_2019 - telecommunication_maintenance_2018
#         scale = 'thousand'  # Assuming scale is thousand
#         return (round(increase_decrease, 2), scale)
#     else:
#         return (None, None)
# ```|||
#  Success: -0.2
# << 86.8 - 87.0 || [87.0, 86.8, -0.20000000000000284] || [86.8, 87.0] || True >>
# 1770461950.854156 37.142268657684326
# cnt: 13
# Base EM: 0.0
# Base VM: 1.0
# Fix EM: 0.3076923076923077
# Fix VM: 0.8461538461538461
# RuleDecision(accepted=False, reason='McNemar p>=alpha vagy ΔEM túl kicsi', summary={'N': 13, 'b_improved': 4, 'c_degraded': 0, 'delta_pp': 30.76923076923077, 'p_mcnemar_exact': 0.125, 'p_mcnemar_chi2cc': 0.13361440253771584, 'criteria': {'mcnemar_and_delta': False}})

# %% [markdown]
# ## Calc global Performance

# %%
res = cga_utils.execute_dataset_predictions(llm, messages)
# Out:
# 1770462048.5858574
# 0it [00:00, ?it/s]
# b2786c1a-37de-4120-b03c-32bf5c81f157
# What was the change in the amount for Appliances in 2019 from 2018?R:  ```python
# def run(value_list):
#     """
#     Calculates the change in the amount for Appliances in 2019 from 2018.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#     appliances_2019 = next((item for item in value_list if item['category'] == 'Appliances' and item['header1'] == 'Communications Solutions:' and item['header5'] == 'Communications Solutions:' and item['header3'] == '2019'), None)
#     appliances_2018 = next((item for item in value_list if item['category'] == 'Appliances' and item['header1'] == 'Communications Solutions:' and item['header5'] == 'Communications Solutions:' and item['header3'] == '2018'), None)
#
#     if appliances_2019 and appliances_2018:
#         change = appliances_2019['number_value'] - appliances_2018['number_value']
#         return (round(change, 2), 'million')
#     else:
#         return (None, None)
# ```|||
#  failure: -94.0 good answer:  -94
# << 680-774 || [-94.0] || [680.0, 774.0] || False >>
# fe11f001-3bfe-4089-8108-412676f0a780
# What was the percentage change in the amount for Appliances in 2019 from 2018?R:  ```python
# def run(value_list):
#     """
#     Calculates the percentage change in the amount for Appliances in 2019 from 2018.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale) representing the percentage change.
#     """
#     appliances_2019 = next((item for item in value_list if item['category'] == 'Appliances' and item['header1'] == 'Communications Solutions:' and item['header5'] == 'Communications Solutions:' and item['header3'] == '2019'), None)
#     appliances_2018 = next((item for item in value_list if item['category'] == 'Appliances' and item['header1'] == 'Communications Solutions:' and item['header5'] == 'Communications Solutions:' and item['header3'] == '2018'), None)
#
#     if appliances_2019['number_value'] is None or appliances_2018['number_value'] is None:
#         return (0.00, "")
#
#     change = ((appliances_2019['number_value'] - appliances_2018['number_value']) / appliances_2018['number_value']) * 100
#     return (round(change, 2), "")
# ```|||
#  Success: -12.14
# << (680-774)/774 || [-12.144702842377262] || [680.0, 774.0, 774.0] || False >>
# 5103aed0-b4e8-4fae-bf78-e2c9f4ba84cf
# What is the difference between the domestic and international discount rates as at September 30, 2019?R:  ```python
# def run(value_list):
#     domestic_rate = None
#     international_rate = None
#     for item in value_list:
#         if item['category'] == 'Discount rate' and item['header1'] == '2019' and item['header2'] == 'September 30,' and item['header3'] == 'Domestic':
#             domestic_rate = float(item['number_value'])
#         if item['category'] == 'Discount rate' and item['header1'] == '2019' and item['header2'] == 'September 30,' and item['header3'] == 'International':
#             international_rate = float(item['number_value'])
#     if domestic_rate is not None and international_rate is not None:
#         return round((international_rate - domestic_rate), 2), 'thousand'
#     else:
#         return None
# ```|||
#  Success: -2.1
# << 4.00 - 1.90  || [4.0, 1.9] || [4.0, 1.9] || True >>
# 4dc8be43-d8d9-4b08-9ffd-9c19012361ce
# What is the year on year percentage change in domestic discount rate between 2018 and 2019?R:  ```python
# def run(value_list):
#     """
#     Calculates the year on year percentage change in domestic discount rate between 2018 and 2019.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#
#     domestic_2018 = None
#     domestic_2019 = None
#
#     for item in value_list:
#         if item['category'] == 'Discount rate' and item['header3'] == 'Domestic':
#             if item['header1'] == '2018':
#                 domestic_2018 = item['number_value']
#             elif item['header1'] == '2019':
#                 domestic_2019 = item['number_value']
#
#     if domestic_2018 is not None and domestic_2019 is not None:
#         change = (domestic_2019 - domestic_2018) / domestic_2018
#         return (round(change, 2), 'percent')
#     else:
#         return (None, None)
# ```|||
#  Success: 0.07
# << (4.00 - 3.75)/3.75  || [3.75, 4.0, 0.06666666666666667] || [4.0, 3.75, 3.75] || True >>
# 6c44a1a8-0785-43a0-90ab-7e21df2c57d9
# What is the year on year percentage change in international expected return on plan assets between 2018 and 2019?R:  ```python
# def run(value_list):
#     """
#     Calculates the year on year percentage change in international expected return on plan assets between 2018 and 2019.
#     """
#
#     year_2019_value = None
#     year_2018_value = None
#
#     for item in value_list:
#         if item['category'] == 'Expected return on plan assets' and item['header3'] == 'International':
#             if item['header1'] == '2019':
#                 year_2019_value = item['number_value']
#             elif item['header1'] == '2018':
#                 year_2018_value = item['number_value']
#
#     if year_2019_value is not None and year_2018_value is not None:
#         percentage_change = ((year_2019_value - year_2018_value) / year_2018_value) * 100
#         return (round(percentage_change, 2), 'percent')
#     else:
#         return (None, '')
# ```|||
#  Success: -8.11
# << (3.40 - 3.70)/3.70  || [3.4, 3.7, -8.108108108108116] || [3.4, 3.7, 3.7] || True >>
# a0414f81-8dc2-44b2-a441-2c9d9c805c4d
# What is the 2019 average defined contribution schemes?R:  ```python
# def run(value_list):
#     """
#     Calculates the 2019 average defined contribution schemes.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#
#     scheme_data = [item for item in value_list if item['category'] == 'Defined contribution schemes']
#
#     if scheme_data:
#         values = [item['number_value'] for item in scheme_data]
#         average = sum(values) / len(values)
#
#         scale = 'million'
#
#         return (round(average, 2), scale)
#     else:
#         return (0.00, '')
# ```|||
#  Success: 178.67
# << (166+178)/2 || [178.66666666666666] || [166.0, 178.0] || False >>
# bf7abd62-d9cd-48d2-8826-1457684019a3
# What is the 2019 average defined benefit schemes?R:  ```python
# def run(value_list):
#     """
#     Calculates the 2019 average defined benefit schemes.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#
#     benefit_schemes_2019 = []
#     for item in value_list:
#         if item['category'] == 'Defined benefit schemes' and item['header1'] == '2019 € million':
#             benefit_schemes_2019.append(float(item['number_value']))
#
#     if benefit_schemes_2019:
#         average = sum(benefit_schemes_2019) / len(benefit_schemes_2019)
#         scale = 'million'
#         return (round(average, 2), scale)
#     else:
#         return (0.00, '')
# ```|||
#  Success: 57.0
# << (57+44)/2 || [57.0] || [57.0, 44.0] || False >>
# 4d259081-6da6-44bd-8830-e4de0031744c
# What is the difference between 2019 average defined contribution schemes and 2019 average defined benefit schemes?R:  ```python
# def run(value_list):
#     """
#     Calculates the difference between 2019 average defined contribution schemes and 2019 average defined benefit schemes.
#     """
#     dcf_2019 = None
#     db_2019 = None
#     for item in value_list:
#         if item['category'] == 'Defined contribution schemes' and item['header1'] == '2019 € million':
#             dcf_2019 = item['number_value']
#         if item['category'] == 'Defined benefit schemes' and item['header1'] == '2019 € million':
#             db_2019 = item['number_value']
#
#     if db_2019 is not None and dcf_2019 is not None:
#         difference = abs(dcf_2019 - db_2019)
#         scale = item['scale']
#         return (round(difference, 2), scale)
#     else:
#         return (None, None)
# ```|||
#  Success: 109.0
# << [(166+178)/2] - [(57+44)/2] || [166.0, 57.0, 109.0] || [166.0, 178.0, 57.0, 44.0] || False >>
# bed1fce2-69cb-4d1e-a34a-01950a1770bd
# What is the percentage change in the operating loss carryforward from 2018 to 2019?R:  ```python
# def run(value_list):
#     """
#     Calculates the percentage change in the operating loss carryforward from 2018 to 2019.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#
#     year_2018_data = next((item for item in value_list if item['header2'] == '2 0 1 8'), None)
#     year_2019_data = next((item for item in value_list if item['header2'] == '2 0 1 9'), None)
#
#     if year_2018_data and year_2019_data:
#         operating_loss_2018 = year_2018_data['number_value']
#         operating_loss_2019 = year_2019_data['number_value']
#
#         percentage_change = ((operating_loss_2019 - operating_loss_2018) / operating_loss_2018) * 100
#
#         return (round(percentage_change, 2), 'percent')
#     else:
#         return (None, None)
# ```|||
#  Success: None
# Invalid  None
# << (73,260-57,768)/57,768 || [] || [73260.0, 57768.0, 57768.0] || False >>
# aea850af-68cb-4cc1-80b2-c9c2860b273e
# What is the percentage change in the net deferred tax asset from 2018 to 2019?R:  ```python
# def run(value_list):
#     """
#     Calculates the percentage change in the net deferred tax asset from 2018 to 2019.
#     """
#
#     # Extract values for 2018 and 2019
#     value_2019 = next((item['number_value'] for item in value_list if item['header2'] == '2 0 1 9'), None)
#     value_2018 = next((item['number_value'] for item in value_list if item['header2'] == '2 0 1 8'), None)
#
#     if value_2018 is None or value_2019 is None:
#         return (0.00, "")
#
#     # Calculate the percentage change
#     percentage_change = ((value_2019 - value_2018) / value_2018) * 100
#
#     return (round(percentage_change, 2), "")
# ```|||
#  Success: 0.0
# << (795-772)/772 || [57768.0] || [795.0, 772.0, 772.0] || False >>
# ba6783f3-8207-419a-b407-3f688682caef
# What is the ratio of IMFT’s total assets to total liabilities in 2019?R:  ```python
# def run(value_list):
#     """
#     Calculates the ratio of IMFT’s total assets to total liabilities in 2019.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#     total_assets_2019 = 0.0
#     total_liabilities_2019 = 0.0
#
#     for item in value_list:
#         if item['header1'] == 'Total assets' and item['header2'] == '2019':
#             total_assets_2019 = float(item['number_value'])
#         if item['header1'] == 'Total liabilities' and item['header2'] == '2019':
#             total_liabilities_2019 = float(item['number_value'])
#
#     if total_assets_2019 != 0.0 and total_liabilities_2019 != 0.0:
#         ratio = total_assets_2019 / total_liabilities_2019
#         return (round(ratio, 2), 'thousand')
#     else:
#         return (0.0, '')
# ```|||
#  Success: 0.0
# << 2,664/909  || [0.0, 0.0] || [2664.0, 909.0] || False >>
# 263d03ec-83d2-48df-8376-1a72167798f7
# What is the proportion of IMFT’s property, plant, and equipment over total assets in 2018?R:  ```python
# def run(value_list):
#     """
#     Calculates the proportion of IMFT’s property, plant, and equipment over total assets in 2018.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#     total_assets_2018 = 0.0
#     property_plant_equipment_2018 = 0.0
#
#     for item in value_list:
#         if item['header2'] == '2018':
#             if item['category'] == 'Total assets':
#                 total_assets_2018 = item['number_value']
#             if item['category'] == 'Property, plant, and equipment':
#                 property_plant_equipment_2018 = item['number_value']
#
#     if total_assets_2018 == 0:
#         return (0.0, "")
#
#     proportion = (property_plant_equipment_2018 / total_assets_2018) * 100
#
#     scale = ""
#     if proportion >= 1000:
#         scale = "thousand"
#     elif proportion >= 100:
#         scale = "hundred"
#     elif proportion >= 10:
#         scale = "thousand"
#     elif proportion >= 1:
#         scale = "thousand"
#
#     return (round(proportion, 2), scale)
# ```|||
#  Success: 87.31
# << 2,641/3,025  || [3025.0, 2641.0, 87.30578512396694] || [2641.0, 3025.0] || True >>
# 78fc6d55-c20c-4f71-99fe-bc40a16e61d0
# What is the change of IMFT’s total assets from 2018 to 2019?R:  ```python
# def run(value_list):
#     """
#     Calculates the change of IMFT’s total assets from 2018 to 2019.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#     assets_2018 = 0
#     assets_2019 = 0
#
#     for item in value_list:
#         if item['category'] == 'Total assets' and item['header2'] == '2018':
#             assets_2018 = item['number_value']
#         elif item['category'] == 'Total assets' and item['header2'] == '2019':
#             assets_2019 = item['number_value']
#
#     change = assets_2019 - assets_2018
#     scale = 'thousand'  # Assuming scale is thousand
#
#     return (round(change, 2), scale)
# ```|||
#  Success: -361.0
# << 2,664 - 3,025  || [3025.0, 2664.0, -361.0] || [2664.0, 3025.0] || True >>
# a4f782f1-de3b-47a3-87af-1cb33c112b39
# What was the percentage change in Value added tax receivables, net, noncurrent in 2019 from 2018?R:  ```python
# def run(value_list):
#     """
#     Calculates the percentage change in Value added tax receivables, net, noncurrent in 2019 from 2018.
#     """
#     value_2019 = next((item['number_value'] for item in value_list if item['category'] == 'Value added tax receivables, net, noncurrent',), None)
#     value_2018 = next((item['number_value'] for item in value_list if item['category'] == 'Value added tax receivables, net, noncurrent',), None)
#
#     if value_2018 == 0:
#         return (0.00, '')
#
#     percentage_change = ((value_2019 - value_2018) / value_2018) * 100
#     return (round(percentage_change, 2), 'percent')
# ```|||
# [Error]invalid syntax (<string>, line 5)
# [Error]invalid syntax (<string>, line 5)
#  Success: [Error]invalid syntax (<string>, line 5)
# << (592-519)/519 || [] || [592.0, 519.0, 519.0] || False >>
# dc5e217a-a7b3-4fc9-ac0f-13d328f26b20
# What is the 2019 average free cash flow?R:  ```python
# def run(value_list):
#     """
#     Calculates the 2019 average free cash flow from the provided value list.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale) representing the 2019 average free cash flow.
#     """
#
#     cash_flow_2019 = value_list[0]['number_value']
#     cash_flow_2018 = value_list[1]['number_value']
#
#     average = (cash_flow_2019 + cash_flow_2018) / 2
#
#     if 'million' in value_list[0]['scale']:
#         scale = 'million'
#     elif 'thousand' in value_list[0]['scale']:
#         scale = 'thousand'
#     else:
#         scale = ''
#
#     return (round(average, 2), scale)
# ```|||
#  Success: 14021.0
# << (4,411+4,044)/2 || [14182.0, 13860.0, 14021.0] || [4411.0, 4044.0] || False >>
# 7cd3aedf-1291-4fea-bc9d-a25c65727b7b
# What is the 2018 average free cash flow?R:  ```python
# def run(value_list):
#     """
#     Calculates the 2018 average free cash flow from the provided value list.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale) representing the 2018 average free cash flow.
#     """
#
#     df = pd.DataFrame(value_list)
#
#     df_2018 = df[df['header2'] == '2018']
#
#     if not df_2018.empty:
#         cash_flow_2018 = df_2018['number_value'].sum()
#
#         df_2017 = df[df['header2'] == '2017']
#         cash_flow_2017 = df_2017['number_value'].sum()
#
#         average_cash_flow = (cash_flow_2018 + cash_flow_2017) / 2
#
#         if average_cash_flow == 0:
#             return (0.00, "")
#
#         scale = ""
#         if 'million' in df[df['header2'] == '2018']['scale'].iloc[0]:
#             scale = 'million'
#         elif 'thousand' in df[df['header2'] == '2018']['scale'].iloc[0]:
#             scale = 'thousand'
#         elif 'billion' in df[df['header2'] == '2018']['scale'].iloc[0]:
#             scale = 'billion'
#
#         return (round(average_cash_flow, 2), scale)
#     else:
#         return (0.00, "")
# import pandas as pd
# ```|||
#  Success: 18410.5
# << (4,044+3,316)/2 || [] || [4044.0, 3316.0] || False >>
# 22e20f25-669a-46b9-8779-2768ba391955
# What is the change between 2018 and 2019 average free cash flow?R:  ```python
# def run(value_list):
#     """
#     Calculates the change between 2018 and 2019 average free cash flow.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#
#     # Extract data for 2018 and 2019
#     cash_flow_2018 = None
#     cash_flow_2019 = None
#
#     for item in value_list:
#         if item['header2'] == '2018':
#             cash_flow_2018 = item['number_value']
#         if item['header2'] == '2019':
#             cash_flow_2019 = item['number_value']
#
#     if cash_flow_2018 is not None and cash_flow_2019 is not None:
#         average_cash_flow_2018 = cash_flow_2018
#         average_cash_flow_2019 = cash_flow_2019
#
#         change = average_cash_flow_2019 - average_cash_flow_2018
#
#         scale = 'thousand'
#         if 'million' in scale:
#             scale = 'million'
#         if 'billion' in scale:
#             scale = 'billion'
#
#         return (round(change, 2), scale)
#     else:
#         return (None, None)
# ```|||
#  Success: 367.0
# << [(4,411+4,044)/2] -[(4,044+3,316)/2] || [4044.0, 4411.0, 4044.0, 4411.0, 367.0] || [4411.0, 4044.0, 4044.0, 3316.0] || False >>
# a983501d-2eec-486d-9661-e520c7c8af5e
# What was the average difference between EBITDA and underlying EBITDA for both FYs?R:  ```python
# def run(value_list):
#     """
#     Calculates the average difference between EBITDA and underlying EBITDA for both FYs.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#
#     fy2019_ebitda = 0
#     fy2019_underlying_ebitda = 0
#     fy2018_ebitda = 0
#     fy2018_underlying_ebitda = 0
#
#     for item in value_list:
#         if item['category'] == 'EBITDA':
#             if item['header2'] == '30 June 2019':
#                 fy2019_ebitda = item['number_value']
#             elif item['header2'] == '30 June 2018':
#                 fy2018_ebitda = item['number_value']
#         elif item['category'] == 'Underlying EBITDA':
#             if item['header2'] == '30 June 2019':
#                 fy2019_underlying_ebitda = item['number_value']
#             elif item['header2'] == '30 June 2018':
#                 fy2018_underlying_ebitda = item['number_value']
#
#     if (fy2019_ebitda + fy2019_underlying_ebitda) != 0:
#         average_difference = (fy2019_ebitda + fy2019_underlying_ebitda) / 2
#     else:
#         return (0.00, "")
#
#     if average_difference < 0:
#         average_difference = abs(average_difference)
#
#     if average_difference < 1000:
#         scale = 'thousand'
#     elif average_difference < 100000:
#         scale = 'thousand'
#     elif average_difference < 1000000:
#         scale = 'million'
#     elif average_difference < 10000000:
#         scale = 'million'
#     else:
#         scale = 'thousand'
#
#     return (round(average_difference, 2), scale)
# ```|||
#  Success: 82084.5
# << ((85,123 - 79,046) + (63,954 - 62,575)) / 2  || [79046.0, 85123.0, 63954.0, 62575.0, 82084.5] || [85123.0, 79046.0, 63954.0, 62575.0] || True >>
# 64c902c6-f426-4432-84b3-c10b3065716f
# What was the difference in net profit between both FYs?R:  ```python
# def run(value_list):
#     """
#     Calculates the difference in net profit between both FYs.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#     net_profit_2019 = 0.0
#     net_profit_2018 = 0.0
#
#     for item in value_list:
#         if item['category'] == 'Net profit/(loss) after tax':
#             if item['header2'] == '30 June 2019':
#                 net_profit_2019 = float(item['number_value'])
#             elif item['header2'] == '30 June 2018':
#                 net_profit_2018 = float(item['number_value'])
#
#     difference = net_profit_2019 - net_profit_2018
#     return (round(difference, 2), item['scale'])
# ```|||
#  Success: -16458.0
# << -9,819 - 6,639  || [-9819.0, 6639.0, -16458.0] || [6639.0] || True >>
# 91812b92-5e94-414f-a447-4622aa3c2d10
# What was the average dividend yield for the 3 years from 2017 to 2019?R:  ```python
# def run(value_list):
#     """
#     Calculates the average dividend yield for the 3 years from 2017 to 2019.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#
#     data_2017 = next((d for d in value_list if d['header1'] == '2017'), None)
#     data_2018 = next((d for d in value_list if d['header1'] == '2018'), None)
#     data_2019 = next((d for d in value_list if d['header1'] == '2019'), None)
#
#     if data_2017 and data_2018 and data_2019:
#         dividend_2017 = float(data_2017['number_value'])
#         dividend_2018 = float(data_2018['number_value'])
#         dividend_2019 = float(data_2019['number_value'])
#
#         average_dividend = (dividend_2017 + dividend_2018 + dividend_2019) / 3
#
#         scale = ''
#         for item in value_list:
#             if item['scale'] != '':
#                 scale = item['scale']
#                 break
#
#         return (round(average_dividend, 2), scale)
#     else:
#         return (0.00, '')
# ```|||
#  Success: 4.7
# << (1.7%+1.5%+1.5%)/3 || [4.8, 4.7, 4.6, 4.7] || [1.7, 1.5, 1.5] || False >>
# *** Overall EM:  0.1 / 10
# 29b63db7-4925-4629-b108-49bbb27fb565
# What was the average risk-free interest rate over the 3 year period from 2017 to 2019?R:  ```python
# def run(value_list):
#     rates = []
#     for item in value_list:
#         if item['category'] == 'risk-free interest rate':
#             if item['header1'] == '2017':
#                 rates.append(float(item['number_value']))
#             elif item['header1'] == '2018':
#                 rates.append(float(item['number_value']))
#             elif item['header1'] == '2019':
#                 rates.append(float(item['number_value']))
#     if rates:
#         average = sum(rates) / len(rates)
#         return (round(average, 2), 'thousand')
#     else:
#         return (0.00, '')
# ```|||
#  Success: 1.9
# << (2.7%+2.0%+1.0%)/3 || [1.9000000000000001] || [2.7, 2.0, 1.0] || False >>
# *** Overall EM:  0.09523809523809523 / 10
# 6100c476-160a-4f1e-bfc1-a16f4cc18b52
# What was the increase / (decrease) in the cost from 2018 to 2019?R:  ```python
# def run(value_list):
#     """
#     Calculates the increase/decrease in cost from 2018 to 2019 based on the provided value list.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale) representing the increase/decrease in cost from 2018 to 2019.
#     """
#     try:
#         cost_2019 = None
#         cost_2018 = None
#
#         for item in value_list:
#             if item['category'] == 'Cost' and item['header1'] == '2019':
#                 cost_2019 = float(item['number_value'])
#             if item['category'] == 'Cost' and item['header1'] == '2018':
#                 cost_2018 = float(item['number_value'])
#
#         if cost_2018 is not None and cost_2019 is not None:
#             increase_decrease = cost_2019 - cost_2018
#             scale = item['scale']
#             return (round(increase_decrease / 1000000, 2), scale)
#         else:
#             return (0.0, "")
#     except:
#         return (0.0, "")
# ```|||
#  Success: 0.0
# << 100 - 82 || [100.0, 82.0, 18.0] || [100.0, 82.0] || True >>
# a81f1322-e74f-4e3c-a6cf-4b8d25d01cf5
# What is the average Selling, general and administrative?R:  ```python
# def run(value_list):
#     """
#     Calculates the average Selling, general and administrative cost from the provided financial report.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale) representing the average Selling, general and administrative cost,
#         rounded to two decimal places, and the scale.
#     """
#
#     sgandata = [d for d in value_list if d['category'] == 'Selling, general and administrative']
#
#     if not sgandata:
#         return (0.00, "")
#
#     total = sum(d['number_value'] for d in sgandata)
#     average = total / len(sgandata)
#
#     scale = ""
#     for d in value_list:
#         if d['category'] == 'Selling, general and administrative':
#             if d['number_value'] < 1000000:
#                 scale = 'thousand'
#             elif d['number_value'] < 100000000:
#                 scale = 'million'
#             elif d['number_value'] < 1000000000:
#                 scale = 'billion'
#             else:
#                 scale = 'trillion'
#             break
#
#     return (round(average, 2), scale)
# ```|||
#  Success: 399.33
# << (453 + 361 + 384) / 3 || [1198.0, 399.3333333333333] || [453.0, 361.0, 384.0] || False >>
# f7cac790-05ae-4a55-a41d-836a6b415f88
# What is the percentage increase / (decrease) of Research, development and engineering from 2018 to 2019?R:  ```python
# def run(value_list):
#     """
#     Calculates the percentage increase/decrease of Research, development and engineering from 2018 to 2019.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#
#     engineering_2018 = None
#     engineering_2019 = None
#
#     for item in value_list:
#         if item['category'] == 'Research, development and engineering' and item['header1'] == '2018':
#             engineering_2018 = item['number_value']
#         elif item['category'] == 'Research, development and engineering' and item['header1'] == '2019':
#             engineering_2019 = item['number_value']
#
#     if engineering_2018 is not None and engineering_2019 is not None:
#         percentage_change = ((engineering_2019 - engineering_2018) / engineering_2018) * 100
#         return (round(percentage_change, 2), 'percent')
#     else:
#         return (0.00, '')
# ```|||
#  Success: 88.06
# << 126 / 67 - 1 || [67.0, 126.0, 88.05970149253731] || [126.0, 67.0] || True >>
# 65ec782c-691e-45df-b541-caecb85154ff
# What was the change in Capital redemption reserve in 2019 from 2018?R:  ```python
# def run(value_list):
#     """
#     Calculates the change in Capital redemption reserve in 2019 from 2018.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#
#     # Find the relevant data for 2018 and 2019
#     data_2018 = next((item for item in value_list if item['header3'] == '2018'), None)
#     data_2019 = next((item for item in value_list if item['header3'] == '2019'), None)
#
#     if data_2018 and data_2019:
#         # Extract the values for Capital redemption reserve in 2018 and 2019
#         redemption_reserve_2018 = float(data_2018['number_value'])
#         redemption_reserve_2019 = float(data_2019['number_value'])
#
#         # Calculate the change
#         change = redemption_reserve_2019 - redemption_reserve_2018
#
#         # Determine the scale
#         scale = ""
#         for item in value_list:
#             if item['number_value'] == redemption_reserve_2018:
#                 if item['scale'] == 'million':
#                     scale = 'million'
#                 elif item['scale'] == 'thousand':
#                     scale = 'thousand'
#                 elif item['scale'] == 'billion':
#                     scale = 'billion'
#                 break
#
#         return (round(change, 2), scale)
#     else:
#         return (None, None)
# ```|||
#  Success: 3.1
# << 0.7-0.5 || [1212.9, 1216.0, 3.099999999999909] || [0.7, 0.5] || False >>
# 94916f79-4b6d-487f-8fa2-39f81a085760
# What was the percentage change in Capital redemption reserve in 2019 from 2018?R:  ```python
# def run(value_list):
#     """
#     Calculates the percentage change in Capital redemption reserve in 2019 from 2018.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#
#     # Find the relevant data
#     reserve_2018 = next((item for item in value_list if item['category'] == 'Capital redemption reserve' and item['header3'] == '2018'), None)
#     reserve_2019 = next((item for item in value_list if item['category'] == 'Capital redemption reserve' and item['header3'] == '2019'), None)
#
#     if reserve_2018 is None or reserve_2019 is None:
#         return (0.00, "")
#
#     value_2018 = float(reserve_2018['number_value'])
#     value_2019 = float(reserve_2019['number_value'])
#
#     # Calculate the percentage change
#     percentage_change = ((value_2019 - value_2018) / value_2018) * 100
#
#     return (round(percentage_change, 2), 'percent')
# ```|||
#  Success: 40.0
# << (0.7-0.5)/0.5 || [0.5, 0.7, 39.99999999999999] || [0.7, 0.5, 0.5] || True >>
# bbe335ff-414f-48b3-8126-5a2c7c505de3
# How much was the average operating income from 2015 to 2019?R:  ```python
# def run(value_list):
#     operating_income_2015 = None
#     operating_income_2016 = None
#     operating_income_2017 = None
#     operating_income_2018 = None
#     operating_income_2019 = None
#
#     for item in value_list:
#         if item['category'] == 'Operating income (2)':
#             if item['year'] == '2015':
#                 operating_income_2015 = item['number']
#             elif item['year'] == '2016':
#                 operating_income_2016 = item['number']
#             elif item['year'] == '2017':
#                 operating_income_2017 = item['number']
#             elif item['year'] == '2018':
#                 operating_income_2018 = item['number']
#             elif item['year'] == '2019':
#                 operating_income_2019 = item['number']
#
#     if operating_income_2015 is not None and operating_income_2016 is not None and operating_income_2017 is not None and operating_income_2018 is not None and operating_income_2019 is not None:
#         average_operating_income = (operating_income_2015 + operating_income_2016 + operating_income_2017 + operating_income_2018 + operating_income_2019) / 5
#         return (round(average_operating_income, 2), 'thousand')
#     else:
#         return (None, '')
# ```|||
#  Success: None
# <<  (13,535+13,264+12,913+12,604+13,871) / 5  || [] || [13535.0, 13264.0, 12913.0, 12604.0, 13871.0] || False >>
# ef274d2b-fbd6-4e9f-95f9-79b37827d91c
# What was the total expenses for Oracle in 2018?R:  ```python
# def run(value_list):
#     """
#     Calculates the total expenses for Oracle in 2018 based on the provided financial report.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale) representing the total expenses in 2018.
#     """
#     expenses_2018 = 0.0
#     for item in value_list:
#         if item['category'] == 'Total expenses':
#             if item['year'] == '2018':
#                 expenses_2018 = float(item['number'])
#                 break
#
#     if expenses_2018 == 0.0:
#         return (0.0, "")
#
#     return (expenses_2018, "million")
# ```|||
#  Success: 0.0
# << 39,383-3,587  || [0.0] || [39383.0, 3587.0] || False >>
# 191c3926-7356-4ab8-a8f9-41e7b7c8a492
# What were the total Assets as reported?R:  ```python
# def run(value_list):
#     """
#     Calculates the total Assets as reported from the given value list.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale) representing the total Assets as reported,
#         with the number rounded to two decimal places and the scale
#         (e.g., 'thousand', 'million', 'billion', '', or an empty string).
#     """
#     assets_as_reported = 0
#     for item in value_list:
#         if item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'Adoption' and item['header2'] == 'Without ASC 606' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'Adoption' and item['header2'] == 'Without ASC 606' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Prepaid expenses and other current assets (1)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Deferred revenue (2)' and item['header2'] == 'As reported':
#             assets_as_reported += item['number_value']
#         elif item['category'] == 'Other assets (1)' and item['header2'] == 'As reported':
# ...
#     """
#     Calculates the percentage increase of GAAP-based Professional Service and Other Gross Profit from 2017 to 2019.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale) representing the percentage increase.
#     """
#     try:
#         # Extract values for 2017 and 2019
#         value_2017 = float(
#             next(
#                 (
#                     item["number_value"]
#                     for item in value_list
#                     if item["header2"] == "2017"
#                     and item["category"] == "GAAP-based Professional Service and Other Gross Profit"
#                 ),
#                 None,
#             )
#         )
#         value_2019 = float(
#             next(
#                 (
#                     item["number_value"]
#                     for item in value_list
#                     if item["header2"] == "2019"
#                     and item["category"] == "GAAP-based Professional Service and Other Gross Profit"
#                 ),
#                 None,
#             )
#         )
#
#         # Calculate the percentage increase
#         percentage_increase = ((value_2019 - value_2017) / value_2017) * 100
#
#         return (round(percentage_increase, 2), "percent")
#     except (StopIteration, TypeError, ValueError):
#         return (0.00, "")
# ```|||
#  Success: 49.4
# << (60,301-40,362)/40,362 || [40362.0, 60301.0, 49.40042614340221] || [60301.0, 40362.0, 40362.0] || True >>
# 6ce427fa-d1ff-481d-b6ba-7950d43e7c22
# What is the proportion of long-term debt payments due in 5 years or below? R:  ```python
# def run(value_list):
#     """
#     Calculates the proportion of long-term debt payments due in 5 years or below.
#
#     Args:
#         value_list: A list of dictionaries containing financial report data.
#
#     Returns:
#         A tuple (number, scale) representing the proportion.
#     """
#     total_long_term_debt_5_years = 0
#     for item in value_list:
#         if item['category'] == 'Long-term debt .':
#             if item['header1'] in ['1-3 Years', '3-5 Years', 'After 5 Years']:
#                 total_long_term_debt_5_years += item['number_value']
#
#     total_payments = 0
#     for item in value_list:
#         if item['category'] in ['Long-term debt .', 'Capital lease obligations', 'Operating lease obligations', 'Purchase obligations and other contracts', 'Notes payable']:
#             if item['header1'] in ['Total', 'Less than 1 Year', '1-3 Years', '3-5 Years', 'After 5 Years']:
#                 total_payments += item['number_value']
#
#     if total_payments == 0:
#         return (0.00, "")
#
#     proportion = (total_long_term_debt_5_years / total_payments) * 100
#     return (round(proportion, 2), "thousand")
# ```|||
#  Success: 42.16
# << (2,747.6+2,287.0)/10,556.6  || [10556.6, 25038.200000000004, 42.161976499908135] || [2747.6, 2287.0, 10556.6] || False >>
# *** Overall EM:  0.4318181818181818 / 270
# ff90c9d7-de34-46da-a7b2-c7c2747fab0a
# What is the ratio (in percentage) of total notes payable to total capital lease obligations?R:  ```python
# def run(value_list):
#     """
#     Calculates the ratio (in percentage) of total notes payable to total capital lease obligations.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#     total_notes_payable = 0
#     total_capital_lease_obligations = 0
#
#     for item in value_list:
#         if item['category'] == 'Notes payable':
#             if item['header1'] == 'Total':
#                 total_notes_payable = float(item['number_value'])
#             elif item['header1'] == 'Less than 1 Year':
#                 total_notes_payable = float(item['number_value'])
#         elif item['category'] == 'Capital lease obligations':
#             if item['header1'] == 'Total':
#                 total_capital_lease_obligations = float(item['number_value'])
#             elif item['header1'] == 'Less than 1 Year':
#                 total_capital_lease_obligations = float(item['number_value'])
#             elif item['header1'] == '1-3 Years':
#                 total_capital_lease_obligations = float(item['number_value'])
#             elif item['header1'] == '3-5 Years':
#                 total_capital_lease_obligations = float(item['number_value'])
#             elif item['header1'] == 'After 5 Years':
#                 total_capital_lease_obligations = float(item['number_value'])
#
#     if total_capital_lease_obligations == 0:
#         return (0.00, "")
#
#     ratio = (total_notes_payable / total_capital_lease_obligations) * 100
#     return (round(ratio, 2), "thousand")
# ```|||
#  Success: 1.34
# << 1.0/165.4  || [1.0, 74.4, 1.3440860215053763] || [1.0, 165.4] || False >>
# *** Overall EM:  0.4309278350515464 / 270
# 7e8041b3-4b8c-4e47-8c83-af0b9a6fdb4c
# What was the increase / (decrease) in the FCC licenses from 2018 to 2019?R:  ```python
# def run(value_list):
#     """
#     Calculates the increase/decrease in FCC licenses from 2018 to 2019.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#
#     fcc_2018 = None
#     fcc_2019 = None
#
#     for item in value_list:
#         if item['category'] == 'FCC licenses' and item['header1'] == '2018':
#             fcc_2018 = item['number_value']
#         if item['category'] == 'FCC licenses' and item['header1'] == '2019':
#             fcc_2019 = item['number_value']
#
#     if fcc_2018 is not None and fcc_2019 is not None:
#         increase = fcc_2019 - fcc_2018
#         return (round(increase, 2), '')
#     else:
#         return (None, '')
# ```|||
#  Success: 15.6
# << 136.2 - 120.6 || [120.6, 136.2, 15.599999999999994] || [136.2, 120.6] || True >>
# 65581c66-9e18-4e1b-979a-dcd2a873d998
# What was the average State licenses?R:  ```python
# def run(value_list):
#     state_licenses_2019 = [d['number_value'] for d in value_list if d['category'] == 'State licenses' and d['header1'] == '2019']
#     state_licenses_2018 = [d['number_value'] for d in value_list if d['category'] == 'State licenses' and d['header1'] == '2018']
#
#     if state_licenses_2019:
#         average_state_licenses_2019 = sum(state_licenses_2019) / len(state_licenses_2019)
#     else:
#         average_state_licenses_2019 = 0
#
#     if state_licenses_2018:
#         average_state_licenses_2018 = sum(state_licenses_2018) / len(state_licenses_2018)
#     else:
#         average_state_licenses_2018 = 0
#
#
#     if average_state_licenses_2019 == 0 and average_state_licenses_2018 == 0:
#         return (0.00, '')
#     elif average_state_licenses_2019 == 0:
#         return (round(average_state_licenses_2018, 2), '')
#     elif average_state_licenses_2018 == 0:
#         return (round(average_state_licenses_2019, 2), '')
#     else:
#         return (round(average_state_licenses_2019, 2), '')
# ```|||
#  Success: 2.5
# << (2.5 + 2.5) / 2 || [2.5, 2.5] || [2.5, 2.5] || True >>
# 82c155de-a907-4b3f-b89f-1984bd97ddc5
# What is the percentage increase / (decrease) in the total from 2018 to 2019?R:  ```python
# def run(value_list):
#     """
#     Calculates the percentage increase/decrease in the total from 2018 to 2019.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#     total_2018 = 0
#     total_2019 = 0
#
#     for item in value_list:
#         if item['header1'] == '2018':
#             total_2018 += item['number_value']
#         elif item['category'] == 'Total':
#             total_2019 += item['number_value']
#
#     if total_2018 == 0 or total_2019 == 0:
#         return (0.00, '')
#
#     percentage_change = ((total_2019 - total_2018) / total_2018) * 100
#     return (round(percentage_change, 2), 'percent')
# ```|||
#  Success: -43.66
# << 138.7 / 123.1 - 1 || [246.2, 138.7, -43.663688058489036] || [138.7, 123.1] || False >>
# 5b48fea5-61de-401b-aea9-b2b90b7a0eeb
# What is the percentage of non-vested shares granted in 2019 as a percentage of the total non-vested shares at December 31, 2019?R:  ```python
# def run(value_list):
#     """
#     Calculates the percentage of non-vested shares granted in 2019 as a percentage of the total non-vested shares at December 31, 2019.
#     """
#     granted_2019_shares = 0
#     non_vested_2019_shares = 0
#
#     for item in value_list:
#         if item['category'] == 'Granted' and item['header1'] == 'Shares' and item['header2'] == 'Non-vested awards':
#             granted_2019_shares += item['number_value']
#         if item['category'] == 'Non-vested at December 31, 2019' and item['header1'] == 'Shares' and item['header2'] == 'Non-vested awards':
#             non_vested_2019_shares += item['number_value']
#
#     if non_vested_2019_shares == 0:
#         return (0.00, '')
#
#     percentage = (granted_2019_shares / non_vested_2019_shares) * 100
#     return (round(percentage, 2), 'percent')
# ```|||
#  Success: 36.9
# << 473,550/1,283,281  || [473550.0, 1283281.0, 36.90150481461192] || [473550.0, 1283281.0] || True >>
# 8a7ef462-5a25-48c9-8a49-3fb543a73785
# What is the percentage of non-vested shares vested in 2019 as a percentage of the total non-vested shares at December 31, 2019?R:  ```python
# def run(value_list):
#     """
#     Calculates the percentage of non-vested shares vested in 2019 as a percentage of the total non-vested shares at December 31, 2019.
#     """
#     non_vested_2019 = 0
#     total_non_vested_2019 = 0
#     for item in value_list:
#         if item['category'] == 'Non-vested at December 31, 2019':
#             if item['header1'] == 'Shares':
#                 non_vested_2019 = item['number_value']
#             else:
#                 total_non_vested_2019 = item['number_value']
#
#     if total_non_vested_2019 == 0:
#         return (0.00, "")
#
#     percentage = (non_vested_2019 / total_non_vested_2019) * 100
#     return (round(percentage, 2), "percent")
# ```|||
#  Success: 2826610.13
# << 365,223/1,283,281  || [1283281.0, 45.4, 2826610.1321585905] || [1283281.0] || True >>
# 240b5a32-819a-4cbe-8420-0ab6dfe3b2eb
# What is the percentage of non-vested shares forfeited in 2019 as a percentage of the total non-vested shares at December 31, 2019?R:  ```python
# def run(value_list):
#     """
#     Calculates the percentage of non-vested shares forfeited in 2019 as a percentage of the total non-vested shares at December 31, 2019.
#     """
#     forfeited_shares_2019 = 0
#     for record in value_list:
#         if record['category'] == 'Forfeited' and record['header1'] == 'Shares':
#             forfeited_shares_2019 = record['number_value']
#
#     non_vested_shares_2019 = 0
#     for record in value_list:
#         if record['category'] == 'Non-vested at December 31, 2019' and record['header1'] == 'Shares':
#             non_vested_shares_2019 = record['number_value']
#
#     if non_vested_shares_2019 == 0:
#         return (0.00, '')
#
#     percentage = (forfeited_shares_2019 / non_vested_shares_2019) * 100
#     return (round(percentage, 2), 'percent')
# ```|||
#  Success: -0.98
# << 12,632/1,283,281  || [-12632.0, 1283281.0, -0.9843518294122644] || [1283281.0] || True >>
# c8ed0bf6-60c5-41e2-97e3-5ece54a1349b
# What is the change in total personnel expenses from 2018 to 2019?R:  ```python
# def run(value_list):
#     """
#     Calculates the change in total personnel expenses from 2018 to 2019.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#
#     total_2018 = None
#     total_2019 = None
#
#     for item in value_list:
#         if item['header1'] == '2018' and item['category'] == 'Total':
#             total_2018 = item['number_value']
#         elif item['header1'] == '2019' and item['category'] == 'Total':
#             total_2019 = item['number_value']
#
#     if total_2018 is not None and total_2019 is not None:
#         change = total_2019 - total_2018
#         scale = 'thousand'  # Assuming scale is thousand
#         return (round(change, 2), scale)
#     else:
#         return (None, None)
# ```|||
#  Success: 39224.0
# <<  227,727 - 188,503  || [188503.0, 227727.0, 39224.0] || [227727.0, 188503.0] || True >>
# 4cdc8b2e-e3ea-4c36-bbda-7c409a84cc78
# What is the percentage change in total personnel expenses from 2018 to 2019?R:  ```python
# def run(value_list):
#     """
#     Calculates the percentage change in total personnel expenses from 2018 to 2019.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#     total_2018 = None
#     total_2019 = None
#
#     for item in value_list:
#         if item['header1'] == '2018' and item['category'] == 'Total':
#             total_2018 = item['number_value']
#         elif item['header1'] == '2019' and item['category'] == 'Total':
#             total_2019 = item['number_value']
#
#     if total_2018 is not None and total_2019 is not None:
#         percentage_change = ((total_2019 - total_2018) / total_2018) * 100
#         return (round(percentage_change, 2), 'percent')
#     else:
#         return (None, '')
# ```|||
#  Success: 20.81
# <<  (227,727 - 188,503 )/188,503 || [188503.0, 227727.0, 20.80815689935969] || [227727.0, 188503.0, 188503.0] || True >>
# ec696158-f93d-4608-903d-a6b9c4e7bfd5
# What is the increase / (decrease) in the telecommunication maintenance from 2018 to 2019?R:  ```python
# def run(value_list):
#     """
#     Calculates the increase/decrease in telecommunication maintenance from 2018 to 2019.
#
#     Args:
#         value_list: A list of dictionaries containing financial data.
#
#     Returns:
#         A tuple (number, scale).
#     """
#     telecommunication_maintenance_2018 = None
#     telecommunication_maintenance_2019 = None
#
#     for item in value_list:
#         if item['category'] == 'Telecommunication - Maintenance':
#             if item['header1'] == '2018':
#                 telecommunication_maintenance_2018 = item['number_value']
#             elif item['header1'] == '2019':
#                 telecommunication_maintenance_2019 = item['number_value']
#
#     if telecommunication_maintenance_2018 is not None and telecommunication_maintenance_2019 is not None:
#         increase_decrease = telecommunication_maintenance_2019 - telecommunication_maintenance_2018
#         scale = 'thousand'  # Assuming scale is thousand
#         return (round(increase_decrease, 2), scale)
#     else:
#         return (None, None)
# ```|||
#  Success: -0.2
# << 86.8 - 87.0 || [87.0, 86.8, -0.20000000000000284] || [86.8, 87.0] || True >>
# 27911d6f-dfe5-487b-bc56-7e5cf16a32e0
# What is the average telecommunications installation?R:  ```python
# def run(value_list):
#     telecommunication_installation_2019 = 0
#     telecommunication_installation_2018 = 0
#     for item in value_list:
#         if item['category'] == 'Telecommunication - Installation':
#             telecommunication_installation_2019 += item['number_value']
#             if 'header1':
#                 telecommunication_installation_2018 += item['number_value']
#     if telecommunication_installation_2018 == 0:
#         average = telecommunication_installation_2019
#     else:
#         average = (telecommunication_installation_2019 + telecommunication_installation_2018) / 2
#     scale = item['scale']
#     return (round(average, 2), scale)
# ```|||
#  Success: 74.7
# << (33.2 + 41.5) / 2 || [74.7, 74.7, 74.7] || [33.2, 41.5] || False >>
# 3b8e873e-64d5-4af0-904f-7197dc632773
# What is the average Total Marine Services segment revenue?R:  ```python
# def run(value_list):
#     marine_revenue_2019 = 0
#     marine_revenue_2018 = 0
#     for item in value_list:
#         if item['category'] == 'Total Marine Services segment revenue':
#             if item['header1'] == '2019':
#                 marine_revenue_2019 = item['number_value']
#             elif item['header1'] == '2018':
#                 marine_revenue_2018 = item['number_value']
#
#     if marine_revenue_2019 != 0 and marine_revenue_2018 != 0:
#         average_revenue = (marine_revenue_2019 + marine_revenue_2018) / 2
#         return (round(average_revenue, 2), 'thousand')
#     else:
#         return (0.00, '')
# ```|||
#  Success: 183.4
# << (172.5 + 194.3) / 2 || [172.5, 194.3, 183.4] || [172.5, 194.3] || True >>
# 1770466320.9787636 4272.392906188965
# cnt: 497

# %%
annotated_results = cga_utils.annotate_results(res)
#annotated_results.to_csv('res/Ollama_2_gemma3n_e4b_code_values_v11_m1.csv')
cga_utils.calc_overall_value_match(annotated_results)
# Out:
# Annotaion warning:  invalid syntax (<unknown>, line 5)
# Annotaion warning:  EOL while scanning string literal (<unknown>, line 4)
# Annotaion warning:  invalid decimal literal (<unknown>, line 12)
# Annotaion warning:  invalid decimal literal (<unknown>, line 12)
# 0.5633802816901409

# %%
cga_utils.calc_overall_em(annotated_results), cga_utils.calc_overall_em_alt(annotated_results)
# Out:
# (0.42857142857142855, 0.4285714285714286)

# %%
annotated_results.to_csv('res/gemma3_v19a.csv')

# %%
df = annotated_results.query('error_code != "none"')
cga_utils.crosstab_heatmap(df, 'error_code', 'calc_pattern', 40,0,3) 
len(df)
# Out:
# 266

# %%
v31 = pd.read_csv('res/e38_31.csv')
cga_utils.compare_results(v31, annotated_results, "qid", "exact_match", ["error_code"]).to_csv('res/comp_v31_v45.csv')

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain.schema import HumanMessage

messages = [("human", "Say Hi! /no_think")]
prompt = ChatPromptTemplate.from_messages(messages)
output_parser = StrOutputParser()
chain = prompt | llm | output_parser
r = chain.invoke({})

# %%
import prompt_versions
from fastapi import FastAPI
import os
from fastapi.responses import StreamingResponse
from fastapi.staticfiles import StaticFiles
from fastapi.responses import FileResponse
from fastapi import Request

import asyncio
import json
import ast
import time
import timeit
from pathlib import Path

import cga_utils
import table_convert

app = FastAPI()

from langchain_community.chat_models import ChatOllama
llm = ChatOllama(model="qwen3:4b", temperature = 0.0, top_p = 1, repeat_penalty=1, presence_penalty=0, frequency_penalty=0)  
#agent = CodeGenAgent(llm, "V38")


from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain.schema import HumanMessage

messages = [("human", "Say Hi! /no_think")]
prompt = ChatPromptTemplate.from_messages(messages)
output_parser = StrOutputParser()
chain = prompt | llm | output_parser
r = chain.invoke({})
r
# Out:
# '<think>\n\n</think>\n\nHello! How can I assist you today? 😊'

# %%
df = annotated_results.query('error_code != "none"')
cga_utils.crosstab_heatmap(df, 'error_code', 'calc_pattern', None, 0, 2)
len(df)
# Out:
# 166

# %%
cga_utils.crosstab_heatmap(df, 'error_code', 'calc_pattern', None, 0, 2)

# %%
df = annotated_results.query('error_code != "none"')
cga_utils.crosstab_heatmap(df, 'error_code', 'aggr_calc_pattern', 40)
len(df)
# Out:
# /home/apandy/Tabular/tab_small/cga_utils.py:342: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 166

# %%
df = annotated_results.query('error_code != "none"')
cga_utils.crosstab_heatmap(df, 'error_code', 'calc_pattern', 40,0,3) 
len(df)
# Out:
# 176

# %%
import seaborn as sns
import matplotlib.pyplot as plt
def crosstab_heatmap(df, x, y, vmax=None):
    # 1. Kontingenciatábla
    pattern_error_matrix = pd.crosstab(df[x], df[y], normalize='columns')
    
    # 3. Hőtérkép
    plt.figure(figsize=(14, 6))
    sns.heatmap(pattern_error_matrix, cmap='YlOrBr', vmax=vmax, annot=True )
    
    #plt.title("Hibatípusok előfordulása számítási minták szerint (normalizálva)")
    plt.xlabel(y)
    plt.ylabel(x)
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()
crosstab_heatmap(df, 'error_code', 'calc_pattern')

# %%
import re
from collections import Counter

def aggregate_calc_patterns(patterns, replacement="#", other_group_szie=4):

    def merge(text):        
        while (f'{replacement}+{replacement}+{replacement}' in text):
            text = text.replace(f'{replacement}+{replacement}+{replacement}', f'{replacement}+{replacement}')
        return text
    def aggr(text, counts):
        if counts[text] > other_group_szie:
            return text
        else:
            return "other"
    merged = [merge(text) for text in texts]
    counts = Counter(merged)
    aggregated = [aggr(text, counts) for text in texts]
    return aggregated

# %%
patterns = cga_utils.replace_numbers(annotated_results['derivation'])
patterns2 = aggregate_calc_patterns(patterns)
set(patterns2)
# Out:
# {'#%-#%',
#  '#+#',
#  '#-#',
#  '#/#',
#  '#/#-#',
#  '(#%+#%)/#',
#  '(#+#)/#',
#  '(#-#)/#',
#  '-#-#',
#  '-(#+#)/#',
#  'other'}

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = annotated_results.query('error_code != "none"')

# 1. Csak a True/False típusú oszlopokat szűrjük ki
bool_cols = df.select_dtypes(include=['bool'])

# 2. Korrelációs mátrix számítása
corr = bool_cols.corr()
em_corr = bool_cols.corr()['exact_match'].dropna().sort_values(ascending=False)

print(em_corr)

# 3. Heatmap megjelenítés
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap="coolwarm", center=0)

plt.title("Korrelációs heatmap (True/False oszlopokra)")
plt.tight_layout()
plt.show()
# Out:
# Series([], Name: exact_match, dtype: float64)

# %%
bool_cols
# Out:
#      value_match  selection_success  sign_error  is_parenth_in_table  \
# 6          False              False       False                False
# 8          False              False       False                 True
# 16         False              False       False                 True
# 17         False               True       False                 True
# 22         False              False       False                 True
# ..           ...                ...         ...                  ...
# 482        False              False       False                 True
# 484         True               True       False                False
# 489        False               True       False                 True
# 490        False               True        True                 True
# 491        False               True       False                 True
#
#      has_code_abs  exact_match
# 6           False        False
# 8           False        False
# 16          False        False
# 17          False        False
# 22          False        False
# ..            ...          ...
# 482         False        False
# 484         False        False
# 489         False        False
# 490         False        False
# 491          True        False
#
# [190 rows x 6 columns]
