# %%
import cga_utils
import prompt_versions
# %load_ext autoreload
# %autoreload 2

# %%
from langchain.globals import set_llm_cache
from langchain_community.cache import SQLiteCache

set_llm_cache(SQLiteCache(database_path=".langchain.s2_1.db"))

# %%
from langchain_community.chat_models import ChatOllama
#llm = ChatOllama(model="qwen3:4b", temperature = 0.0, top_p = 1, repeat_penalty=1, presence_penalty=0, frequency_penalty=0)  # vagy bármely más elérhető Ollama model
llm = ChatOllama(model="hf.co/unsloth/Qwen3-4B-Instruct-2507-GGUF:latest")  # vagy bármely más elérhető Ollama modell

# %%
dataset_tr = pd.read_json('dataset_raw/tatqa_dataset_train.json')    
dataset_t = pd.read_json('dataset_raw/tatqa_dataset_test.json')    
dataset_tg = pd.read_json('dataset_raw/tatqa_dataset_test_gold.json')    
dataset_d = pd.read_json('dataset_raw/tatqa_dataset_dev.json')    

sample_df = dataset_tg.sample(frac=0.20, random_state=42)
#sample_df = dataset_tr.sample(frac=0.031, random_state=42)

# %%
len(dataset_tr), len(dataset_d),  len(dataset_t), len(dataset_tg), len(sample_df)
# Out:
# (2201, 278, 278, 277, 55)

# %%
for i, item in sample_df.iterrows():    
    table = item['table']['table']     
    for q_item in item['questions']:
        for idev, itemd in dataset_d.iterrows():
            tabled = itemd['table']['table']     
            for q_itemd in itemd['questions']: 
                if q_itemd['answer_type'] == "arithmetic" and q_item['question'] == q_itemd['question']:
                #if q_item['question'] == q_itemd['question']:
                    print('duplicate', q_item['question'], q_itemd['question'], q_item['answer'],  q_itemd['answer'])

# %%
import pandas as pd
messages = prompt_versions.prompt_versions['V18'] #Base
#messages = [(a, t.replace('/no_think','')) for (a,t)  in messages]
#messages[-1] = ( messages[-1][0],  messages[-1][1] + "/no_think" ) 

res = cga_utils.execute_dataset_predictions(llm, messages, dataset=sample_df)
# Out:
# 1770204294.33221
# 0it [00:00, ?it/s]
# 7e2290f656cbeef6d9a61c02767b752c
# What was the percentage change in adjusted EBITDA between 2018 and 2019? failure: 16.36 good answer:  16.36
# << ((108,307-93,081)/93,081) * 100 || [108307.0, 93081.0, 16.357795898196194] || [108307.0, 93081.0, 93081.0, 100.0] || False >>
# *** Overall EM:  1.0 / 30
# d2fca279eeba2f76f54127d5884fc542
# What is the change in revenue growth between 2019 and 2018? Success: -4.4
# << ((7.2%-11.6%)) * 100 || [7.2, 11.6, -4.3999999999999995] || [7.2, 11.6] || True >>
# 15c13aff533786d03238eb3e6f433c1f
# What are leasehold improvements in 2019 as a percentage of the total property equipment before depreciation, amortization and fixed assets not in service? Success: 3.26
# << ((3,522/79,828)) * 100 || [3522.0, 107962.0, 3.262258942961412] || [3522.0, 79828.0] || False >>
# *** Overall EM:  0.6666666666666666 / 220
# a232d237c226f8bcfdabfd8daad919fc
# What was the change in Property and equipment, net in 2018 from 2017? Success: -3991.0
# << -$9,401-(-$5,410) || [-9401.0, -5410.0, -3991.0] || [] || True >>
# 60fc4cb62e02f1bc47519bc34b2cd6b1
# What was the percentage change in Property and equipment, net in 2018 from 2017? Success: 73.77
# << ((-$9,401-(-$5,410))/-$5,410) * 100 || [-9401.0, -5410.0, 73.77079482439926] || [] || True >>
# a30c0da091bbd33f665ab11a25117074
# What was the percentage change in Interest expense between 2015 and 2016? Success: 20.3
# << ((717-596)/596) * 100 || [596.0, 717.0, 20.302013422818792] || [717.0, 596.0, 596.0] || True >>
# eeef320a4199b74356c5e18e58c33fb4
# What was the average Research and development expense for 2018 and 2019? Success: 45664.5
# << (50,024 + 41,305) / 2 || [50024.0, 41305.0, 45664.5] || [50024.0, 41305.0] || True >>
# 36453309f798d54fba67e60cac4490e2
# What is the change in the % of revenue from 2018 to 2019? Success: -3.0
# << 25 - 28 || [25.0, 28.0, -3.0] || [25.0, 28.0] || True >>
# 7645f09642d6f2db485e05ac58013f26
# What is the change of expenses for facilities from fiscal year 2017 to 2019?  Success: 3059.0
# << 7,834-4,775 || [7834.0, -4775.0, 3059.0] || [7834.0] || True >>
# a23b3dcb820703a1d9aea7dc33091afb
# What is the difference between the Change between Fiscal increase for 2019 and 2018 and 2018 and 2017 for Payroll and payroll-related benefits? Success: -26490.0
# << 39,119-12,629 || [12629.0, 39119.0, -26490.0] || [39119.0, 12629.0] || True >>
# 6d046c35f507c818158760c49dae5e23
# What is the Total change in research and development expenses from 2017 to 2019? Success: 40621.0
# << 41,694-1,073 || [41694.0, -1073.0, 40621.0] || [41694.0] || True >>
# 640faac1ccb705ef422bfaa0f72e84f1
# What was the percentage change in Dividend and interest income in 2018 from 2017? Success: 50.47
# << ((635-422)/422) * 100 || [635.0, 422.0, 50.4739336492891] || [635.0, 422.0, 422.0] || True >>
# 50d6a01be8a0986d1b43bdb3a32e3446
# What was the change in the Loss from discontinued operations from 2017 to 2018? Success: -60921.0
# << -72,836 - (-11,915) || [-11915.0, -72836.0, -60921.0] || [] || True >>
# 679f03324e62ac16d07bc3e09c8e2376
# What is the average Gain on sale of Netsmart between 2017-2019? Success: 166823.67
# << (0 + 500,471 + 0) / 3 || [166823.66666666666] || [0.0, 500471.0, 0.0] || False >>
# 0cc2a888dd2540ce9991a759eb85bbaf
# What was the average Income tax effect on discontinued operations between 2017-2019? Success: 3255.33
# << (0 - 32,497 + 42,263) / 3 || [3255.3333333333335] || [0.0, 42263.0] || False >>
# 56d9aa6afc1e09a1727aacc4c0435d45
# What was the 2019 percentage change in accrued revenue? Success: 377.63
# << ((27,817 - 5,824) / 5,824 ) * 100 || [27817.0, 5824.0, 377.62706043956047] || [27817.0, 5824.0, 5824.0] || True >>
# 247b29ff672119850a618a5e59edf29e
# What was the average accrued revenue between 2018 and 2019? Success: 16820.5
# << (27,817 + 5,824) / 2  || [27817.0, 5824.0, 16820.5] || [27817.0, 5824.0] || True >>
# 6f1652507bcbc0845aa582d579321209
# How much was the difference in unearned revenue and accrued revenue in 2019? Success: -748.0
# << 27,817 - 27,069  || [27817.0, 27069.0, -748.0] || [27817.0, 27069.0] || True >>
# 0360296840de0645325b8cb6306101ff
# What is the net value of the unrealized gains and losses of the company's municipal bonds? Success: -97.0
# << 13 + (110)  || [13.0, -110.0, -97.0] || [13.0] || True >>
# 8039ea4c8f281b490be3e64dd7aef8e7
# What is the value of the amortized costs of  the municipal bonds as a percentage of the total amortized cost? Success: 24.01
# << (44,802/93,301 ) * 100 || [44802.0, 186602.0, 24.0093889668921] || [44802.0, 93301.0] || False >>
# afe196e1ac486bdab48cad41046bcf08
# What is the value of the amortized costs of  the corporate bonds as a percentage of the total amortized cost? Success: 25.99
# << (48,499/93,301 ) * 100 || [48499.0, 186602.0, 25.990611033107896] || [48499.0, 93301.0] || False >>
# 9c0a92f33095574b70f992e3ac68715a
# What is the total amount of all other compensation by all the directors in the table? Success: 41386.0
# << $4,000+$17,000+$15,950+$4,436 || [41386.0] || [4000.0, 17000.0, 15950.0, 4436.0] || False >>
# *** Overall EM:  0.7272727272727273 / 230
# 87192af423506160cd1df8fc628706e4
# What is the average amount of total compensation for each non-returning director? Success: 330267.33
# << ($259,472+$471,422+$259,908)/3 || [330267.3333333333] || [259472.0, 471422.0, 259908.0] || False >>
# *** Overall EM:  0.7391304347826086 / 230
# ffe60dd9dae69ba85ea4fae7ee10ebae
# What is the increase/ (decrease) in Wireless devices and accessories from 2018 to 2019? Success: -19.0
# << 380-399 || [380.0, 399.0, -19.0] || [380.0, 399.0] || True >>
# 80f4540b447fc62c20f332f34250dc94
# What is the increase/ (decrease) in Other finished goods and merchandise from 2018 to 2019? Success: 13.0
# << 80-67 || [80.0, 67.0, 13.0] || [80.0, 67.0] || True >>
# b9052616463aee5ec89dd6da25bc73a2
# What is the increase/ (decrease) in Total inventories from 2018 to 2019? Success: -6.0
# << 460-466 || [460.0, 466.0, -6.0] || [460.0, 466.0] || True >>
# cf42ab5eb0e02d2fa26ecbd6f525fb13
# What was the percentage change in the the total net property, plant and equipment between 2018 and 2019? Success: 5.67
# << ((105,038-99,401)/99,401) * 100 || [105038.0, 99401.0, 5.67] || [105038.0, 99401.0, 99401.0] || True >>
# 12c96773a28e7443eb18764411eaef50
# What is the percentage change in capitalized interest in 2019? Success: -11.76
# << ((45-51)/51) * 100 || [45.0, 51.0, -11.76470588235294] || [45.0, 51.0, 51.0] || True >>
# 2e7d0e6099ef5431e0ce2ca15d0cc9d9
# What is the company's total operating lease obligations between 2020 to 2022? Success: 55746.0
# << 19,373 + 36,373  || [55746.0] || [19373.0, 36373.0] || False >>
# 75022367778142d287da9236724aad8d
# What is the percentage constitution of purchase obligations among the total contractual obligations in 2020? Success: 54.0
# << (24,800/45,927) * 100 || [45927.0, 24800.0, 53.99873712630914] || [24800.0, 45927.0] || True >>
# 5b8b422ea976902a5f10dbb8bb17179e
# What is the value of the company's 2023-2024 purchase obligations as a percentage of its total payment due in the 2023-2024 period? Success: 2.18
# << (438/20,121 ) * 100 || [438.0, 20121.0, 2.1768301774265693] || [438.0, 20121.0] || True >>
# 76fcf6b0bf227d2e506aee1910f497cf
# What is the difference in the total franchise revenues between 2018 and 2019? Success: 191668.0
# << $613,300 - $421,632  || [613300.0, 421632.0, 191668.0] || [613300.0, 421632.0] || True >>
# *** Overall EM:  0.8125 / 60
# 23fe1be9117b398035a9ead824b331a8
# What is the average in total franchise costs for 2018 and 2019? Success: 263349.5
# << ($356,787 + $169,912)/2  || [169912.0, 356787.0, 263349.5] || [356787.0, 169912.0] || True >>
# *** Overall EM:  0.8181818181818182 / 60
# dca2866a67dde74f8acfb646e68e7592
# What is the percentage constitution of franchise rental revenues among the total franchise revenues in 2019? Success: 44.48
# << ($272,815/$613,300 ) * 100 || [272815.0, 613300.0, 44.483124082830585] || [272815.0, 613300.0] || True >>
# *** Overall EM:  0.8235294117647058 / 60
# 40acacac7f638d5cfdff96a4b1c0995d
# What is the average year-on-year change in Weighted average grant date fair value from 2017 to 2019?  Success: -9.5
# << (((4.72-3.36)/3.36+(3.36-3.69)/3.69)/2) * 100 || [4.72, 3.36, 3.69, -28.8135593220339, 9.821428571428575, -9.496065375302663] || [4.72, 3.36, 3.36, 3.36, 3.69, 3.69] || True >>
# f7e00028b6447875f8005ab8c18639a4
# What was the percentage increase / (decrease) in Weighted average grant date fair value from 2018 to 2019? Success: 40.48
# << (4.72 / 3.36 - 1) * 100 || [3.36, 4.72, 40.476190476190474] || [4.72, 3.36] || True >>
# 586b24199ab25b1747ae3573492f1ccb
# What was the increase / (decrease) in the Weighted average grant date fair value from 2018 to 2019? Success: 1.36
# << 4.72 - 3.36 || [3.36, 4.72, 1.3599999999999999] || [4.72, 3.36] || True >>
# 75e012945b2e63911c3bc4376b042c0d
# What is the percentage change in the net operating loss carry forward from 2018 to 2019? Success: 8.45
# << ((27,907 - 25,733)/25,733 ) * 100 || [25733.0, 27907.0, 8.448295962382932] || [27907.0, 25733.0, 25733.0] || True >>
# 128c698b8fad151bf8516c2d51f1760b
# What is the change in Reserves and accruals between 2018 and 2019? Success: 17.0
# << 62 - 45  || [62.0, 45.0, 17.0] || [62.0, 45.0] || True >>
# 90fe2b41c9523249f82744554c978991
# What was the percentage change in Total cash, cash equivalents and restricted cash between 2018 and 2019? Success: 20.93
# << (($1,578.0-$1,304.9)/$1,304.9) * 100 || [1578.0, 1304.9, 20.93] || [1578.0, 1304.9, 1304.9] || True >>
# b2d5e2512b0988dd701480c344fb82bf
# What is the change in Item reclassified from freehold investment property from 2018 to 2019? Success: -2332.0
# << 2,068-4,400 || [4400.0, 2068.0, -2332.0] || [2068.0, 4400.0] || True >>
# 03b8194d47511d07e1e1aa58aa721957
# What is the change in Disposals during the year from 2018 to 2019? Success: 3439.0
# << 961-4,400 || [-4400.0, -961.0, 3439.0] || [4400.0] || False >>
# 4478c71ff25482f914636301d4c2413a
# What is the change in Other intangible assets Amortisation 2018 to 2019? Success: 0.0
# << 1,107-5,713 || [] || [1107.0, 5713.0] || False >>
# 715c9dd9b0dc4720ea3ba7ad4e436ee8
# What was the change in the amount for contracts within one year? Success: 2.8
# << 18.3-15.5 || [18.3, 15.5, 2.8000000000000007] || [18.3, 15.5] || True >>
# 25c53226518b6687085500e468d8cdfa
# What was the percentage change in the amount for contracts within one year? Success: 18.06
# << ((18.3-15.5)/15.5) * 100 || [18.3, 15.5, 18.064516129032263] || [18.3, 15.5, 15.5] || True >>
# 85c74755d4ccf8eb9167000284c818a9
# What is the revenue from Canada in 2019 as a percentage of the total revenue in 2019? Success: 2.7
# << ((9,815/363,800)) * 100 || [9815.0, 363800.0, 2.6979109400769654] || [9815.0, 363800.0] || True >>
# 276815a7f82a8c5eb1a4991d98fe253b
# What is the change in the number of IPTV retail subscribers in 2019? Success: -19314.0
# << 1,767,182-1,675,706 || [] || [1767182.0, 1675706.0] || False >>
# 34e05c377aa4cec6cc7ab6feedb0812c
# What is the percentage of Satellite subscribers out of the total retail subscribers in 2019? Success: 36.26
# << (1,005,282/2,772,464) * 100 || [1005282.0, 2772464.0, 36.259515001817874] || [1005282.0, 2772464.0] || True >>
# 587984b897fac513f24769a16342c523
# What is the percentage of IPTV subscribers out of the total retail subscribers in 2019? Success: 63.74
# << (1,767,182/2,772,464) * 100 || [1767182.0, 2772464.0, 63.740484998182126] || [1767182.0, 2772464.0] || True >>
# 653f0628622f8a654b56e21f1d58d1f8
# What is the change in Interest income from 2018 to 2019? Success: 28.7
# << 121-94 || [121.0, 94.0, 28.7] || [121.0, 94.0] || True >>
# e25f7d33f913085e05d33e04acedf950
# What is the change in Other components of net periodic benefit cost from 2018 to 2019? Success: -2441.0
# << 627-3,068 || [] || [627.0, 3068.0] || False >>
# 5c54743f6de457f4d0af525fc5ba37ed
# What is the change in Early debt extinguishment costs from 2018 to 2019?[Inner Exception]cannot unpack non-iterable NoneType object
# ab007d8a4c643492a9312c096956dffe
# What was the change in PSP payments for the Group in 2019 from 2018? Success: 0.3
# << 2.1-1.8 || [1.8, 2.1, 0.30000000000000004] || [2.1, 1.8] || True >>
# b78a785338a7b71fdc0668c0faf22fbe
# What was the percentage change in PSP payments for the Group in 2019 from 2018? Success: 16.67
# << ((2.1-1.8)/1.8) * 100 || [1.8, 2.1, 16.666666666666668] || [2.1, 1.8, 1.8] || True >>
# 25d2e81cd8e2d8ab81c5796d6e89c4ec
# What was the change in gross profit between May 2019 and August 2019? Success: 51279.0
# << 495,078-443,799 || [443799.0, 495078.0, 51279.0] || [495078.0, 443799.0] || True >>
# 8f23d52beaedf5e030daa78043e721cc
# What was the change in basic earnings per share attributable to the stockholders of Jabil Inc. between May 2019 and August 2019?[Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType'
# [Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType'
#  Success: [Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType'
# << $0.34-$0.28 || [] || [0.34, 0.28] || False >>
# 27f1a9c7a554b928ab4da0afb589b3f6
# What was the percentage change in net revenue between November 2018 and February 2019? Success: -6.75
# << (($6,066,990-$6,506,275)/$6,506,275) * 100 || [6506275.0, 6066990.0, -6.751712769595505] || [6066990.0, 6506275.0, 6506275.0] || True >>
# a4778f6baf7fbc47c36e2df4f39aff7e
# What was the change in the total compensation in 2019 from 2018? Success: 1.2
# << 9.0-7.8 || [9.0, 7.8, 1.2000000000000002] || [9.0, 7.8] || True >>
# fd96beba233f4b2ec8b7e5d2cf1c7aed
# What was the percentage change in the total compensation in 2019 from 2018? Success: 15.38
# << ((9.0-7.8)/7.8) * 100 || [9.0, 7.8, 15.384615384615389] || [9.0, 7.8, 7.8] || True >>
# c148020f43b4ba93d6dc65235e69e7cc
# What proportion of the total cost does the acquisition related cost form part of in 2019? Success: 0.12
# << ($1,696 / $14,290) * 100 || [14290.0, 1696.0, 0.11868439468159551] || [1696.0, 14290.0] || True >>
# 1d568952985d546e1035c7b8311c07cf
# What was the percentage change in non-current assets in Asia Pacific? Success: 68.18
# << ((7.4-4.4)/4.4) * 100 || [7.4, 4.4, 68.18181818181817] || [7.4, 4.4, 4.4] || True >>
# 11f94da9b4b3b0eb8e771898f7cb3b5c
# In 2019, what is the percentage constitution of nonvested stock units among the total share-based compensation expense? Success: 67.6
# << (5,458/8,074) * 100 || [5458.0, 8074.0, 67.59970274956652] || [5458.0, 8074.0] || True >>
# d82ccbf862bbea0c2a60bf0f08df9c5d
# What was the difference between the 2019 actual group cash generation compared with the 2019 target group cash generation? Success: 11.399999999999977
# << 296.4-285.0 || [296.4, 285.0, 11.399999999999977] || [296.4, 285.0] || True >>
# 3bff27eb2944cb199f863d6eb50bb06d
# What is the 2019 actual group operating profit expressed as a ratio of the 2019 target group operating profit? Success: 1.03
# << 277.3/270.3 || [277.3, 270.3, 1.0258971513133555] || [277.3, 270.3] || True >>
# 7d26ba6ef5c6202999c0593a1ec5c6d6
# What is the year-on-year change in VAS Business revenue? Success: -5.36
# << 199,991-176,646 || [53.0, 56.0, -5.357142857142857] || [199991.0, 176646.0] || False >>
# 929018fca125b27facecdc3b42edbe47
# What is the year-on-year change in FinTech and Business Services revenue? Success: 17.39
# << 101,355-73,138 || [27.0, 23.0, 17.391304347826086] || [101355.0, 73138.0] || False >>
# df27c6c6567c0b93f2a4b3702d885835
# What is the year-on-year change in Online Advertising Business revenue? Success: -5.26
# << 68,377-58,079 || [18.0, 19.0, -5.263157894736842] || [68377.0, 58079.0] || False >>
# b5572f9f8b64c1e860b7c4dcdcf272de
# What was the change in personnel expenses in 2018/2019 from 2017/2018? Success: 91.0
# << 2,816-2,725 || [2173.0, 2264.0, 91.0] || [2816.0, 2725.0] || False >>
# 2df5086d76d9cb82d007d208a95e03bf
# What was the percentage change in personnel expenses in 2018/2019 from 2017/2018? Success: 4.19
# << ((2,816-2,725)/2,725) * 100 || [2173.0, 2264.0, 4.187758858720662] || [2816.0, 2725.0, 2725.0] || False >>
# 4cc89377aa421d8d6eece5a7dce4de2d
# What is the average cash dividends declared per share for fiscal years 2017 to 2019?[Error]unsupported operand type(s) for +: 'NoneType' and 'NoneType'
# [Error]unsupported operand type(s) for +: 'NoneType' and 'NoneType'
#  Success: [Error]unsupported operand type(s) for +: 'NoneType' and 'NoneType'
# << (1.28+ 1.28+ 2.04)/3 || [] || [1.28, 1.28, 2.04] || False >>
# a070ac129ffad54615cd45118c9aea75
# What is the change in operating income between fiscal years 2019 and 2018? Success: 38294.0
# << 67,994-29,700 || [67994.0, 29700.0, 38294.0] || [67994.0, 29700.0] || True >>
# 27f6efd18696c43720f1ca2e94c0f7e5
# What is the average basic earnings per share for fiscal years 2017 to 2019?[Error]unsupported operand type(s) for +: 'NoneType' and 'NoneType'
# [Error]unsupported operand type(s) for +: 'NoneType' and 'NoneType'
#  Success: [Error]unsupported operand type(s) for +: 'NoneType' and 'NoneType'
# << (2.41+ 2.70+ 12.30)/3 || [] || [2.41, 2.7, 12.3] || False >>
# 2c0e0e756168b45e92978a151a7fb2ab
# What is the amount of total commission as a percentage of the Ceiling as per Section 198 of the Companies Act? Success: 108.98
# << (1,210.00/40,434.81 ) * 100 || [44064.81, 40434.81, 108.97741327336522] || [1210.0, 40434.81, 100.0] || False >>
# f0b2fe06c1b53072f911666f3c4fc564
# What is the amount of total Sitting Fees as a percentage of Total Managerial Remuneration? Success: 6.36
# << (33.60/1,243.60 ) * 100 || [2573.0, 40434.81, 6.363329022691093] || [33.6, 1243.6, 100.0] || False >>
# f585885778f95bf1dbb2a00151125624
# What was the change in revenue in Ireland in 2019 from 2018? Success: 0.0
# << 5.2-5.2 || [5.2, 5.2, 0.0] || [5.2, 5.2] || True >>
# acf5fdb8be289c36f97930c4fcf72942
# What was the percentage change in revenue in Ireland in 2019 from 2018? Success: 0.0
# << (5.2-5.2)/5.2 || [5.2, 5.2, 0.0] || [5.2, 5.2, 5.2] || True >>
# ee85b9ce062cb99f0861b9c43d6f6eed
# What is the ratio of Darcy Antonellis’ total compensation to David C. Habiger’s total compensation? Success: 0.93
# << 205,320/219,987  || [205320.0, 219987.0, 0.9333278784655457] || [205320.0, 219987.0] || True >>
# bf0f732e7286dad472c3a7a3848415a2
# What is the average fee earned or paid in cash compensation for all non-employee directors? Success: 77111.0
# << (106,000+55,333+70,000+81,000+68,333+82,000)/6  || [77111.0] || [106000.0, 55333.0, 70000.0, 81000.0, 68333.0, 82000.0] || False >>
# 48f4cafcd78061339d631d6490c055e0
# What was the change in Other in FY2019 from FY2018? Success: 0.0
# << 1-1 || [1.0, 1.0, 0.0] || [1.0, 1.0] || True >>
# 5bbcaeb1ebcedc949361aba4d6559771
# What was the percentage change in Other in FY2019 from FY2018? Success: 0.0
# << (1-1)/1 || [1.0, 1.0, 0.0] || [1.0, 1.0, 1.0] || True >>
# 0f782fc4163163785b2e178515809eaf
# What was the change in the Expected volatility from 2017 to 2018? Success: -1.82
# << 25.37 - 27.19 || [27.19, 25.37, -1.8200000000000003] || [25.37, 27.19] || True >>
# 337883b1c9a3f437f0667434c832a52e
# What was the change in Weighted average grant date stock price from 2017 to 2018? Success: 11.27
# << 65 - 53.73 || [53.73, 65.0, 11.270000000000003] || [65.0, 53.73] || True >>
# ba05732dd03e71da5b0e02ba9b16447d
# What was the change in the amount of surcharge revenue from 2018 to 2019? Success: 72.7
# << 438.1-365.4 || [438.1, 365.4, 72.70000000000005] || [438.1, 365.4] || True >>
# *** Overall EM:  0.7195121951219512 / 90
# e395e9f47dbe3fd712e7ab4f42fe0eec
# What was the percentage change in the amount of surcharge revenue from 2018 to 2019? Success: 19.9
# << ((438.1-365.4)/365.4) * 100 || [438.1, 365.4, 19.896004378763013] || [438.1, 365.4, 365.4] || True >>
# *** Overall EM:  0.7228915662650602 / 90
# 844c4d74af9231f62c7c193d54c0549e
# What is the average sales and marketing expenses for 2018 and 2019? Success: 411455.0
# << (472,841+350,069)/2 || [472841.0, 350069.0, 411455.0] || [472841.0, 350069.0] || True >>
# 9d8a4bd1a58a100ae2c3fd8b605a490b
# What is the difference between the Ending balance of unrecognized tax benefits of 2019 against 2017? Success: 176.0
# << 390.3-214.3 || [390.3, 214.3, 176.0] || [390.3, 214.3] || True >>
# *** Overall EM:  0.7294117647058823 / 260
# 2a7951420ed77b8b40366a4d53a2f5d3
# What is the Beginning balance of unrecognized tax benefits expressed as a percentage of Ending balance of unrecognized tax benefits for 2019? Success: 91.31
# << (356.4/390.3) * 100 || [356.4, 390.3, 91.31437355880091] || [356.4, 390.3] || True >>
# *** Overall EM:  0.7325581395348837 / 260
# 557c1e6b072d90960071e39e584e404e
# What is the average annual Ending balance of unrecognized tax benefits?  Success: 320.33
# << (390.3+356.4+214.3)/3 || [320.3333333333333] || [390.3, 356.4, 214.3] || False >>
# *** Overall EM:  0.735632183908046 / 260
# e2164a95603660da8e3b21396f51c71d
# What was the change in the amount of Accruals? Success: 6.1
# << 49.3-43.2 || [49.3, 43.2, 6.099999999999994] || [49.3, 43.2] || True >>
# 44caa96068a5c3f6e3584d1b363568f9
# What was the percentage change in the amount of Accruals? Success: 14.12
# << ((49.3-43.2)/43.2) * 100 || [49.3, 43.2, 14.120370370370356] || [49.3, 43.2, 43.2] || True >>
# 922ce7104fc57e4abeefb7ece1532a8f
# What was the percentage change in interest expense from 2018 to 2019? Success: -50.6
# << ((53,353 - 108,011)/108,011 ) * 100 || [-108011.0, -53353.0, -50.6041051374397] || [] || True >>
# 1770204294.6754823 0.34327220916748047
# cnt: 91

# %%
annotated_results = cga_utils.annotate_results(res)
#annotated_results.to_csv('res/Ollama_2_gemma3n_e4b_code_values_v11_m1.csv')
cga_utils.calc_overall_em(annotated_results)
# Out:
# 0.7362637362637363

# %%
import pandas as pd
messages = prompt_versions.prompt_versions['V29'] #Best alg
#messages = [(a, t.replace('/no_think','')) for (a,t)  in messages]
#messages[-1] = ( messages[-1][0],  messages[-1][1] + "/no_think" ) 

res = cga_utils.execute_dataset_predictions(llm, messages, dataset=sample_df)
# Out:
# 1770165553.0563605
# 0it [00:00, ?it/s]
# 7e2290f656cbeef6d9a61c02767b752c
# What was the percentage change in adjusted EBITDA between 2018 and 2019? failure: 16.36 good answer:  16.36
# << ((108,307-93,081)/93,081) * 100 || [108307.0, 93081.0, 16.357795898196194] || [108307.0, 93081.0, 93081.0, 100.0] || False >>
# *** Overall EM:  1.0 / 30
# d2fca279eeba2f76f54127d5884fc542
# What is the change in revenue growth between 2019 and 2018? Success: -4.3999999999999995
# << ((7.2%-11.6%)) * 100 || [7.2, 11.6, -4.3999999999999995] || [7.2, 11.6] || True >>
# 15c13aff533786d03238eb3e6f433c1f
# What are leasehold improvements in 2019 as a percentage of the total property equipment before depreciation, amortization and fixed assets not in service? Success: 18.13
# << ((3,522/79,828)) * 100 || [3522.0, 29920.0, 10493.0, 19427.0, 18.12940752560869] || [3522.0, 79828.0] || False >>
# *** Overall EM:  0.6666666666666666 / 220
# a232d237c226f8bcfdabfd8daad919fc
# What was the change in Property and equipment, net in 2018 from 2017? Success: -3991.0
# << -$9,401-(-$5,410) || [-9401.0, -5410.0, -3991.0] || [] || True >>
# 60fc4cb62e02f1bc47519bc34b2cd6b1
# What was the percentage change in Property and equipment, net in 2018 from 2017? Success: 73.77
# << ((-$9,401-(-$5,410))/-$5,410) * 100 || [-9401.0, -5410.0, 73.77079482439926] || [] || True >>
# a30c0da091bbd33f665ab11a25117074
# What was the percentage change in Interest expense between 2015 and 2016? Success: 20.3
# << ((717-596)/596) * 100 || [596.0, 717.0, 20.302013422818792] || [717.0, 596.0, 596.0] || True >>
# eeef320a4199b74356c5e18e58c33fb4
# What was the average Research and development expense for 2018 and 2019? Success: 45664.5
# << (50,024 + 41,305) / 2 || [50024.0, 41305.0, 45664.5] || [50024.0, 41305.0] || True >>
# 36453309f798d54fba67e60cac4490e2
# What is the change in the % of revenue from 2018 to 2019? Success: -3.0
# << 25 - 28 || [-3.0] || [25.0, 28.0] || False >>
# 7645f09642d6f2db485e05ac58013f26
# What is the change of expenses for facilities from fiscal year 2017 to 2019?  Success: 3059.0
# << 7,834-4,775 || [7834.0, -4775.0, 3059.0] || [7834.0] || True >>
# a23b3dcb820703a1d9aea7dc33091afb
# What is the difference between the Change between Fiscal increase for 2019 and 2018 and 2018 and 2017 for Payroll and payroll-related benefits? Success: -26490.0
# << 39,119-12,629 || [12629.0, 39119.0, -26490.0] || [39119.0, 12629.0] || True >>
# 6d046c35f507c818158760c49dae5e23
# What is the Total change in research and development expenses from 2017 to 2019? Success: 40621.0
# << 41,694-1,073 || [41694.0, -1073.0, 40621.0] || [41694.0] || True >>
# 640faac1ccb705ef422bfaa0f72e84f1
# What was the percentage change in Dividend and interest income in 2018 from 2017? Success: 50.47
# << ((635-422)/422) * 100 || [635.0, 422.0, 50.4739336492891] || [635.0, 422.0, 422.0] || True >>
# 50d6a01be8a0986d1b43bdb3a32e3446
# What was the change in the Loss from discontinued operations from 2017 to 2018? Success: -60921.0
# << -72,836 - (-11,915) || [-11915.0, -72836.0, -60921.0] || [] || True >>
# 679f03324e62ac16d07bc3e09c8e2376
# What is the average Gain on sale of Netsmart between 2017-2019? Success: 166823.67
# << (0 + 500,471 + 0) / 3 || [166823.66666666666] || [0.0, 500471.0, 0.0] || False >>
# 0cc2a888dd2540ce9991a759eb85bbaf
# What was the average Income tax effect on discontinued operations between 2017-2019? Success: 3255.33
# << (0 - 32,497 + 42,263) / 3 || [3255.3333333333335] || [0.0, 42263.0] || False >>
# 56d9aa6afc1e09a1727aacc4c0435d45
# What was the 2019 percentage change in accrued revenue? Success: 377.63
# << ((27,817 - 5,824) / 5,824 ) * 100 || [27817.0, 5824.0, 377.62706043956047] || [27817.0, 5824.0, 5824.0] || True >>
# 247b29ff672119850a618a5e59edf29e
# What was the average accrued revenue between 2018 and 2019? Success: 16820.5
# << (27,817 + 5,824) / 2  || [27817.0, 5824.0, 16820.5] || [27817.0, 5824.0] || True >>
# 6f1652507bcbc0845aa582d579321209
# How much was the difference in unearned revenue and accrued revenue in 2019? Success: -748.0
# << 27,817 - 27,069  || [27817.0, 27069.0, -748.0] || [27817.0, 27069.0] || True >>
# 0360296840de0645325b8cb6306101ff
# What is the net value of the unrealized gains and losses of the company's municipal bonds? Success: -97.0
# << 13 + (110)  || [13.0, -110.0, -97.0] || [13.0] || True >>
# 8039ea4c8f281b490be3e64dd7aef8e7
# What is the value of the amortized costs of  the municipal bonds as a percentage of the total amortized cost? Success: 24.01
# << (44,802/93,301 ) * 100 || [44802.0, 186602.0, 24.0093889668921] || [44802.0, 93301.0] || False >>
# afe196e1ac486bdab48cad41046bcf08
# What is the value of the amortized costs of  the corporate bonds as a percentage of the total amortized cost? Success: 51.98
# << (48,499/93,301 ) * 100 || [48499.0, 93301.0, 51.98122206621579] || [48499.0, 93301.0] || True >>
# 9c0a92f33095574b70f992e3ac68715a
# What is the total amount of all other compensation by all the directors in the table? Success: 41386.0
# << $4,000+$17,000+$15,950+$4,436 || [41386.0] || [4000.0, 17000.0, 15950.0, 4436.0] || False >>
# *** Overall EM:  0.8181818181818182 / 230
# 87192af423506160cd1df8fc628706e4
# What is the average amount of total compensation for each non-returning director? Success: 330267.33
# << ($259,472+$471,422+$259,908)/3 || [330267.3333333333] || [259472.0, 471422.0, 259908.0] || False >>
# *** Overall EM:  0.8260869565217391 / 230
# ffe60dd9dae69ba85ea4fae7ee10ebae
# What is the increase/ (decrease) in Wireless devices and accessories from 2018 to 2019? Success: -19.0
# << 380-399 || [380.0, 399.0, -19.0] || [380.0, 399.0] || True >>
# 80f4540b447fc62c20f332f34250dc94
# What is the increase/ (decrease) in Other finished goods and merchandise from 2018 to 2019? Success: 13.0
# << 80-67 || [80.0, 67.0, 13.0] || [80.0, 67.0] || True >>
# b9052616463aee5ec89dd6da25bc73a2
# What is the increase/ (decrease) in Total inventories from 2018 to 2019? Success: -6.0
# << 460-466 || [460.0, 466.0, -6.0] || [460.0, 466.0] || True >>
# cf42ab5eb0e02d2fa26ecbd6f525fb13
# What was the percentage change in the the total net property, plant and equipment between 2018 and 2019? Success: 5.67
# << ((105,038-99,401)/99,401) * 100 || [105038.0, 99401.0, 5.670969104938582] || [105038.0, 99401.0, 99401.0] || True >>
# 12c96773a28e7443eb18764411eaef50
# What is the percentage change in capitalized interest in 2019? Success: -11.76
# << ((45-51)/51) * 100 || [45.0, 51.0, -11.76470588235294] || [45.0, 51.0, 51.0] || True >>
# 2e7d0e6099ef5431e0ce2ca15d0cc9d9
# What is the company's total operating lease obligations between 2020 to 2022? Success: 55746.0
# << 19,373 + 36,373  || [55746.0] || [19373.0, 36373.0] || False >>
# 75022367778142d287da9236724aad8d
# What is the percentage constitution of purchase obligations among the total contractual obligations in 2020? Success: 54.0
# << (24,800/45,927) * 100 || [24800.0, 45927.0, 53.99873712630914] || [24800.0, 45927.0] || True >>
# 5b8b422ea976902a5f10dbb8bb17179e
# What is the value of the company's 2023-2024 purchase obligations as a percentage of its total payment due in the 2023-2024 period? Success: 2.18
# << (438/20,121 ) * 100 || [438.0, 20121.0, 2.1768301774265693] || [438.0, 20121.0] || True >>
# 76fcf6b0bf227d2e506aee1910f497cf
# What is the difference in the total franchise revenues between 2018 and 2019? Success: 191668.0
# << $613,300 - $421,632  || [613300.0, 421632.0, 191668.0] || [613300.0, 421632.0] || True >>
# *** Overall EM:  0.875 / 60
# 23fe1be9117b398035a9ead824b331a8
# What is the average in total franchise costs for 2018 and 2019? Success: 263349.5
# << ($356,787 + $169,912)/2  || [169912.0, 356787.0, 263349.5] || [356787.0, 169912.0] || True >>
# *** Overall EM:  0.8787878787878788 / 60
# dca2866a67dde74f8acfb646e68e7592
# What is the percentage constitution of franchise rental revenues among the total franchise revenues in 2019? Success: 44.48
# << ($272,815/$613,300 ) * 100 || [272815.0, 613300.0, 44.483124082830585] || [272815.0, 613300.0] || True >>
# *** Overall EM:  0.8823529411764706 / 60
# 40acacac7f638d5cfdff96a4b1c0995d
# What is the average year-on-year change in Weighted average grant date fair value from 2017 to 2019?  Success: 15.77
# << (((4.72-3.36)/3.36+(3.36-3.69)/3.69)/2) * 100 || [-8.943089430894311, 40.476190476190474, 15.766550522648082] || [4.72, 3.36, 3.36, 3.36, 3.69, 3.69] || False >>
# f7e00028b6447875f8005ab8c18639a4
# What was the percentage increase / (decrease) in Weighted average grant date fair value from 2018 to 2019? Success: 40.48
# << (4.72 / 3.36 - 1) * 100 || [3.36, 4.72, 40.476190476190474] || [4.72, 3.36] || True >>
# 586b24199ab25b1747ae3573492f1ccb
# What was the increase / (decrease) in the Weighted average grant date fair value from 2018 to 2019? Success: 1.36
# << 4.72 - 3.36 || [4.72, 3.36, 1.3599999999999999] || [4.72, 3.36] || True >>
# 75e012945b2e63911c3bc4376b042c0d
# What is the percentage change in the net operating loss carry forward from 2018 to 2019? Success: 8.45
# << ((27,907 - 25,733)/25,733 ) * 100 || [25733.0, 27907.0, 8.448295962382932] || [27907.0, 25733.0, 25733.0] || True >>
# 128c698b8fad151bf8516c2d51f1760b
# What is the change in Reserves and accruals between 2018 and 2019? Success: 17.0
# << 62 - 45  || [45.0, 62.0, 17.0] || [62.0, 45.0] || True >>
# 90fe2b41c9523249f82744554c978991
# What was the percentage change in Total cash, cash equivalents and restricted cash between 2018 and 2019? Success: 20.93
# << (($1,578.0-$1,304.9)/$1,304.9) * 100 || [1304.9, 1578.0, 20.92880680511916] || [1578.0, 1304.9, 1304.9] || True >>
# b2d5e2512b0988dd701480c344fb82bf
# What is the change in Item reclassified from freehold investment property from 2018 to 2019? Success: -2332.0
# << 2,068-4,400 || [4400.0, 2068.0, -2332.0] || [2068.0, 4400.0] || True >>
# 03b8194d47511d07e1e1aa58aa721957
# What is the change in Disposals during the year from 2018 to 2019? Success: 3439.0
# << 961-4,400 || [-4400.0, -961.0, 3439.0] || [4400.0] || False >>
# 4478c71ff25482f914636301d4c2413a
# What is the change in Other intangible assets Amortisation 2018 to 2019? Success: 0.0
# << 1,107-5,713 || [] || [1107.0, 5713.0] || False >>
# 715c9dd9b0dc4720ea3ba7ad4e436ee8
# What was the change in the amount for contracts within one year? Success: 2.8
# << 18.3-15.5 || [18.3, 15.5, 2.8000000000000007] || [18.3, 15.5] || True >>
# 25c53226518b6687085500e468d8cdfa
# What was the percentage change in the amount for contracts within one year? Success: 18.06
# << ((18.3-15.5)/15.5) * 100 || [18.3, 15.5, 18.064516129032263] || [18.3, 15.5, 15.5] || True >>
# 85c74755d4ccf8eb9167000284c818a9
# What is the revenue from Canada in 2019 as a percentage of the total revenue in 2019? Success: 1.35
# << ((9,815/363,800)) * 100 || [9815.0, 727600.0, 1.3489554700384827] || [9815.0, 363800.0] || False >>
# 276815a7f82a8c5eb1a4991d98fe253b
# What is the change in the number of IPTV retail subscribers in 2019? Success: -19314.0
# << 1,767,182-1,675,706 || [] || [1767182.0, 1675706.0] || False >>
# 34e05c377aa4cec6cc7ab6feedb0812c
# What is the percentage of Satellite subscribers out of the total retail subscribers in 2019? Success: -3.08
# << (1,005,282/2,772,464) * 100 || [-85423.0, 2772464.0, -3.081122063262138] || [1005282.0, 2772464.0] || False >>
# 587984b897fac513f24769a16342c523
# What is the percentage of IPTV subscribers out of the total retail subscribers in 2019? Success: 63.74
# << (1,767,182/2,772,464) * 100 || [1767182.0, 2772464.0, 63.740484998182126] || [1767182.0, 2772464.0] || True >>
# 653f0628622f8a654b56e21f1d58d1f8
# What is the change in Interest income from 2018 to 2019? Success: 27.0
# << 121-94 || [121.0, 94.0, 27.0] || [121.0, 94.0] || True >>
# e25f7d33f913085e05d33e04acedf950
# What is the change in Other components of net periodic benefit cost from 2018 to 2019? Success: -2441.0
# << 627-3,068 || [] || [627.0, 3068.0] || False >>
# 5c54743f6de457f4d0af525fc5ba37ed
# What is the change in Early debt extinguishment costs from 2018 to 2019? Success: -2879.0
# << 3,604-725 || [] || [] || True >>
# ab007d8a4c643492a9312c096956dffe
# What was the change in PSP payments for the Group in 2019 from 2018? Success: 0.3
# << 2.1-1.8 || [2.1, 1.8, 0.30000000000000004] || [2.1, 1.8] || True >>
# b78a785338a7b71fdc0668c0faf22fbe
# What was the percentage change in PSP payments for the Group in 2019 from 2018? Success: 16.67
# << ((2.1-1.8)/1.8) * 100 || [1.8, 2.1, 16.666666666666668] || [2.1, 1.8, 1.8] || True >>
# 25d2e81cd8e2d8ab81c5796d6e89c4ec
# What was the change in gross profit between May 2019 and August 2019? Success: 51279.0
# << 495,078-443,799 || [443799.0, 495078.0, 51279.0] || [495078.0, 443799.0] || True >>
# 8f23d52beaedf5e030daa78043e721cc
# What was the change in basic earnings per share attributable to the stockholders of Jabil Inc. between May 2019 and August 2019?[Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType'
# [Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType'
#  Success: [Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType'
# << $0.34-$0.28 || [] || [0.34, 0.28] || False >>
# 27f1a9c7a554b928ab4da0afb589b3f6
# What was the percentage change in net revenue between November 2018 and February 2019? Success: -6.75
# << (($6,066,990-$6,506,275)/$6,506,275) * 100 || [6506275.0, 6066990.0, -6.751712769595505] || [6066990.0, 6506275.0, 6506275.0] || True >>
# a4778f6baf7fbc47c36e2df4f39aff7e
# What was the change in the total compensation in 2019 from 2018? Success: 1.2
# << 9.0-7.8 || [9.0, 7.8, 1.2000000000000002] || [9.0, 7.8] || True >>
# fd96beba233f4b2ec8b7e5d2cf1c7aed
# What was the percentage change in the total compensation in 2019 from 2018? Success: 15.38
# << ((9.0-7.8)/7.8) * 100 || [9.0, 7.8, 15.384615384615389] || [9.0, 7.8, 7.8] || True >>
# c148020f43b4ba93d6dc65235e69e7cc
# What proportion of the total cost does the acquisition related cost form part of in 2019? Success: 0.12
# << ($1,696 / $14,290) * 100 || [14290.0, 1696.0, 0.11868439468159551] || [1696.0, 14290.0] || True >>
# 1d568952985d546e1035c7b8311c07cf
# What was the percentage change in non-current assets in Asia Pacific? Success: 68.18
# << ((7.4-4.4)/4.4) * 100 || [7.4, 4.4, 68.18181818181817] || [7.4, 4.4, 4.4] || True >>
# 11f94da9b4b3b0eb8e771898f7cb3b5c
# In 2019, what is the percentage constitution of nonvested stock units among the total share-based compensation expense? Success: 67.6
# << (5,458/8,074) * 100 || [5458.0, 8074.0, 67.59970274956652] || [5458.0, 8074.0] || True >>
# d82ccbf862bbea0c2a60bf0f08df9c5d
# What was the difference between the 2019 actual group cash generation compared with the 2019 target group cash generation? Success: 11.399999999999977
# << 296.4-285.0 || [296.4, 285.0, 11.399999999999977] || [296.4, 285.0] || True >>
# 3bff27eb2944cb199f863d6eb50bb06d
# What is the 2019 actual group operating profit expressed as a ratio of the 2019 target group operating profit? Success: 1.03
# << 277.3/270.3 || [277.3, 270.3, 1.0258971513133555] || [277.3, 270.3] || True >>
# 7d26ba6ef5c6202999c0593a1ec5c6d6
# What is the year-on-year change in VAS Business revenue? Success: -5.36
# << 199,991-176,646 || [53.0, 56.0, -5.357142857142857] || [199991.0, 176646.0] || False >>
# 929018fca125b27facecdc3b42edbe47
# What is the year-on-year change in FinTech and Business Services revenue? Success: 17.39
# << 101,355-73,138 || [27.0, 23.0, 17.391304347826086] || [101355.0, 73138.0] || False >>
# df27c6c6567c0b93f2a4b3702d885835
# What is the year-on-year change in Online Advertising Business revenue? Success: -5.26
# << 68,377-58,079 || [18.0, 19.0, -5.263157894736842] || [68377.0, 58079.0] || False >>
# b5572f9f8b64c1e860b7c4dcdcf272de
# What was the change in personnel expenses in 2018/2019 from 2017/2018? Success: 91.0
# << 2,816-2,725 || [2173.0, 2264.0, 91.0] || [2816.0, 2725.0] || False >>
# 2df5086d76d9cb82d007d208a95e03bf
# What was the percentage change in personnel expenses in 2018/2019 from 2017/2018? Success: 4.19
# << ((2,816-2,725)/2,725) * 100 || [2173.0, 2264.0, 4.187758858720662] || [2816.0, 2725.0, 2725.0] || False >>
# 4cc89377aa421d8d6eece5a7dce4de2d
# What is the average cash dividends declared per share for fiscal years 2017 to 2019?[Error]
# [Error]
#  Success: [Error]
# << (1.28+ 1.28+ 2.04)/3 || [] || [1.28, 1.28, 2.04] || False >>
# a070ac129ffad54615cd45118c9aea75
# What is the change in operating income between fiscal years 2019 and 2018? Success: 38294.0
# << 67,994-29,700 || [67994.0, 29700.0, 38294.0] || [67994.0, 29700.0] || True >>
# 27f6efd18696c43720f1ca2e94c0f7e5
# What is the average basic earnings per share for fiscal years 2017 to 2019?[Error]
# [Error]
#  Success: [Error]
# << (2.41+ 2.70+ 12.30)/3 || [] || [2.41, 2.7, 12.3] || False >>
# 2c0e0e756168b45e92978a151a7fb2ab
# What is the amount of total commission as a percentage of the Ceiling as per Section 198 of the Companies Act? Success: 108.98
# << (1,210.00/40,434.81 ) * 100 || [44064.81, 40434.81, 108.97741327336522] || [1210.0, 40434.81, 100.0] || False >>
# f0b2fe06c1b53072f911666f3c4fc564
# What is the amount of total Sitting Fees as a percentage of Total Managerial Remuneration? Success: 6.36
# << (33.60/1,243.60 ) * 100 || [2573.0, 40434.81, 6.363329022691093] || [33.6, 1243.6, 100.0] || False >>
# f585885778f95bf1dbb2a00151125624
# What was the change in revenue in Ireland in 2019 from 2018? Success: 0.0
# << 5.2-5.2 || [5.2, 5.2, 0.0] || [5.2, 5.2] || True >>
# acf5fdb8be289c36f97930c4fcf72942
# What was the percentage change in revenue in Ireland in 2019 from 2018? Success: 0.0
# << (5.2-5.2)/5.2 || [5.2, 5.2, 0.0] || [5.2, 5.2, 5.2] || True >>
# ee85b9ce062cb99f0861b9c43d6f6eed
# What is the ratio of Darcy Antonellis’ total compensation to David C. Habiger’s total compensation? Success: 0.93
# << 205,320/219,987  || [205320.0, 219987.0, 0.9333278784655457] || [205320.0, 219987.0] || True >>
# bf0f732e7286dad472c3a7a3848415a2
# What is the average fee earned or paid in cash compensation for all non-employee directors? Success: 77111.0
# << (106,000+55,333+70,000+81,000+68,333+82,000)/6  || [77111.0] || [106000.0, 55333.0, 70000.0, 81000.0, 68333.0, 82000.0] || False >>
# 48f4cafcd78061339d631d6490c055e0
# What was the change in Other in FY2019 from FY2018? Success: 0.0
# << 1-1 || [1.0, 1.0, 0.0] || [1.0, 1.0] || True >>
# 5bbcaeb1ebcedc949361aba4d6559771
# What was the percentage change in Other in FY2019 from FY2018? Success: 0.0
# << (1-1)/1 || [1.0, 1.0, 0.0] || [1.0, 1.0, 1.0] || True >>
# 0f782fc4163163785b2e178515809eaf
# What was the change in the Expected volatility from 2017 to 2018? Success: -1.82
# << 25.37 - 27.19 || [27.19, 25.37, -1.8200000000000003] || [25.37, 27.19] || True >>
# 337883b1c9a3f437f0667434c832a52e
# What was the change in Weighted average grant date stock price from 2017 to 2018? Success: 11.27
# << 65 - 53.73 || [53.73, 65.0, 11.270000000000003] || [65.0, 53.73] || True >>
# ba05732dd03e71da5b0e02ba9b16447d
# What was the change in the amount of surcharge revenue from 2018 to 2019? Success: 72.7
# << 438.1-365.4 || [438.1, 365.4, 72.70000000000005] || [438.1, 365.4] || True >>
# *** Overall EM:  0.7349397590361446 / 90
# e395e9f47dbe3fd712e7ab4f42fe0eec
# What was the percentage change in the amount of surcharge revenue from 2018 to 2019? Success: 19.9
# << ((438.1-365.4)/365.4) * 100 || [365.4, 438.1, 19.896004378763013] || [438.1, 365.4, 365.4] || True >>
# *** Overall EM:  0.7380952380952381 / 90
# 844c4d74af9231f62c7c193d54c0549e
# What is the average sales and marketing expenses for 2018 and 2019? Success: 411455.0
# << (472,841+350,069)/2 || [472841.0, 350069.0, 411455.0] || [472841.0, 350069.0] || True >>
# 9d8a4bd1a58a100ae2c3fd8b605a490b
# What is the difference between the Ending balance of unrecognized tax benefits of 2019 against 2017? Success: 176.0
# << 390.3-214.3 || [390.3, 214.3, 176.0] || [390.3, 214.3] || True >>
# *** Overall EM:  0.7441860465116279 / 260
# 2a7951420ed77b8b40366a4d53a2f5d3
# What is the Beginning balance of unrecognized tax benefits expressed as a percentage of Ending balance of unrecognized tax benefits for 2019? Success: 91.31
# << (356.4/390.3) * 100 || [356.4, 390.3, 91.31437355880091] || [356.4, 390.3] || True >>
# *** Overall EM:  0.7471264367816092 / 260
# 557c1e6b072d90960071e39e584e404e
# What is the average annual Ending balance of unrecognized tax benefits?  Success: 373.35
# << (390.3+356.4+214.3)/3 || [214.3, 373.35] || [390.3, 356.4, 214.3] || False >>
# *** Overall EM:  0.7386363636363636 / 260
# e2164a95603660da8e3b21396f51c71d
# What was the change in the amount of Accruals? Success: 6.1
# << 49.3-43.2 || [49.3, 43.2, 6.099999999999994] || [49.3, 43.2] || True >>
# 44caa96068a5c3f6e3584d1b363568f9
# What was the percentage change in the amount of Accruals? Success: 14.12
# << ((49.3-43.2)/43.2) * 100 || [49.3, 43.2, 14.120370370370356] || [49.3, 43.2, 43.2] || True >>
# 922ce7104fc57e4abeefb7ece1532a8f
# What was the percentage change in interest expense from 2018 to 2019? Success: -50.6
# << ((53,353 - 108,011)/108,011 ) * 100 || [-108011.0, -53353.0, -50.6041051374397] || [] || True >>
# 1770165697.9152544 144.85889387130737
# cnt: 91

# %%
annotated_results = cga_utils.annotate_results(res)
#annotated_results.to_csv('res/Ollama_2_gemma3n_e4b_code_values_v11_m1.csv')
cga_utils.calc_overall_em(annotated_results)
# Out:
# 0.7472527472527473

# %%
import pandas as pd
messages = prompt_versions.prompt_versions['V38b']
#messages = [(a, t.replace('/no_think','')) for (a,t)  in messages]
#messages[-1] = ( messages[-1][0],  messages[-1][1] + "/no_think" ) 

res = cga_utils.execute_dataset_predictions(llm, messages, dataset=sample_df)
# Out:
# 1770226816.8635337
# 0it [00:00, ?it/s]
# 7e2290f656cbeef6d9a61c02767b752c
# What was the percentage change in adjusted EBITDA between 2018 and 2019? failure: 16.36 good answer:  16.36
# << ((108,307-93,081)/93,081) * 100 || [108307.0, 93081.0, 16.357795898196194] || [108307.0, 93081.0, 93081.0, 100.0] || False >>
# *** Overall EM:  1.0 / 30
# d2fca279eeba2f76f54127d5884fc542
# What is the change in revenue growth between 2019 and 2018? Success: -4.3999999999999995
# << ((7.2%-11.6%)) * 100 || [7.2, 11.6, -4.3999999999999995] || [7.2, 11.6] || True >>
# 15c13aff533786d03238eb3e6f433c1f
# What are leasehold improvements in 2019 as a percentage of the total property equipment before depreciation, amortization and fixed assets not in service? Success: 2.97
# << ((3,522/79,828)) * 100 || [3522.0, 118455.0, 2.973280992782069] || [3522.0, 79828.0] || False >>
# *** Overall EM:  0.6666666666666666 / 220
# a232d237c226f8bcfdabfd8daad919fc
# What was the change in Property and equipment, net in 2018 from 2017? Success: -3991.0
# << -$9,401-(-$5,410) || [-9401.0, -5410.0, -3991.0] || [] || True >>
# 60fc4cb62e02f1bc47519bc34b2cd6b1
# What was the percentage change in Property and equipment, net in 2018 from 2017? Success: 73.77
# << ((-$9,401-(-$5,410))/-$5,410) * 100 || [-9401.0, -5410.0, 73.77079482439926] || [] || True >>
# a30c0da091bbd33f665ab11a25117074
# What was the percentage change in Interest expense between 2015 and 2016? Success: 20.3
# << ((717-596)/596) * 100 || [596.0, 717.0, 20.302013422818792] || [717.0, 596.0, 596.0] || True >>
# eeef320a4199b74356c5e18e58c33fb4
# What was the average Research and development expense for 2018 and 2019? Success: 45664.5
# << (50,024 + 41,305) / 2 || [50024.0, 41305.0, 45664.5] || [50024.0, 41305.0] || True >>
# 36453309f798d54fba67e60cac4490e2
# What is the change in the % of revenue from 2018 to 2019? Success: -3.0
# << 25 - 28 || [25.0, 28.0, -3.0] || [25.0, 28.0] || True >>
# 7645f09642d6f2db485e05ac58013f26
# What is the change of expenses for facilities from fiscal year 2017 to 2019?  Success: 3059.0
# << 7,834-4,775 || [7834.0, -4775.0, 3059.0] || [7834.0] || True >>
# a23b3dcb820703a1d9aea7dc33091afb
# What is the difference between the Change between Fiscal increase for 2019 and 2018 and 2018 and 2017 for Payroll and payroll-related benefits? Success: -26490.0
# << 39,119-12,629 || [12629.0, 39119.0, -26490.0] || [39119.0, 12629.0] || True >>
# 6d046c35f507c818158760c49dae5e23
# What is the Total change in research and development expenses from 2017 to 2019? Success: 40621.0
# << 41,694-1,073 || [-1073.0, 41694.0, 40621.0] || [41694.0] || True >>
# 640faac1ccb705ef422bfaa0f72e84f1
# What was the percentage change in Dividend and interest income in 2018 from 2017? Success: 50.47
# << ((635-422)/422) * 100 || [635.0, 422.0, 50.4739336492891] || [635.0, 422.0, 422.0] || True >>
# 50d6a01be8a0986d1b43bdb3a32e3446
# What was the change in the Loss from discontinued operations from 2017 to 2018? Success: -60921.0
# << -72,836 - (-11,915) || [-11915.0, -72836.0, -60921.0] || [] || True >>
# 679f03324e62ac16d07bc3e09c8e2376
# What is the average Gain on sale of Netsmart between 2017-2019? Success: 166823.67
# << (0 + 500,471 + 0) / 3 || [500471.0, 166823.66666666666] || [0.0, 500471.0, 0.0] || False >>
# 0cc2a888dd2540ce9991a759eb85bbaf
# What was the average Income tax effect on discontinued operations between 2017-2019? Success: 3255.3333333333335
# << (0 - 32,497 + 42,263) / 3 || [3255.3333333333335] || [0.0, 42263.0] || False >>
# 56d9aa6afc1e09a1727aacc4c0435d45
# What was the 2019 percentage change in accrued revenue? Success: 377.63
# << ((27,817 - 5,824) / 5,824 ) * 100 || [27817.0, 5824.0, 377.62706043956047] || [27817.0, 5824.0, 5824.0] || True >>
# 247b29ff672119850a618a5e59edf29e
# What was the average accrued revenue between 2018 and 2019? Success: 16820.5
# << (27,817 + 5,824) / 2  || [27817.0, 5824.0, 16820.5] || [27817.0, 5824.0] || True >>
# 6f1652507bcbc0845aa582d579321209
# How much was the difference in unearned revenue and accrued revenue in 2019? Success: -748.0
# << 27,817 - 27,069  || [27817.0, 27069.0, -748.0] || [27817.0, 27069.0] || True >>
# 0360296840de0645325b8cb6306101ff
# What is the net value of the unrealized gains and losses of the company's municipal bonds? Success: -97.0
# << 13 + (110)  || [13.0, -110.0, -97.0] || [13.0] || True >>
# 8039ea4c8f281b490be3e64dd7aef8e7
# What is the value of the amortized costs of  the municipal bonds as a percentage of the total amortized cost? Success: 24.01
# << (44,802/93,301 ) * 100 || [44802.0, 186602.0, 24.0093889668921] || [44802.0, 93301.0] || False >>
# afe196e1ac486bdab48cad41046bcf08
# What is the value of the amortized costs of  the corporate bonds as a percentage of the total amortized cost? Success: 25.99
# << (48,499/93,301 ) * 100 || [48499.0, 186602.0, 25.990611033107896] || [48499.0, 93301.0] || False >>
# 9c0a92f33095574b70f992e3ac68715a
# What is the total amount of all other compensation by all the directors in the table? Success: 41386.0
# << $4,000+$17,000+$15,950+$4,436 || [41386.0] || [4000.0, 17000.0, 15950.0, 4436.0] || False >>
# *** Overall EM:  0.7727272727272727 / 230
# 87192af423506160cd1df8fc628706e4
# What is the average amount of total compensation for each non-returning director? Success: 330267.33
# << ($259,472+$471,422+$259,908)/3 || [330267.3333333333] || [259472.0, 471422.0, 259908.0] || False >>
# *** Overall EM:  0.782608695652174 / 230
# ffe60dd9dae69ba85ea4fae7ee10ebae
# What is the increase/ (decrease) in Wireless devices and accessories from 2018 to 2019? Success: -19.0
# << 380-399 || [380.0, 399.0, -19.0] || [380.0, 399.0] || True >>
# 80f4540b447fc62c20f332f34250dc94
# What is the increase/ (decrease) in Other finished goods and merchandise from 2018 to 2019? Success: 13.0
# << 80-67 || [80.0, 67.0, 13.0] || [80.0, 67.0] || True >>
# b9052616463aee5ec89dd6da25bc73a2
# What is the increase/ (decrease) in Total inventories from 2018 to 2019? Success: -6.0
# << 460-466 || [460.0, 466.0, -6.0] || [460.0, 466.0] || True >>
# cf42ab5eb0e02d2fa26ecbd6f525fb13
# What was the percentage change in the the total net property, plant and equipment between 2018 and 2019? Success: 5.67
# << ((105,038-99,401)/99,401) * 100 || [105038.0, 99401.0, 5.670969104938582] || [105038.0, 99401.0, 99401.0] || True >>
# 12c96773a28e7443eb18764411eaef50
# What is the percentage change in capitalized interest in 2019? Success: -11.76
# << ((45-51)/51) * 100 || [45.0, 51.0, -11.76470588235294] || [45.0, 51.0, 51.0] || True >>
# 2e7d0e6099ef5431e0ce2ca15d0cc9d9
# What is the company's total operating lease obligations between 2020 to 2022? Success: 55746.0
# << 19,373 + 36,373  || [19373.0, 36373.0, 55746.0] || [19373.0, 36373.0] || True >>
# 75022367778142d287da9236724aad8d
# What is the percentage constitution of purchase obligations among the total contractual obligations in 2020? Success: 54.0
# << (24,800/45,927) * 100 || [24800.0, 45927.0, 53.99873712630914] || [24800.0, 45927.0] || True >>
# 5b8b422ea976902a5f10dbb8bb17179e
# What is the value of the company's 2023-2024 purchase obligations as a percentage of its total payment due in the 2023-2024 period? Success: 2.18
# << (438/20,121 ) * 100 || [438.0, 20121.0, 2.1768301774265693] || [438.0, 20121.0] || True >>
# 76fcf6b0bf227d2e506aee1910f497cf
# What is the difference in the total franchise revenues between 2018 and 2019? Success: 191668.0
# << $613,300 - $421,632  || [613300.0, 421632.0, 191668.0] || [613300.0, 421632.0] || True >>
# *** Overall EM:  0.84375 / 60
# 23fe1be9117b398035a9ead824b331a8
# What is the average in total franchise costs for 2018 and 2019? Success: 263349.5
# << ($356,787 + $169,912)/2  || [356787.0, 169912.0, 263349.5] || [356787.0, 169912.0] || True >>
# *** Overall EM:  0.8484848484848485 / 60
# dca2866a67dde74f8acfb646e68e7592
# What is the percentage constitution of franchise rental revenues among the total franchise revenues in 2019? Success: 44.48
# << ($272,815/$613,300 ) * 100 || [272815.0, 613300.0, 44.483124082830585] || [272815.0, 613300.0] || True >>
# *** Overall EM:  0.8529411764705882 / 60
# 40acacac7f638d5cfdff96a4b1c0995d
# What is the average year-on-year change in Weighted average grant date fair value from 2017 to 2019?  Success: 15.77
# << (((4.72-3.36)/3.36+(3.36-3.69)/3.69)/2) * 100 || [-8.943089430894311, 40.476190476190474, 15.766550522648082] || [4.72, 3.36, 3.36, 3.36, 3.69, 3.69] || False >>
# f7e00028b6447875f8005ab8c18639a4
# What was the percentage increase / (decrease) in Weighted average grant date fair value from 2018 to 2019? Success: 40.48
# << (4.72 / 3.36 - 1) * 100 || [3.36, 4.72, 40.476190476190474] || [4.72, 3.36] || True >>
# 586b24199ab25b1747ae3573492f1ccb
# What was the increase / (decrease) in the Weighted average grant date fair value from 2018 to 2019? Success: 1.36
# << 4.72 - 3.36 || [4.72, 3.36, 1.3599999999999999] || [4.72, 3.36] || True >>
# 75e012945b2e63911c3bc4376b042c0d
# What is the percentage change in the net operating loss carry forward from 2018 to 2019? Success: 8.45
# << ((27,907 - 25,733)/25,733 ) * 100 || [27907.0, 25733.0, 8.448295962382932] || [27907.0, 25733.0, 25733.0] || True >>
# 128c698b8fad151bf8516c2d51f1760b
# What is the change in Reserves and accruals between 2018 and 2019? Success: 17.0
# << 62 - 45  || [62.0, 45.0, 17.0] || [62.0, 45.0] || True >>
# 90fe2b41c9523249f82744554c978991
# What was the percentage change in Total cash, cash equivalents and restricted cash between 2018 and 2019? Success: 20.93
# << (($1,578.0-$1,304.9)/$1,304.9) * 100 || [1578.0, 1304.9, 20.92880680511916] || [1578.0, 1304.9, 1304.9] || True >>
# b2d5e2512b0988dd701480c344fb82bf
# What is the change in Item reclassified from freehold investment property from 2018 to 2019? Success: -2332.0
# << 2,068-4,400 || [4400.0, 2068.0, -2332.0] || [2068.0, 4400.0] || True >>
# 03b8194d47511d07e1e1aa58aa721957
# What is the change in Disposals during the year from 2018 to 2019? Success: 3439.0
# << 961-4,400 || [-4400.0, -961.0, 3439.0] || [4400.0] || False >>
# 4478c71ff25482f914636301d4c2413a
# What is the change in Other intangible assets Amortisation 2018 to 2019? Success: 0.0
# << 1,107-5,713 || [] || [1107.0, 5713.0] || False >>
# 715c9dd9b0dc4720ea3ba7ad4e436ee8
# What was the change in the amount for contracts within one year? Success: 2.8
# << 18.3-15.5 || [18.3, 15.5, 2.8000000000000007] || [18.3, 15.5] || True >>
# 25c53226518b6687085500e468d8cdfa
# What was the percentage change in the amount for contracts within one year? Success: 18.06
# << ((18.3-15.5)/15.5) * 100 || [18.3, 15.5, 18.064516129032263] || [18.3, 15.5, 15.5] || True >>
# 85c74755d4ccf8eb9167000284c818a9
# What is the revenue from Canada in 2019 as a percentage of the total revenue in 2019? Success: 1.35
# << ((9,815/363,800)) * 100 || [9815.0, 727600.0, 1.3489554700384827] || [9815.0, 363800.0] || False >>
# 276815a7f82a8c5eb1a4991d98fe253b
# What is the change in the number of IPTV retail subscribers in 2019? Success: -19314.0
# << 1,767,182-1,675,706 || [] || [1767182.0, 1675706.0] || False >>
# 34e05c377aa4cec6cc7ab6feedb0812c
# What is the percentage of Satellite subscribers out of the total retail subscribers in 2019? Success: -3.08
# << (1,005,282/2,772,464) * 100 || [-85423.0, 2772464.0, -3.081122063262138] || [1005282.0, 2772464.0] || False >>
# 587984b897fac513f24769a16342c523
# What is the percentage of IPTV subscribers out of the total retail subscribers in 2019? Success: 63.74
# << (1,767,182/2,772,464) * 100 || [1767182.0, 2772464.0, 63.740484998182126] || [1767182.0, 2772464.0] || True >>
# 653f0628622f8a654b56e21f1d58d1f8
# What is the change in Interest income from 2018 to 2019? Success: 27.0
# << 121-94 || [121.0, 94.0, 27.0] || [121.0, 94.0] || True >>
# e25f7d33f913085e05d33e04acedf950
# What is the change in Other components of net periodic benefit cost from 2018 to 2019? Success: -2441.0
# << 627-3,068 || [] || [627.0, 3068.0] || False >>
# 5c54743f6de457f4d0af525fc5ba37ed
# What is the change in Early debt extinguishment costs from 2018 to 2019? Success: -2879.0
# << 3,604-725 || [] || [] || True >>
# ab007d8a4c643492a9312c096956dffe
# What was the change in PSP payments for the Group in 2019 from 2018? Success: 0.3
# << 2.1-1.8 || [1.8, 2.1, 0.30000000000000004] || [2.1, 1.8] || True >>
# b78a785338a7b71fdc0668c0faf22fbe
# What was the percentage change in PSP payments for the Group in 2019 from 2018? Success: 16.67
# << ((2.1-1.8)/1.8) * 100 || [1.8, 2.1, 16.666666666666668] || [2.1, 1.8, 1.8] || True >>
# 25d2e81cd8e2d8ab81c5796d6e89c4ec
# What was the change in gross profit between May 2019 and August 2019? Success: 51279.0
# << 495,078-443,799 || [443799.0, 495078.0, 51279.0] || [495078.0, 443799.0] || True >>
# 8f23d52beaedf5e030daa78043e721cc
# What was the change in basic earnings per share attributable to the stockholders of Jabil Inc. between May 2019 and August 2019?[Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType'
# [Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType'
#  Success: [Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType'
# << $0.34-$0.28 || [] || [0.34, 0.28] || False >>
# 27f1a9c7a554b928ab4da0afb589b3f6
# What was the percentage change in net revenue between November 2018 and February 2019? Success: -6.75
# << (($6,066,990-$6,506,275)/$6,506,275) * 100 || [6506275.0, 6066990.0, -6.751712769595505] || [6066990.0, 6506275.0, 6506275.0] || True >>
# a4778f6baf7fbc47c36e2df4f39aff7e
# What was the change in the total compensation in 2019 from 2018? Success: 1.2
# << 9.0-7.8 || [9.0, 7.8, 1.2000000000000002] || [9.0, 7.8] || True >>
# fd96beba233f4b2ec8b7e5d2cf1c7aed
# What was the percentage change in the total compensation in 2019 from 2018? Success: 15.38
# << ((9.0-7.8)/7.8) * 100 || [9.0, 7.8, 15.384615384615389] || [9.0, 7.8, 7.8] || True >>
# c148020f43b4ba93d6dc65235e69e7cc
# What proportion of the total cost does the acquisition related cost form part of in 2019? Success: 0.12
# << ($1,696 / $14,290) * 100 || [14290.0, 1696.0, 0.11868439468159551] || [1696.0, 14290.0] || True >>
# 1d568952985d546e1035c7b8311c07cf
# What was the percentage change in non-current assets in Asia Pacific? Success: 68.18
# << ((7.4-4.4)/4.4) * 100 || [7.4, 4.4, 68.18181818181817] || [7.4, 4.4, 4.4] || True >>
# 11f94da9b4b3b0eb8e771898f7cb3b5c
# In 2019, what is the percentage constitution of nonvested stock units among the total share-based compensation expense? Success: 67.6
# << (5,458/8,074) * 100 || [5458.0, 8074.0, 67.59970274956652] || [5458.0, 8074.0] || True >>
# d82ccbf862bbea0c2a60bf0f08df9c5d
# What was the difference between the 2019 actual group cash generation compared with the 2019 target group cash generation? Success: 11.399999999999977
# << 296.4-285.0 || [296.4, 285.0, 11.399999999999977] || [296.4, 285.0] || True >>
# 3bff27eb2944cb199f863d6eb50bb06d
# What is the 2019 actual group operating profit expressed as a ratio of the 2019 target group operating profit? Success: 1.03
# << 277.3/270.3 || [277.3, 270.3, 1.0258971513133555] || [277.3, 270.3] || True >>
# 7d26ba6ef5c6202999c0593a1ec5c6d6
# What is the year-on-year change in VAS Business revenue? Success: -5.36
# << 199,991-176,646 || [53.0, 56.0, -5.357142857142857] || [199991.0, 176646.0] || False >>
# 929018fca125b27facecdc3b42edbe47
# What is the year-on-year change in FinTech and Business Services revenue? Success: 17.39
# << 101,355-73,138 || [27.0, 23.0, 17.391304347826086] || [101355.0, 73138.0] || False >>
# df27c6c6567c0b93f2a4b3702d885835
# What is the year-on-year change in Online Advertising Business revenue? Success: -5.26
# << 68,377-58,079 || [18.0, 19.0, -5.263157894736842] || [68377.0, 58079.0] || False >>
# b5572f9f8b64c1e860b7c4dcdcf272de
# What was the change in personnel expenses in 2018/2019 from 2017/2018? Success: 91.0
# << 2,816-2,725 || [2173.0, 2264.0, 91.0] || [2816.0, 2725.0] || False >>
# 2df5086d76d9cb82d007d208a95e03bf
# What was the percentage change in personnel expenses in 2018/2019 from 2017/2018? Success: 4.19
# << ((2,816-2,725)/2,725) * 100 || [2173.0, 2264.0, 4.187758858720662] || [2816.0, 2725.0, 2725.0] || False >>
# 4cc89377aa421d8d6eece5a7dce4de2d
# What is the average cash dividends declared per share for fiscal years 2017 to 2019?[Error]
# [Error]
#  Success: [Error]
# << (1.28+ 1.28+ 2.04)/3 || [] || [1.28, 1.28, 2.04] || False >>
# a070ac129ffad54615cd45118c9aea75
# What is the change in operating income between fiscal years 2019 and 2018? Success: 38294.0
# << 67,994-29,700 || [67994.0, 29700.0, 38294.0] || [67994.0, 29700.0] || True >>
# 27f6efd18696c43720f1ca2e94c0f7e5
# What is the average basic earnings per share for fiscal years 2017 to 2019?[Error]
# [Error]
#  Success: [Error]
# << (2.41+ 2.70+ 12.30)/3 || [] || [2.41, 2.7, 12.3] || False >>
# 2c0e0e756168b45e92978a151a7fb2ab
# What is the amount of total commission as a percentage of the Ceiling as per Section 198 of the Companies Act? Success: 0.0
# << (1,210.00/40,434.81 ) * 100 || [44064.81, 0] || [1210.0, 40434.81, 100.0] || False >>
# f0b2fe06c1b53072f911666f3c4fc564
# What is the amount of total Sitting Fees as a percentage of Total Managerial Remuneration? Success: 6.36
# << (33.60/1,243.60 ) * 100 || [2573.0, 40434.81, 6.363329022691093] || [33.6, 1243.6, 100.0] || False >>
# f585885778f95bf1dbb2a00151125624
# What was the change in revenue in Ireland in 2019 from 2018? Success: 0.0
# << 5.2-5.2 || [5.2, 5.2, 0.0] || [5.2, 5.2] || True >>
# acf5fdb8be289c36f97930c4fcf72942
# What was the percentage change in revenue in Ireland in 2019 from 2018? Success: 0.0
# << (5.2-5.2)/5.2 || [5.2, 5.2, 0.0] || [5.2, 5.2, 5.2] || True >>
# ee85b9ce062cb99f0861b9c43d6f6eed
# What is the ratio of Darcy Antonellis’ total compensation to David C. Habiger’s total compensation? Success: 0.93
# << 205,320/219,987  || [205320.0, 219987.0, 0.9333278784655457] || [205320.0, 219987.0] || True >>
# bf0f732e7286dad472c3a7a3848415a2
# What is the average fee earned or paid in cash compensation for all non-employee directors? Success: 81466.6
# << (106,000+55,333+70,000+81,000+68,333+82,000)/6  || [81466.6] || [106000.0, 55333.0, 70000.0, 81000.0, 68333.0, 82000.0] || False >>
# 48f4cafcd78061339d631d6490c055e0
# What was the change in Other in FY2019 from FY2018? Success: 0.0
# << 1-1 || [1.0, 1.0, 0.0] || [1.0, 1.0] || True >>
# 5bbcaeb1ebcedc949361aba4d6559771
# What was the percentage change in Other in FY2019 from FY2018? Success: 0.0
# << (1-1)/1 || [1.0, 1.0, 0.0] || [1.0, 1.0, 1.0] || True >>
# 0f782fc4163163785b2e178515809eaf
# What was the change in the Expected volatility from 2017 to 2018? Success: -1.82
# << 25.37 - 27.19 || [27.19, 25.37, -1.8200000000000003] || [25.37, 27.19] || True >>
# 337883b1c9a3f437f0667434c832a52e
# What was the change in Weighted average grant date stock price from 2017 to 2018? Success: 11.27
# << 65 - 53.73 || [53.73, 65.0, 11.270000000000003] || [65.0, 53.73] || True >>
# ba05732dd03e71da5b0e02ba9b16447d
# What was the change in the amount of surcharge revenue from 2018 to 2019? Success: 72.70000000000005
# << 438.1-365.4 || [438.1, 365.4, 72.70000000000005] || [438.1, 365.4] || True >>
# *** Overall EM:  0.6746987951807228 / 90
# e395e9f47dbe3fd712e7ab4f42fe0eec
# What was the percentage change in the amount of surcharge revenue from 2018 to 2019? Success: 19.9
# << ((438.1-365.4)/365.4) * 100 || [438.1, 365.4, 19.896004378763013] || [438.1, 365.4, 365.4] || True >>
# *** Overall EM:  0.6785714285714286 / 90
# 844c4d74af9231f62c7c193d54c0549e
# What is the average sales and marketing expenses for 2018 and 2019? Success: 411455.0
# << (472,841+350,069)/2 || [472841.0, 350069.0, 411455.0] || [472841.0, 350069.0] || True >>
# 9d8a4bd1a58a100ae2c3fd8b605a490b
# What is the difference between the Ending balance of unrecognized tax benefits of 2019 against 2017? Success: 176.0
# << 390.3-214.3 || [390.3, 214.3, 176.0] || [390.3, 214.3] || True >>
# *** Overall EM:  0.686046511627907 / 260
# 2a7951420ed77b8b40366a4d53a2f5d3
# What is the Beginning balance of unrecognized tax benefits expressed as a percentage of Ending balance of unrecognized tax benefits for 2019? Success: 91.31
# << (356.4/390.3) * 100 || [356.4, 390.3, 91.31437355880091] || [356.4, 390.3] || True >>
# *** Overall EM:  0.6781609195402298 / 260
# 557c1e6b072d90960071e39e584e404e
# What is the average annual Ending balance of unrecognized tax benefits?  Success: 320.33
# << (390.3+356.4+214.3)/3 || [320.3333333333333] || [390.3, 356.4, 214.3] || False >>
# *** Overall EM:  0.6818181818181818 / 260
# e2164a95603660da8e3b21396f51c71d
# What was the change in the amount of Accruals? Success: 6.1
# << 49.3-43.2 || [49.3, 43.2, 6.099999999999994] || [49.3, 43.2] || True >>
# 44caa96068a5c3f6e3584d1b363568f9
# What was the percentage change in the amount of Accruals? Success: 14.12
# << ((49.3-43.2)/43.2) * 100 || [49.3, 43.2, 14.120370370370356] || [49.3, 43.2, 43.2] || True >>
# 922ce7104fc57e4abeefb7ece1532a8f
# What was the percentage change in interest expense from 2018 to 2019? Success: -50.6
# << ((53,353 - 108,011)/108,011 ) * 100 || [-108011.0, -53353.0, -50.6041051374397] || [] || True >>
# 1770226817.200915 0.33738136291503906
# cnt: 91

# %%
annotated_results = cga_utils.annotate_results(res)
cga_utils.calc_overall_em(annotated_results)
# Out:
# 0.6923076923076923

# %%
import pandas as pd
messages = prompt_versions.prompt_versions['V23']
#messages = [(a, t.replace('/no_think','')) for (a,t)  in messages]
#messages[-1] = ( messages[-1][0],  messages[-1][1] + "/no_think" ) 

res = cga_utils.execute_dataset_predictions(llm, messages, dataset=sample_df)
# Out:
# 1770226917.6007342
# 0it [00:00, ?it/s]
# 7e2290f656cbeef6d9a61c02767b752c
# What was the percentage change in adjusted EBITDA between 2018 and 2019? failure: 16.36 good answer:  16.36
# << ((108,307-93,081)/93,081) * 100 || [108307.0, 93081.0, 16.357795898196194] || [108307.0, 93081.0, 93081.0, 100.0] || False >>
# *** Overall EM:  1.0 / 30
# d2fca279eeba2f76f54127d5884fc542
# What is the change in revenue growth between 2019 and 2018? Success: -4.3999999999999995
# << ((7.2%-11.6%)) * 100 || [7.2, 11.6, -4.3999999999999995] || [7.2, 11.6] || True >>
# 15c13aff533786d03238eb3e6f433c1f
# What are leasehold improvements in 2019 as a percentage of the total property equipment before depreciation, amortization and fixed assets not in service? Success: 3.26
# << ((3,522/79,828)) * 100 || [3522.0, 107962.0, 3.262258942961412] || [3522.0, 79828.0] || False >>
# *** Overall EM:  0.6666666666666666 / 220
# a232d237c226f8bcfdabfd8daad919fc
# What was the change in Property and equipment, net in 2018 from 2017? Success: -3991.0
# << -$9,401-(-$5,410) || [-9401.0, -5410.0, -3991.0] || [] || True >>
# 60fc4cb62e02f1bc47519bc34b2cd6b1
# What was the percentage change in Property and equipment, net in 2018 from 2017? Success: 73.77
# << ((-$9,401-(-$5,410))/-$5,410) * 100 || [-9401.0, -5410.0, 73.77079482439926] || [] || True >>
# a30c0da091bbd33f665ab11a25117074
# What was the percentage change in Interest expense between 2015 and 2016? Success: 20.3
# << ((717-596)/596) * 100 || [596.0, 717.0, 20.302013422818792] || [717.0, 596.0, 596.0] || True >>
# eeef320a4199b74356c5e18e58c33fb4
# What was the average Research and development expense for 2018 and 2019? Success: 45664.5
# << (50,024 + 41,305) / 2 || [50024.0, 41305.0, 45664.5] || [50024.0, 41305.0] || True >>
# 36453309f798d54fba67e60cac4490e2
# What is the change in the % of revenue from 2018 to 2019? Success: -10.71
# << 25 - 28 || [25.0, 28.0, -10.714285714285714] || [25.0, 28.0] || True >>
# 7645f09642d6f2db485e05ac58013f26
# What is the change of expenses for facilities from fiscal year 2017 to 2019?  Success: 3059.0
# << 7,834-4,775 || [7834.0, -4775.0, 3059.0] || [7834.0] || True >>
# a23b3dcb820703a1d9aea7dc33091afb
# What is the difference between the Change between Fiscal increase for 2019 and 2018 and 2018 and 2017 for Payroll and payroll-related benefits? Success: -26490.0
# << 39,119-12,629 || [12629.0, 39119.0, -26490.0] || [39119.0, 12629.0] || True >>
# 6d046c35f507c818158760c49dae5e23
# What is the Total change in research and development expenses from 2017 to 2019?[Error]name 'r_and_d_2017_to_2018' is not defined
# [Error]name 'r_and_d_2017_to_2018' is not defined
#  Success: [Error]name 'r_and_d_2017_to_2018' is not defined
# << 41,694-1,073 || [] || [41694.0] || False >>
# 640faac1ccb705ef422bfaa0f72e84f1
# What was the percentage change in Dividend and interest income in 2018 from 2017? Success: 50.47
# << ((635-422)/422) * 100 || [635.0, 422.0, 50.4739336492891] || [635.0, 422.0, 422.0] || True >>
# 50d6a01be8a0986d1b43bdb3a32e3446
# What was the change in the Loss from discontinued operations from 2017 to 2018? Success: -60921.0
# << -72,836 - (-11,915) || [-11915.0, -72836.0, -60921.0] || [] || True >>
# 679f03324e62ac16d07bc3e09c8e2376
# What is the average Gain on sale of Netsmart between 2017-2019? Success: 166823.67
# << (0 + 500,471 + 0) / 3 || [166823.66666666666] || [0.0, 500471.0, 0.0] || False >>
# 0cc2a888dd2540ce9991a759eb85bbaf
# What was the average Income tax effect on discontinued operations between 2017-2019? Success: 3255.33
# << (0 - 32,497 + 42,263) / 3 || [3255.3333333333335] || [0.0, 42263.0] || False >>
# 56d9aa6afc1e09a1727aacc4c0435d45
# What was the 2019 percentage change in accrued revenue? Success: 377.63
# << ((27,817 - 5,824) / 5,824 ) * 100 || [27817.0, 5824.0, 377.62706043956047] || [27817.0, 5824.0, 5824.0] || True >>
# 247b29ff672119850a618a5e59edf29e
# What was the average accrued revenue between 2018 and 2019? Success: 16820.5
# << (27,817 + 5,824) / 2  || [5824.0, 27817.0, 16820.5] || [27817.0, 5824.0] || True >>
# 6f1652507bcbc0845aa582d579321209
# How much was the difference in unearned revenue and accrued revenue in 2019? Success: -748.0
# << 27,817 - 27,069  || [27817.0, 27069.0, -748.0] || [27817.0, 27069.0] || True >>
# 0360296840de0645325b8cb6306101ff
# What is the net value of the unrealized gains and losses of the company's municipal bonds? Success: -97.0
# << 13 + (110)  || [13.0, -110.0, -97.0] || [13.0] || True >>
# 8039ea4c8f281b490be3e64dd7aef8e7
# What is the value of the amortized costs of  the municipal bonds as a percentage of the total amortized cost? Success: 24.01
# << (44,802/93,301 ) * 100 || [44802.0, 186602.0, 24.0093889668921] || [44802.0, 93301.0] || False >>
# afe196e1ac486bdab48cad41046bcf08
# What is the value of the amortized costs of  the corporate bonds as a percentage of the total amortized cost? Success: 25.99
# << (48,499/93,301 ) * 100 || [48499.0, 186602.0, 25.990611033107896] || [48499.0, 93301.0] || False >>
# 9c0a92f33095574b70f992e3ac68715a
# What is the total amount of all other compensation by all the directors in the table? Success: 41386.0
# << $4,000+$17,000+$15,950+$4,436 || [41386.0] || [4000.0, 17000.0, 15950.0, 4436.0] || False >>
# *** Overall EM:  0.6818181818181818 / 230
# 87192af423506160cd1df8fc628706e4
# What is the average amount of total compensation for each non-returning director? Success: 330267.33
# << ($259,472+$471,422+$259,908)/3 || [330267.3333333333] || [259472.0, 471422.0, 259908.0] || False >>
# *** Overall EM:  0.6956521739130435 / 230
# ffe60dd9dae69ba85ea4fae7ee10ebae
# What is the increase/ (decrease) in Wireless devices and accessories from 2018 to 2019? Success: -19.0
# << 380-399 || [380.0, 399.0, -19.0] || [380.0, 399.0] || True >>
# 80f4540b447fc62c20f332f34250dc94
# What is the increase/ (decrease) in Other finished goods and merchandise from 2018 to 2019? Success: 13.0
# << 80-67 || [80.0, 67.0, 13.0] || [80.0, 67.0] || True >>
# b9052616463aee5ec89dd6da25bc73a2
# What is the increase/ (decrease) in Total inventories from 2018 to 2019? Success: -6.0
# << 460-466 || [460.0, 466.0, -6.0] || [460.0, 466.0] || True >>
# cf42ab5eb0e02d2fa26ecbd6f525fb13
# What was the percentage change in the the total net property, plant and equipment between 2018 and 2019? Success: 5.67
# << ((105,038-99,401)/99,401) * 100 || [105038.0, 99401.0, 5.67] || [105038.0, 99401.0, 99401.0] || True >>
# 12c96773a28e7443eb18764411eaef50
# What is the percentage change in capitalized interest in 2019? Success: -11.76
# << ((45-51)/51) * 100 || [45.0, 51.0, -11.76] || [45.0, 51.0, 51.0] || True >>
# 2e7d0e6099ef5431e0ce2ca15d0cc9d9
# What is the company's total operating lease obligations between 2020 to 2022? Success: 55746.0
# << 19,373 + 36,373  || [55746.0] || [19373.0, 36373.0] || False >>
# 75022367778142d287da9236724aad8d
# What is the percentage constitution of purchase obligations among the total contractual obligations in 2020? Success: 21.05
# << (24,800/45,927) * 100 || [24800.0, 117807.0, 21.051380648009033] || [24800.0, 45927.0] || False >>
# 5b8b422ea976902a5f10dbb8bb17179e
# What is the value of the company's 2023-2024 purchase obligations as a percentage of its total payment due in the 2023-2024 period? Success: 2.18
# << (438/20,121 ) * 100 || [438.0, 20121.0, 2.1768301774265693] || [438.0, 20121.0] || True >>
# 76fcf6b0bf227d2e506aee1910f497cf
# What is the difference in the total franchise revenues between 2018 and 2019? Success: 191668.0
# << $613,300 - $421,632  || [613300.0, 421632.0, 191668.0] || [613300.0, 421632.0] || True >>
# *** Overall EM:  0.75 / 60
# 23fe1be9117b398035a9ead824b331a8
# What is the average in total franchise costs for 2018 and 2019? Success: 263349.5
# << ($356,787 + $169,912)/2  || [169912.0, 356787.0, 263349.5] || [356787.0, 169912.0] || True >>
# *** Overall EM:  0.7575757575757576 / 60
# dca2866a67dde74f8acfb646e68e7592
# What is the percentage constitution of franchise rental revenues among the total franchise revenues in 2019? Success: 44.48
# << ($272,815/$613,300 ) * 100 || [272815.0, 613300.0, 44.483124082830585] || [272815.0, 613300.0] || True >>
# *** Overall EM:  0.7647058823529411 / 60
# 40acacac7f638d5cfdff96a4b1c0995d
# What is the average year-on-year change in Weighted average grant date fair value from 2017 to 2019?  Success: -9.5
# << (((4.72-3.36)/3.36+(3.36-3.69)/3.69)/2) * 100 || [4.72, 3.36, 3.69, -28.8135593220339, 9.821428571428575, -9.496065375302663] || [4.72, 3.36, 3.36, 3.36, 3.69, 3.69] || True >>
# f7e00028b6447875f8005ab8c18639a4
# What was the percentage increase / (decrease) in Weighted average grant date fair value from 2018 to 2019? Success: 40.48
# << (4.72 / 3.36 - 1) * 100 || [3.36, 4.72, 40.476190476190474] || [4.72, 3.36] || True >>
# 586b24199ab25b1747ae3573492f1ccb
# What was the increase / (decrease) in the Weighted average grant date fair value from 2018 to 2019? Success: 1.36
# << 4.72 - 3.36 || [3.36, 4.72, 1.3599999999999999] || [4.72, 3.36] || True >>
# 75e012945b2e63911c3bc4376b042c0d
# What is the percentage change in the net operating loss carry forward from 2018 to 2019? Success: 8.45
# << ((27,907 - 25,733)/25,733 ) * 100 || [25733.0, 27907.0, 8.448295962382932] || [27907.0, 25733.0, 25733.0] || True >>
# 128c698b8fad151bf8516c2d51f1760b
# What is the change in Reserves and accruals between 2018 and 2019? Success: 17.0
# << 62 - 45  || [62.0, 45.0, 17.0] || [62.0, 45.0] || True >>
# 90fe2b41c9523249f82744554c978991
# What was the percentage change in Total cash, cash equivalents and restricted cash between 2018 and 2019? Success: 20.93
# << (($1,578.0-$1,304.9)/$1,304.9) * 100 || [1578.0, 1304.9, 20.93] || [1578.0, 1304.9, 1304.9] || True >>
# b2d5e2512b0988dd701480c344fb82bf
# What is the change in Item reclassified from freehold investment property from 2018 to 2019? Success: -2332.0
# << 2,068-4,400 || [4400.0, 2068.0, -2332.0] || [2068.0, 4400.0] || True >>
# 03b8194d47511d07e1e1aa58aa721957
# What is the change in Disposals during the year from 2018 to 2019? Success: 3439.0
# << 961-4,400 || [-4400.0, -961.0, 3439.0] || [4400.0] || False >>
# 4478c71ff25482f914636301d4c2413a
# What is the change in Other intangible assets Amortisation 2018 to 2019? Success: 0.0
# << 1,107-5,713 || [] || [1107.0, 5713.0] || False >>
# 715c9dd9b0dc4720ea3ba7ad4e436ee8
# What was the change in the amount for contracts within one year? Success: 2.8
# << 18.3-15.5 || [18.3, 15.5, 2.8000000000000007] || [18.3, 15.5] || True >>
# 25c53226518b6687085500e468d8cdfa
# What was the percentage change in the amount for contracts within one year? Success: 18.06
# << ((18.3-15.5)/15.5) * 100 || [18.3, 15.5, 18.064516129032263] || [18.3, 15.5, 15.5] || True >>
# 85c74755d4ccf8eb9167000284c818a9
# What is the revenue from Canada in 2019 as a percentage of the total revenue in 2019? Success: 1.35
# << ((9,815/363,800)) * 100 || [9815.0, 727600.0, 1.3489554700384827] || [9815.0, 363800.0] || False >>
# 276815a7f82a8c5eb1a4991d98fe253b
# What is the change in the number of IPTV retail subscribers in 2019? Success: -19314.0
# << 1,767,182-1,675,706 || [] || [1767182.0, 1675706.0] || False >>
# 34e05c377aa4cec6cc7ab6feedb0812c
# What is the percentage of Satellite subscribers out of the total retail subscribers in 2019? Success: -3.08
# << (1,005,282/2,772,464) * 100 || [-85423.0, 2772464.0, -3.081122063262138] || [1005282.0, 2772464.0] || False >>
# 587984b897fac513f24769a16342c523
# What is the percentage of IPTV subscribers out of the total retail subscribers in 2019? Success: 3.3
# << (1,767,182/2,772,464) * 100 || [91476.0, 2772464.0, 3.29944771149418] || [1767182.0, 2772464.0] || False >>
# 653f0628622f8a654b56e21f1d58d1f8
# What is the change in Interest income from 2018 to 2019? Success: 27.0
# << 121-94 || [121.0, 94.0, 121.0, 94.0, 27.0] || [121.0, 94.0] || True >>
# e25f7d33f913085e05d33e04acedf950
# What is the change in Other components of net periodic benefit cost from 2018 to 2019? Success: -2441.0
# << 627-3,068 || [] || [627.0, 3068.0] || False >>
# 5c54743f6de457f4d0af525fc5ba37ed
# What is the change in Early debt extinguishment costs from 2018 to 2019? Success: -2879.0
# << 3,604-725 || [-2879.0] || [] || True >>
# ab007d8a4c643492a9312c096956dffe
# What was the change in PSP payments for the Group in 2019 from 2018? Success: 0.3
# << 2.1-1.8 || [1.8, 2.1, 0.30000000000000004] || [2.1, 1.8] || True >>
# b78a785338a7b71fdc0668c0faf22fbe
# What was the percentage change in PSP payments for the Group in 2019 from 2018? Success: 16.67
# << ((2.1-1.8)/1.8) * 100 || [1.8, 2.1, 16.666666666666668] || [2.1, 1.8, 1.8] || True >>
# 25d2e81cd8e2d8ab81c5796d6e89c4ec
# What was the change in gross profit between May 2019 and August 2019? Success: 51279.0
# << 495,078-443,799 || [443799.0, 495078.0, 51279.0] || [495078.0, 443799.0] || True >>
# 8f23d52beaedf5e030daa78043e721cc
# What was the change in basic earnings per share attributable to the stockholders of Jabil Inc. between May 2019 and August 2019?[Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType'
# [Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType'
#  Success: [Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType'
# << $0.34-$0.28 || [] || [0.34, 0.28] || False >>
# 27f1a9c7a554b928ab4da0afb589b3f6
# What was the percentage change in net revenue between November 2018 and February 2019? Success: -6.75
# << (($6,066,990-$6,506,275)/$6,506,275) * 100 || [6506275.0, 6066990.0, -6.751712769595505] || [6066990.0, 6506275.0, 6506275.0] || True >>
# a4778f6baf7fbc47c36e2df4f39aff7e
# What was the change in the total compensation in 2019 from 2018? Success: 1.2
# << 9.0-7.8 || [9.0, 7.8, 1.2000000000000002] || [9.0, 7.8] || True >>
# fd96beba233f4b2ec8b7e5d2cf1c7aed
# What was the percentage change in the total compensation in 2019 from 2018? Success: 15.38
# << ((9.0-7.8)/7.8) * 100 || [9.0, 7.8, 15.384615384615389] || [9.0, 7.8, 7.8] || True >>
# c148020f43b4ba93d6dc65235e69e7cc
# What proportion of the total cost does the acquisition related cost form part of in 2019? Success: 11.87
# << ($1,696 / $14,290) * 100 || [14290.0, 1696.0, 11.86843946815955] || [1696.0, 14290.0] || True >>
# 1d568952985d546e1035c7b8311c07cf
# What was the percentage change in non-current assets in Asia Pacific? Success: 68.18
# << ((7.4-4.4)/4.4) * 100 || [7.4, 4.4, 68.18181818181817] || [7.4, 4.4, 4.4] || True >>
# 11f94da9b4b3b0eb8e771898f7cb3b5c
# In 2019, what is the percentage constitution of nonvested stock units among the total share-based compensation expense? Success: 67.6
# << (5,458/8,074) * 100 || [5458.0, 8074.0, 67.59970274956652] || [5458.0, 8074.0] || True >>
# d82ccbf862bbea0c2a60bf0f08df9c5d
# What was the difference between the 2019 actual group cash generation compared with the 2019 target group cash generation? Success: 11.399999999999977
# Invalid  £m
# << 296.4-285.0 || [296.4, 285.0, 11.399999999999977] || [296.4, 285.0] || True >>
# 3bff27eb2944cb199f863d6eb50bb06d
# What is the 2019 actual group operating profit expressed as a ratio of the 2019 target group operating profit? Success: 1.03
# << 277.3/270.3 || [277.3, 270.3, 1.0258971513133555] || [277.3, 270.3] || True >>
# 7d26ba6ef5c6202999c0593a1ec5c6d6
# What is the year-on-year change in VAS Business revenue? Success: -5.36
# << 199,991-176,646 || [53.0, 56.0, -5.357142857142857] || [199991.0, 176646.0] || False >>
# 929018fca125b27facecdc3b42edbe47
# What is the year-on-year change in FinTech and Business Services revenue? Success: 17.39
# << 101,355-73,138 || [27.0, 23.0, 17.391304347826086] || [101355.0, 73138.0] || False >>
# df27c6c6567c0b93f2a4b3702d885835
# What is the year-on-year change in Online Advertising Business revenue? Success: -5.26
# << 68,377-58,079 || [18.0, 19.0, -5.263157894736842] || [68377.0, 58079.0] || False >>
# b5572f9f8b64c1e860b7c4dcdcf272de
# What was the change in personnel expenses in 2018/2019 from 2017/2018? Success: 91.0
# << 2,816-2,725 || [2173.0, 2264.0, 91.0] || [2816.0, 2725.0] || False >>
# 2df5086d76d9cb82d007d208a95e03bf
# What was the percentage change in personnel expenses in 2018/2019 from 2017/2018? Success: 4.19
# << ((2,816-2,725)/2,725) * 100 || [2173.0, 2264.0, 4.187758858720662] || [2816.0, 2725.0, 2725.0] || False >>
# 4cc89377aa421d8d6eece5a7dce4de2d
# What is the average cash dividends declared per share for fiscal years 2017 to 2019? Success: 0.0
# << (1.28+ 1.28+ 2.04)/3 || [] || [1.28, 1.28, 2.04] || False >>
# a070ac129ffad54615cd45118c9aea75
# What is the change in operating income between fiscal years 2019 and 2018? Success: 38294.0
# << 67,994-29,700 || [67994.0, 29700.0, 38294.0] || [67994.0, 29700.0] || True >>
# 27f6efd18696c43720f1ca2e94c0f7e5
# What is the average basic earnings per share for fiscal years 2017 to 2019? Success: 0.0
# << (2.41+ 2.70+ 12.30)/3 || [] || [2.41, 2.7, 12.3] || False >>
# 2c0e0e756168b45e92978a151a7fb2ab
# What is the amount of total commission as a percentage of the Ceiling as per Section 198 of the Companies Act? Success: 0.0
# << (1,210.00/40,434.81 ) * 100 || [44064.81, 0] || [1210.0, 40434.81, 100.0] || False >>
# f0b2fe06c1b53072f911666f3c4fc564
# What is the amount of total Sitting Fees as a percentage of Total Managerial Remuneration? Success: 0.17
# << (33.60/1,243.60 ) * 100 || [67.20000000000002, 40434.81, 0.16619343580444676] || [33.6, 1243.6, 100.0] || False >>
# f585885778f95bf1dbb2a00151125624
# What was the change in revenue in Ireland in 2019 from 2018? Success: 0.0
# << 5.2-5.2 || [5.2, 5.2, 0.0] || [5.2, 5.2] || True >>
# acf5fdb8be289c36f97930c4fcf72942
# What was the percentage change in revenue in Ireland in 2019 from 2018? Success: 0.0
# << (5.2-5.2)/5.2 || [5.2, 5.2, 0.0] || [5.2, 5.2, 5.2] || True >>
# ee85b9ce062cb99f0861b9c43d6f6eed
# What is the ratio of Darcy Antonellis’ total compensation to David C. Habiger’s total compensation? Success: 0.93
# << 205,320/219,987  || [205320.0, 219987.0, 0.9333278784655457] || [205320.0, 219987.0] || True >>
# bf0f732e7286dad472c3a7a3848415a2
# What is the average fee earned or paid in cash compensation for all non-employee directors? Success: 77111.0
# << (106,000+55,333+70,000+81,000+68,333+82,000)/6  || [77111.0] || [106000.0, 55333.0, 70000.0, 81000.0, 68333.0, 82000.0] || False >>
# 48f4cafcd78061339d631d6490c055e0
# What was the change in Other in FY2019 from FY2018? Success: 0.0
# << 1-1 || [1.0, 1.0, 0.0] || [1.0, 1.0] || True >>
# 5bbcaeb1ebcedc949361aba4d6559771
# What was the percentage change in Other in FY2019 from FY2018? Success: 0.0
# << (1-1)/1 || [1.0, 1.0, 0.0] || [1.0, 1.0, 1.0] || True >>
# 0f782fc4163163785b2e178515809eaf
# What was the change in the Expected volatility from 2017 to 2018? Success: -6.69
# << 25.37 - 27.19 || [27.19, 25.37, -6.693637366678927] || [25.37, 27.19] || True >>
# 337883b1c9a3f437f0667434c832a52e
# What was the change in Weighted average grant date stock price from 2017 to 2018? Success: 20.98
# << 65 - 53.73 || [53.73, 65.0, 20.975246603387316] || [65.0, 53.73] || True >>
# ba05732dd03e71da5b0e02ba9b16447d
# What was the change in the amount of surcharge revenue from 2018 to 2019? Success: 72.70000000000005
# << 438.1-365.4 || [438.1, 365.4, 72.70000000000005] || [438.1, 365.4] || True >>
# *** Overall EM:  0.6626506024096386 / 90
# e395e9f47dbe3fd712e7ab4f42fe0eec
# What was the percentage change in the amount of surcharge revenue from 2018 to 2019? Success: 19.9
# << ((438.1-365.4)/365.4) * 100 || [365.4, 438.1, 19.896004378763013] || [438.1, 365.4, 365.4] || True >>
# *** Overall EM:  0.6666666666666666 / 90
# 844c4d74af9231f62c7c193d54c0549e
# What is the average sales and marketing expenses for 2018 and 2019? Success: 411455.0
# << (472,841+350,069)/2 || [472841.0, 350069.0, 411455.0] || [472841.0, 350069.0] || True >>
# 9d8a4bd1a58a100ae2c3fd8b605a490b
# What is the difference between the Ending balance of unrecognized tax benefits of 2019 against 2017? Success: 176.0
# << 390.3-214.3 || [390.3, 214.3, 176.0] || [390.3, 214.3] || True >>
# *** Overall EM:  0.6744186046511628 / 260
# 2a7951420ed77b8b40366a4d53a2f5d3
# What is the Beginning balance of unrecognized tax benefits expressed as a percentage of Ending balance of unrecognized tax benefits for 2019? Success: 91.31
# << (356.4/390.3) * 100 || [356.4, 390.3, 91.31437355880091] || [356.4, 390.3] || True >>
# *** Overall EM:  0.6781609195402298 / 260
# 557c1e6b072d90960071e39e584e404e
# What is the average annual Ending balance of unrecognized tax benefits?  Success: 320.33
# << (390.3+356.4+214.3)/3 || [320.3333333333333] || [390.3, 356.4, 214.3] || False >>
# *** Overall EM:  0.6818181818181818 / 260
# e2164a95603660da8e3b21396f51c71d
# What was the change in the amount of Accruals? Success: 6.1
# << 49.3-43.2 || [49.3, 43.2, 6.099999999999994] || [49.3, 43.2] || True >>
# 44caa96068a5c3f6e3584d1b363568f9
# What was the percentage change in the amount of Accruals? Success: 14.12
# << ((49.3-43.2)/43.2) * 100 || [49.3, 43.2, 14.120370370370356] || [49.3, 43.2, 43.2] || True >>
# 922ce7104fc57e4abeefb7ece1532a8f
# What was the percentage change in interest expense from 2018 to 2019? Success: -50.6
# << ((53,353 - 108,011)/108,011 ) * 100 || [-108011.0, -53353.0, -50.6041051374397] || [] || True >>
# 1770227061.2197812 143.6190469264984
# cnt: 91

# %%
annotated_results = cga_utils.annotate_results(res)
cga_utils.calc_overall_em(annotated_results)
# Out:
# 0.6923076923076923

# %%
import pandas as pd
messages = prompt_versions.prompt_versions['V41']
#messages = [(a, t.replace('/no_think','')) for (a,t)  in messages]
#messages[-1] = ( messages[-1][0],  messages[-1][1] + "/no_think" ) 

res = cga_utils.execute_dataset_predictions(llm, messages, dataset=sample_df)
# Out:
# 1770227061.2707314
# 0it [00:00, ?it/s]
# 7e2290f656cbeef6d9a61c02767b752c
# What was the percentage change in adjusted EBITDA between 2018 and 2019? failure: 16.36 good answer:  16.36
# << ((108,307-93,081)/93,081) * 100 || [108307.0, 93081.0, 16.357795898196194] || [108307.0, 93081.0, 93081.0, 100.0] || False >>
# *** Overall EM:  1.0 / 30
# d2fca279eeba2f76f54127d5884fc542
# What is the change in revenue growth between 2019 and 2018? Success: -4.4
# << ((7.2%-11.6%)) * 100 || [7.2, 11.6, -4.3999999999999995] || [7.2, 11.6] || True >>
# 15c13aff533786d03238eb3e6f433c1f
# What are leasehold improvements in 2019 as a percentage of the total property equipment before depreciation, amortization and fixed assets not in service? Success: 3.26
# << ((3,522/79,828)) * 100 || [3522.0, 107962.0, 3.262258942961412] || [3522.0, 79828.0] || False >>
# *** Overall EM:  0.6666666666666666 / 220
# a232d237c226f8bcfdabfd8daad919fc
# What was the change in Property and equipment, net in 2018 from 2017? Success: -3991.0
# << -$9,401-(-$5,410) || [-9401.0, -5410.0, -3991.0] || [] || True >>
# 60fc4cb62e02f1bc47519bc34b2cd6b1
# What was the percentage change in Property and equipment, net in 2018 from 2017? Success: 73.77
# << ((-$9,401-(-$5,410))/-$5,410) * 100 || [-9401.0, -5410.0, 73.77079482439926] || [] || True >>
# a30c0da091bbd33f665ab11a25117074
# What was the percentage change in Interest expense between 2015 and 2016? Success: 20.3
# << ((717-596)/596) * 100 || [596.0, 717.0, 20.302013422818792] || [717.0, 596.0, 596.0] || True >>
# eeef320a4199b74356c5e18e58c33fb4
# What was the average Research and development expense for 2018 and 2019? Success: 45664.5
# << (50,024 + 41,305) / 2 || [50024.0, 41305.0, 45664.5] || [50024.0, 41305.0] || True >>
# 36453309f798d54fba67e60cac4490e2
# What is the change in the % of revenue from 2018 to 2019? Success: -3.0
# << 25 - 28 || [28.0, 25.0, -3.0] || [25.0, 28.0] || True >>
# 7645f09642d6f2db485e05ac58013f26
# What is the change of expenses for facilities from fiscal year 2017 to 2019?  Success: 3059.0
# << 7,834-4,775 || [7834.0, -4775.0, 3059.0] || [7834.0] || True >>
# a23b3dcb820703a1d9aea7dc33091afb
# What is the difference between the Change between Fiscal increase for 2019 and 2018 and 2018 and 2017 for Payroll and payroll-related benefits? Success: -26490.0
# << 39,119-12,629 || [12629.0, 39119.0, -26490.0] || [39119.0, 12629.0] || True >>
# 6d046c35f507c818158760c49dae5e23
# What is the Total change in research and development expenses from 2017 to 2019? Success: 40621.0
# << 41,694-1,073 || [-1073.0, 41694.0, 40621.0] || [41694.0] || True >>
# 640faac1ccb705ef422bfaa0f72e84f1
# What was the percentage change in Dividend and interest income in 2018 from 2017? Success: 50.47
# << ((635-422)/422) * 100 || [635.0, 422.0, 50.4739336492891] || [635.0, 422.0, 422.0] || True >>
# 50d6a01be8a0986d1b43bdb3a32e3446
# What was the change in the Loss from discontinued operations from 2017 to 2018? Success: -60921.0
# << -72,836 - (-11,915) || [-11915.0, -72836.0, -60921.0] || [] || True >>
# 679f03324e62ac16d07bc3e09c8e2376
# What is the average Gain on sale of Netsmart between 2017-2019? Success: 166823.67
# << (0 + 500,471 + 0) / 3 || [166823.66666666666] || [0.0, 500471.0, 0.0] || False >>
# 0cc2a888dd2540ce9991a759eb85bbaf
# What was the average Income tax effect on discontinued operations between 2017-2019? Success: 3255.33
# << (0 - 32,497 + 42,263) / 3 || [3255.3333333333335] || [0.0, 42263.0] || False >>
# 56d9aa6afc1e09a1727aacc4c0435d45
# What was the 2019 percentage change in accrued revenue? Success: 377.63
# << ((27,817 - 5,824) / 5,824 ) * 100 || [27817.0, 5824.0, 377.62706043956047] || [27817.0, 5824.0, 5824.0] || True >>
# 247b29ff672119850a618a5e59edf29e
# What was the average accrued revenue between 2018 and 2019? Success: 16820.5
# << (27,817 + 5,824) / 2  || [5824.0, 27817.0, 16820.5] || [27817.0, 5824.0] || True >>
# 6f1652507bcbc0845aa582d579321209
# How much was the difference in unearned revenue and accrued revenue in 2019? Success: -748.0
# << 27,817 - 27,069  || [27817.0, 27069.0, -748.0] || [27817.0, 27069.0] || True >>
# 0360296840de0645325b8cb6306101ff
# What is the net value of the unrealized gains and losses of the company's municipal bonds? Success: -97.0
# << 13 + (110)  || [13.0, -110.0, -97.0] || [13.0] || True >>
# 8039ea4c8f281b490be3e64dd7aef8e7
# What is the value of the amortized costs of  the municipal bonds as a percentage of the total amortized cost? Success: 24.01
# << (44,802/93,301 ) * 100 || [44802.0, 186602.0, 24.0093889668921] || [44802.0, 93301.0] || False >>
# afe196e1ac486bdab48cad41046bcf08
# What is the value of the amortized costs of  the corporate bonds as a percentage of the total amortized cost? Success: 25.99
# << (48,499/93,301 ) * 100 || [48499.0, 186602.0, 25.990611033107896] || [48499.0, 93301.0] || False >>
# 9c0a92f33095574b70f992e3ac68715a
# What is the total amount of all other compensation by all the directors in the table? Success: 41386.0
# << $4,000+$17,000+$15,950+$4,436 || [41386.0] || [4000.0, 17000.0, 15950.0, 4436.0] || False >>
# *** Overall EM:  0.7727272727272727 / 230
# 87192af423506160cd1df8fc628706e4
# What is the average amount of total compensation for each non-returning director? Success: 330267.33
# << ($259,472+$471,422+$259,908)/3 || [330267.3333333333] || [259472.0, 471422.0, 259908.0] || False >>
# *** Overall EM:  0.782608695652174 / 230
# ffe60dd9dae69ba85ea4fae7ee10ebae
# What is the increase/ (decrease) in Wireless devices and accessories from 2018 to 2019? Success: -19.0
# << 380-399 || [380.0, 399.0, -19.0] || [380.0, 399.0] || True >>
# 80f4540b447fc62c20f332f34250dc94
# What is the increase/ (decrease) in Other finished goods and merchandise from 2018 to 2019? Success: 13.0
# << 80-67 || [80.0, 67.0, 13.0] || [80.0, 67.0] || True >>
# b9052616463aee5ec89dd6da25bc73a2
# What is the increase/ (decrease) in Total inventories from 2018 to 2019? Success: -6.0
# << 460-466 || [460.0, 466.0, -6.0] || [460.0, 466.0] || True >>
# cf42ab5eb0e02d2fa26ecbd6f525fb13
# What was the percentage change in the the total net property, plant and equipment between 2018 and 2019? Success: 5.67
# << ((105,038-99,401)/99,401) * 100 || [105038.0, 99401.0, 5.670969104938582] || [105038.0, 99401.0, 99401.0] || True >>
# 12c96773a28e7443eb18764411eaef50
# What is the percentage change in capitalized interest in 2019? Success: -11.76
# << ((45-51)/51) * 100 || [45.0, 51.0, -11.76470588235294] || [45.0, 51.0, 51.0] || True >>
# 2e7d0e6099ef5431e0ce2ca15d0cc9d9
# What is the company's total operating lease obligations between 2020 to 2022? Success: 55746.0
# << 19,373 + 36,373  || [55746.0] || [19373.0, 36373.0] || False >>
# 75022367778142d287da9236724aad8d
# What is the percentage constitution of purchase obligations among the total contractual obligations in 2020? Success: 54.0
# << (24,800/45,927) * 100 || [24800.0, 45927.0, 53.99873712630914] || [24800.0, 45927.0] || True >>
# 5b8b422ea976902a5f10dbb8bb17179e
# What is the value of the company's 2023-2024 purchase obligations as a percentage of its total payment due in the 2023-2024 period? Success: 2.18
# << (438/20,121 ) * 100 || [438.0, 20121.0, 2.1768301774265693] || [438.0, 20121.0] || True >>
# 76fcf6b0bf227d2e506aee1910f497cf
# What is the difference in the total franchise revenues between 2018 and 2019? Success: 191668.0
# << $613,300 - $421,632  || [613300.0, 421632.0, 191668.0] || [613300.0, 421632.0] || True >>
# *** Overall EM:  0.84375 / 60
# 23fe1be9117b398035a9ead824b331a8
# What is the average in total franchise costs for 2018 and 2019? Success: 263349.5
# << ($356,787 + $169,912)/2  || [169912.0, 356787.0, 263349.5] || [356787.0, 169912.0] || True >>
# *** Overall EM:  0.8484848484848485 / 60
# dca2866a67dde74f8acfb646e68e7592
# What is the percentage constitution of franchise rental revenues among the total franchise revenues in 2019? Success: 44.48
# << ($272,815/$613,300 ) * 100 || [272815.0, 613300.0, 44.483124082830585] || [272815.0, 613300.0] || True >>
# *** Overall EM:  0.8529411764705882 / 60
# 40acacac7f638d5cfdff96a4b1c0995d
# What is the average year-on-year change in Weighted average grant date fair value from 2017 to 2019?  Success: -9.5
# << (((4.72-3.36)/3.36+(3.36-3.69)/3.69)/2) * 100 || [4.72, 3.36, 3.69, -28.8135593220339, 9.821428571428575, -9.496065375302663] || [4.72, 3.36, 3.36, 3.36, 3.69, 3.69] || True >>
# f7e00028b6447875f8005ab8c18639a4
# What was the percentage increase / (decrease) in Weighted average grant date fair value from 2018 to 2019? Success: 40.48
# << (4.72 / 3.36 - 1) * 100 || [3.36, 4.72, 40.476190476190474] || [4.72, 3.36] || True >>
# 586b24199ab25b1747ae3573492f1ccb
# What was the increase / (decrease) in the Weighted average grant date fair value from 2018 to 2019? Success: 1.36
# << 4.72 - 3.36 || [3.36, 4.72, 1.3599999999999999] || [4.72, 3.36] || True >>
# 75e012945b2e63911c3bc4376b042c0d
# What is the percentage change in the net operating loss carry forward from 2018 to 2019? Success: 8.45
# << ((27,907 - 25,733)/25,733 ) * 100 || [25733.0, 27907.0, 8.448295962382932] || [27907.0, 25733.0, 25733.0] || True >>
# 128c698b8fad151bf8516c2d51f1760b
# What is the change in Reserves and accruals between 2018 and 2019? Success: 17.0
# << 62 - 45  || [62.0, 45.0, 17.0] || [62.0, 45.0] || True >>
# 90fe2b41c9523249f82744554c978991
# What was the percentage change in Total cash, cash equivalents and restricted cash between 2018 and 2019? Success: 20.93
# << (($1,578.0-$1,304.9)/$1,304.9) * 100 || [1578.0, 1304.9, 20.92880680511916] || [1578.0, 1304.9, 1304.9] || True >>
# b2d5e2512b0988dd701480c344fb82bf
# What is the change in Item reclassified from freehold investment property from 2018 to 2019? Success: -2332.0
# << 2,068-4,400 || [4400.0, 2068.0, -2332.0] || [2068.0, 4400.0] || True >>
# 03b8194d47511d07e1e1aa58aa721957
# What is the change in Disposals during the year from 2018 to 2019? Success: 3439.0
# << 961-4,400 || [-4400.0, -961.0, 3439.0] || [4400.0] || False >>
# 4478c71ff25482f914636301d4c2413a
# What is the change in Other intangible assets Amortisation 2018 to 2019? Success: 0.0
# << 1,107-5,713 || [] || [1107.0, 5713.0] || False >>
# 715c9dd9b0dc4720ea3ba7ad4e436ee8
# What was the change in the amount for contracts within one year? Success: 2.8
# << 18.3-15.5 || [18.3, 15.5, 2.8000000000000007] || [18.3, 15.5] || True >>
# 25c53226518b6687085500e468d8cdfa
# What was the percentage change in the amount for contracts within one year? Success: 18.06
# << ((18.3-15.5)/15.5) * 100 || [18.3, 15.5, 18.064516129032263] || [18.3, 15.5, 15.5] || True >>
# 85c74755d4ccf8eb9167000284c818a9
# What is the revenue from Canada in 2019 as a percentage of the total revenue in 2019? Success: 1.35
# << ((9,815/363,800)) * 100 || [9815.0, 727600.0, 1.3489554700384827] || [9815.0, 363800.0] || False >>
# 276815a7f82a8c5eb1a4991d98fe253b
# What is the change in the number of IPTV retail subscribers in 2019? Success: -19314.0
# << 1,767,182-1,675,706 || [] || [1767182.0, 1675706.0] || False >>
# 34e05c377aa4cec6cc7ab6feedb0812c
# What is the percentage of Satellite subscribers out of the total retail subscribers in 2019? Success: 36.26
# << (1,005,282/2,772,464) * 100 || [1005282.0, 2772464.0, 36.259515001817874] || [1005282.0, 2772464.0] || True >>
# 587984b897fac513f24769a16342c523
# What is the percentage of IPTV subscribers out of the total retail subscribers in 2019? Success: 63.74
# << (1,767,182/2,772,464) * 100 || [1767182.0, 2772464.0, 63.740484998182126] || [1767182.0, 2772464.0] || True >>
# 653f0628622f8a654b56e21f1d58d1f8
# What is the change in Interest income from 2018 to 2019? Success: 27.0
# << 121-94 || [121.0, 94.0, 27.0] || [121.0, 94.0] || True >>
# e25f7d33f913085e05d33e04acedf950
# What is the change in Other components of net periodic benefit cost from 2018 to 2019? Success: -2441.0
# << 627-3,068 || [] || [627.0, 3068.0] || False >>
# 5c54743f6de457f4d0af525fc5ba37ed
# What is the change in Early debt extinguishment costs from 2018 to 2019? Success: -2879.0
# << 3,604-725 || [-2879.0] || [] || True >>
# ab007d8a4c643492a9312c096956dffe
# What was the change in PSP payments for the Group in 2019 from 2018? Success: 0.3
# << 2.1-1.8 || [1.8, 2.1, 0.30000000000000004] || [2.1, 1.8] || True >>
# b78a785338a7b71fdc0668c0faf22fbe
# What was the percentage change in PSP payments for the Group in 2019 from 2018? Success: 16.67
# << ((2.1-1.8)/1.8) * 100 || [1.8, 2.1, 16.666666666666668] || [2.1, 1.8, 1.8] || True >>
# 25d2e81cd8e2d8ab81c5796d6e89c4ec
# What was the change in gross profit between May 2019 and August 2019? Success: 51279.0
# << 495,078-443,799 || [443799.0, 495078.0, 51279.0] || [495078.0, 443799.0] || True >>
# 8f23d52beaedf5e030daa78043e721cc
# What was the change in basic earnings per share attributable to the stockholders of Jabil Inc. between May 2019 and August 2019?[Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType'
# [Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType'
#  Success: [Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType'
# << $0.34-$0.28 || [] || [0.34, 0.28] || False >>
# 27f1a9c7a554b928ab4da0afb589b3f6
# What was the percentage change in net revenue between November 2018 and February 2019? Success: -6.75
# << (($6,066,990-$6,506,275)/$6,506,275) * 100 || [6506275.0, 6066990.0, -6.751712769595505] || [6066990.0, 6506275.0, 6506275.0] || True >>
# a4778f6baf7fbc47c36e2df4f39aff7e
# What was the change in the total compensation in 2019 from 2018? Success: 1.2
# << 9.0-7.8 || [9.0, 7.8, 1.2000000000000002] || [9.0, 7.8] || True >>
# fd96beba233f4b2ec8b7e5d2cf1c7aed
# What was the percentage change in the total compensation in 2019 from 2018? Success: 15.38
# << ((9.0-7.8)/7.8) * 100 || [9.0, 7.8, 15.384615384615389] || [9.0, 7.8, 7.8] || True >>
# c148020f43b4ba93d6dc65235e69e7cc
# What proportion of the total cost does the acquisition related cost form part of in 2019? Success: 11.87
# << ($1,696 / $14,290) * 100 || [14290.0, 1696.0, 11.86843946815955] || [1696.0, 14290.0] || True >>
# 1d568952985d546e1035c7b8311c07cf
# What was the percentage change in non-current assets in Asia Pacific? Success: 68.18
# << ((7.4-4.4)/4.4) * 100 || [7.4, 4.4, 68.18181818181817] || [7.4, 4.4, 4.4] || True >>
# 11f94da9b4b3b0eb8e771898f7cb3b5c
# In 2019, what is the percentage constitution of nonvested stock units among the total share-based compensation expense? Success: 67.6
# << (5,458/8,074) * 100 || [5458.0, 8074.0, 67.59970274956652] || [5458.0, 8074.0] || True >>
# d82ccbf862bbea0c2a60bf0f08df9c5d
# What was the difference between the 2019 actual group cash generation compared with the 2019 target group cash generation? Success: 11.399999999999977
# << 296.4-285.0 || [296.4, 285.0, 11.399999999999977] || [296.4, 285.0] || True >>
# 3bff27eb2944cb199f863d6eb50bb06d
# What is the 2019 actual group operating profit expressed as a ratio of the 2019 target group operating profit? Success: 1.03
# << 277.3/270.3 || [277.3, 270.3, 1.0258971513133555] || [277.3, 270.3] || True >>
# 7d26ba6ef5c6202999c0593a1ec5c6d6
# What is the year-on-year change in VAS Business revenue? Success: -5.36
# << 199,991-176,646 || [53.0, 56.0, -5.357142857142857] || [199991.0, 176646.0] || False >>
# 929018fca125b27facecdc3b42edbe47
# What is the year-on-year change in FinTech and Business Services revenue? Success: 17.39
# << 101,355-73,138 || [27.0, 23.0, 17.391304347826086] || [101355.0, 73138.0] || False >>
# df27c6c6567c0b93f2a4b3702d885835
# What is the year-on-year change in Online Advertising Business revenue? Success: -5.26
# << 68,377-58,079 || [18.0, 19.0, -5.263157894736842] || [68377.0, 58079.0] || False >>
# b5572f9f8b64c1e860b7c4dcdcf272de
# What was the change in personnel expenses in 2018/2019 from 2017/2018? Success: 91.0
# << 2,816-2,725 || [2173.0, 2264.0, 91.0] || [2816.0, 2725.0] || False >>
# 2df5086d76d9cb82d007d208a95e03bf
# What was the percentage change in personnel expenses in 2018/2019 from 2017/2018? Success: 4.19
# << ((2,816-2,725)/2,725) * 100 || [2173.0, 2264.0, 4.187758858720662] || [2816.0, 2725.0, 2725.0] || False >>
# 4cc89377aa421d8d6eece5a7dce4de2d
# What is the average cash dividends declared per share for fiscal years 2017 to 2019?[Error]
# [Error]
#  Success: [Error]
# << (1.28+ 1.28+ 2.04)/3 || [] || [1.28, 1.28, 2.04] || False >>
# a070ac129ffad54615cd45118c9aea75
# What is the change in operating income between fiscal years 2019 and 2018? Success: 38294.0
# << 67,994-29,700 || [67994.0, 29700.0, 38294.0] || [67994.0, 29700.0] || True >>
# 27f6efd18696c43720f1ca2e94c0f7e5
# What is the average basic earnings per share for fiscal years 2017 to 2019?[Error]division by zero
# [Error]division by zero
#  Success: [Error]division by zero
# << (2.41+ 2.70+ 12.30)/3 || [] || [2.41, 2.7, 12.3] || False >>
# 2c0e0e756168b45e92978a151a7fb2ab
# What is the amount of total commission as a percentage of the Ceiling as per Section 198 of the Companies Act? Success: 0.0
# << (1,210.00/40,434.81 ) * 100 || [40434.81, 0] || [1210.0, 40434.81, 100.0] || False >>
# f0b2fe06c1b53072f911666f3c4fc564
# What is the amount of total Sitting Fees as a percentage of Total Managerial Remuneration? Success: 0.25
# << (33.60/1,243.60 ) * 100 || [100.80000000000001, 40434.81, 0.2492901537066701] || [33.6, 1243.6, 100.0] || False >>
# f585885778f95bf1dbb2a00151125624
# What was the change in revenue in Ireland in 2019 from 2018? Success: 0.0
# << 5.2-5.2 || [5.2, 5.2, 0.0] || [5.2, 5.2] || True >>
# acf5fdb8be289c36f97930c4fcf72942
# What was the percentage change in revenue in Ireland in 2019 from 2018? Success: 0.0
# << (5.2-5.2)/5.2 || [5.2, 5.2, 0.0] || [5.2, 5.2, 5.2] || True >>
# ee85b9ce062cb99f0861b9c43d6f6eed
# What is the ratio of Darcy Antonellis’ total compensation to David C. Habiger’s total compensation? Success: 0.93
# << 205,320/219,987  || [205320.0, 219987.0, 0.9333278784655457] || [205320.0, 219987.0] || True >>
# bf0f732e7286dad472c3a7a3848415a2
# What is the average fee earned or paid in cash compensation for all non-employee directors? Success: 77111.0
# << (106,000+55,333+70,000+81,000+68,333+82,000)/6  || [77111.0] || [106000.0, 55333.0, 70000.0, 81000.0, 68333.0, 82000.0] || False >>
# 48f4cafcd78061339d631d6490c055e0
# What was the change in Other in FY2019 from FY2018? Success: 0.0
# << 1-1 || [1.0, 1.0, 0.0] || [1.0, 1.0] || True >>
# 5bbcaeb1ebcedc949361aba4d6559771
# What was the percentage change in Other in FY2019 from FY2018? Success: 0.0
# << (1-1)/1 || [1.0, 1.0, 0.0] || [1.0, 1.0, 1.0] || True >>
# 0f782fc4163163785b2e178515809eaf
# What was the change in the Expected volatility from 2017 to 2018? Success: -6.69
# << 25.37 - 27.19 || [27.19, 25.37, -6.693637366678927] || [25.37, 27.19] || True >>
# 337883b1c9a3f437f0667434c832a52e
# What was the change in Weighted average grant date stock price from 2017 to 2018? Success: 20.98
# << 65 - 53.73 || [53.73, 65.0, 20.975246603387316] || [65.0, 53.73] || True >>
# ba05732dd03e71da5b0e02ba9b16447d
# What was the change in the amount of surcharge revenue from 2018 to 2019? Success: 72.70000000000005
# << 438.1-365.4 || [438.1, 365.4, 72.70000000000005] || [438.1, 365.4] || True >>
# *** Overall EM:  0.7108433734939759 / 90
# e395e9f47dbe3fd712e7ab4f42fe0eec
# What was the percentage change in the amount of surcharge revenue from 2018 to 2019? Success: 19.9
# << ((438.1-365.4)/365.4) * 100 || [365.4, 438.1, 19.896004378763013] || [438.1, 365.4, 365.4] || True >>
# *** Overall EM:  0.7142857142857143 / 90
# 844c4d74af9231f62c7c193d54c0549e
# What is the average sales and marketing expenses for 2018 and 2019? Success: 411455.0
# << (472,841+350,069)/2 || [472841.0, 350069.0, 411455.0] || [472841.0, 350069.0] || True >>
# 9d8a4bd1a58a100ae2c3fd8b605a490b
# What is the difference between the Ending balance of unrecognized tax benefits of 2019 against 2017? Success: 176.0
# << 390.3-214.3 || [390.3, 214.3, 176.0] || [390.3, 214.3] || True >>
# *** Overall EM:  0.7209302325581395 / 260
# 2a7951420ed77b8b40366a4d53a2f5d3
# What is the Beginning balance of unrecognized tax benefits expressed as a percentage of Ending balance of unrecognized tax benefits for 2019? Success: 91.31
# << (356.4/390.3) * 100 || [356.4, 390.3, 91.31437355880091] || [356.4, 390.3] || True >>
# *** Overall EM:  0.7241379310344828 / 260
# 557c1e6b072d90960071e39e584e404e
# What is the average annual Ending balance of unrecognized tax benefits?  Success: 320.33
# << (390.3+356.4+214.3)/3 || [320.3333333333333] || [390.3, 356.4, 214.3] || False >>
# *** Overall EM:  0.7272727272727273 / 260
# e2164a95603660da8e3b21396f51c71d
# What was the change in the amount of Accruals? Success: 6.1
# << 49.3-43.2 || [49.3, 43.2, 6.099999999999994] || [49.3, 43.2] || True >>
# 44caa96068a5c3f6e3584d1b363568f9
# What was the percentage change in the amount of Accruals? Success: 14.12
# << ((49.3-43.2)/43.2) * 100 || [49.3, 43.2, 14.120370370370356] || [49.3, 43.2, 43.2] || True >>
# 922ce7104fc57e4abeefb7ece1532a8f
# What was the percentage change in interest expense from 2018 to 2019? Success: -50.6
# << ((53,353 - 108,011)/108,011 ) * 100 || [-108011.0, -53353.0, -50.6041051374397] || [] || True >>
# 1770227201.4700544 140.19932293891907
# cnt: 91

# %%
annotated_results = cga_utils.annotate_results(res)
cga_utils.calc_overall_em(annotated_results)
# Out:
# 0.7362637362637363

# %%
import pandas as pd
messages = prompt_versions.prompt_versions['V43c']
#messages = [(a, t.replace('/no_think','')) for (a,t)  in messages]
#messages[-1] = ( messages[-1][0],  messages[-1][1] + "/no_think" ) 

res = cga_utils.execute_dataset_predictions(llm, messages, dataset=sample_df)
# Out:
# 1770227201.5165617
# 0it [00:00, ?it/s]
# 7e2290f656cbeef6d9a61c02767b752c
# What was the percentage change in adjusted EBITDA between 2018 and 2019? failure: 16.36 good answer:  16.36
# << ((108,307-93,081)/93,081) * 100 || [108307.0, 93081.0, 16.357795898196194] || [108307.0, 93081.0, 93081.0, 100.0] || False >>
# *** Overall EM:  1.0 / 30
# d2fca279eeba2f76f54127d5884fc542
# What is the change in revenue growth between 2019 and 2018? Success: -4.3999999999999995
# << ((7.2%-11.6%)) * 100 || [7.2, 11.6, -4.3999999999999995] || [7.2, 11.6] || True >>
# 15c13aff533786d03238eb3e6f433c1f
# What are leasehold improvements in 2019 as a percentage of the total property equipment before depreciation, amortization and fixed assets not in service? Success: 11.77
# << ((3,522/79,828)) * 100 || [3522.0, 29920.0, 10493.0, 29920.0, 11.77139037433155] || [3522.0, 79828.0] || False >>
# *** Overall EM:  0.6666666666666666 / 220
# a232d237c226f8bcfdabfd8daad919fc
# What was the change in Property and equipment, net in 2018 from 2017? Success: -3991.0
# << -$9,401-(-$5,410) || [-9401.0, -5410.0, -3991.0] || [] || True >>
# 60fc4cb62e02f1bc47519bc34b2cd6b1
# What was the percentage change in Property and equipment, net in 2018 from 2017? Success: 73.77
# << ((-$9,401-(-$5,410))/-$5,410) * 100 || [-9401.0, -5410.0, 73.77079482439926] || [] || True >>
# a30c0da091bbd33f665ab11a25117074
# What was the percentage change in Interest expense between 2015 and 2016? Success: 20.3
# << ((717-596)/596) * 100 || [596.0, 717.0, 20.302013422818792] || [717.0, 596.0, 596.0] || True >>
# eeef320a4199b74356c5e18e58c33fb4
# What was the average Research and development expense for 2018 and 2019? Success: 45664.5
# << (50,024 + 41,305) / 2 || [50024.0, 41305.0, 45664.5] || [50024.0, 41305.0] || True >>
# 36453309f798d54fba67e60cac4490e2
# What is the change in the % of revenue from 2018 to 2019? Success: -3.0
# << 25 - 28 || [-3.0] || [25.0, 28.0] || False >>
# 7645f09642d6f2db485e05ac58013f26
# What is the change of expenses for facilities from fiscal year 2017 to 2019?  Success: 3059.0
# << 7,834-4,775 || [7834.0, -4775.0, 3059.0] || [7834.0] || True >>
# a23b3dcb820703a1d9aea7dc33091afb
# What is the difference between the Change between Fiscal increase for 2019 and 2018 and 2018 and 2017 for Payroll and payroll-related benefits? Success: 26490.0
# << 39,119-12,629 || [12629.0, 39119.0] || [39119.0, 12629.0] || True >>
# 6d046c35f507c818158760c49dae5e23
# What is the Total change in research and development expenses from 2017 to 2019? Success: 40621.0
# << 41,694-1,073 || [-1073.0, 41694.0, 40621.0] || [41694.0] || True >>
# 640faac1ccb705ef422bfaa0f72e84f1
# What was the percentage change in Dividend and interest income in 2018 from 2017? Success: 50.47
# << ((635-422)/422) * 100 || [635.0, 422.0, 50.4739336492891] || [635.0, 422.0, 422.0] || True >>
# 50d6a01be8a0986d1b43bdb3a32e3446
# What was the change in the Loss from discontinued operations from 2017 to 2018? Success: -60921.0
# << -72,836 - (-11,915) || [-11915.0, -72836.0, -60921.0] || [] || True >>
# 679f03324e62ac16d07bc3e09c8e2376
# What is the average Gain on sale of Netsmart between 2017-2019? Success: 166823.67
# << (0 + 500,471 + 0) / 3 || [166823.66666666666] || [0.0, 500471.0, 0.0] || False >>
# 0cc2a888dd2540ce9991a759eb85bbaf
# What was the average Income tax effect on discontinued operations between 2017-2019? Success: 3255.33
# << (0 - 32,497 + 42,263) / 3 || [3255.3333333333335] || [0.0, 42263.0] || False >>
# 56d9aa6afc1e09a1727aacc4c0435d45
# What was the 2019 percentage change in accrued revenue? Success: 377.63
# << ((27,817 - 5,824) / 5,824 ) * 100 || [27817.0, 5824.0, 377.62706043956047] || [27817.0, 5824.0, 5824.0] || True >>
# 247b29ff672119850a618a5e59edf29e
# What was the average accrued revenue between 2018 and 2019? Success: 16820.5
# << (27,817 + 5,824) / 2  || [27817.0, 5824.0, 16820.5] || [27817.0, 5824.0] || True >>
# 6f1652507bcbc0845aa582d579321209
# How much was the difference in unearned revenue and accrued revenue in 2019? Success: -748.0
# << 27,817 - 27,069  || [27817.0, 27069.0, -748.0] || [27817.0, 27069.0] || True >>
# 0360296840de0645325b8cb6306101ff
# What is the net value of the unrealized gains and losses of the company's municipal bonds? Success: -97.0
# << 13 + (110)  || [13.0, -110.0, -97.0] || [13.0] || True >>
# 8039ea4c8f281b490be3e64dd7aef8e7
# What is the value of the amortized costs of  the municipal bonds as a percentage of the total amortized cost? Success: 24.01
# << (44,802/93,301 ) * 100 || [44802.0, 186602.0, 24.0093889668921] || [44802.0, 93301.0] || False >>
# afe196e1ac486bdab48cad41046bcf08
# What is the value of the amortized costs of  the corporate bonds as a percentage of the total amortized cost? Success: 25.99
# << (48,499/93,301 ) * 100 || [48499.0, 186602.0, 25.990611033107896] || [48499.0, 93301.0] || False >>
# 9c0a92f33095574b70f992e3ac68715a
# What is the total amount of all other compensation by all the directors in the table? Success: 41386.0
# << $4,000+$17,000+$15,950+$4,436 || [41386.0] || [4000.0, 17000.0, 15950.0, 4436.0] || False >>
# *** Overall EM:  0.8181818181818182 / 230
# 87192af423506160cd1df8fc628706e4
# What is the average amount of total compensation for each non-returning director? Success: 330267.33
# << ($259,472+$471,422+$259,908)/3 || [330267.3333333333] || [259472.0, 471422.0, 259908.0] || False >>
# *** Overall EM:  0.8260869565217391 / 230
# ffe60dd9dae69ba85ea4fae7ee10ebae
# What is the increase/ (decrease) in Wireless devices and accessories from 2018 to 2019? Success: -19.0
# << 380-399 || [380.0, 399.0, -19.0] || [380.0, 399.0] || True >>
# 80f4540b447fc62c20f332f34250dc94
# What is the increase/ (decrease) in Other finished goods and merchandise from 2018 to 2019? Success: 13.0
# << 80-67 || [80.0, 67.0] || [80.0, 67.0] || True >>
# b9052616463aee5ec89dd6da25bc73a2
# What is the increase/ (decrease) in Total inventories from 2018 to 2019? Success: -6.0
# << 460-466 || [460.0, 466.0, -6.0] || [460.0, 466.0] || True >>
# cf42ab5eb0e02d2fa26ecbd6f525fb13
# What was the percentage change in the the total net property, plant and equipment between 2018 and 2019? Success: 5.67
# << ((105,038-99,401)/99,401) * 100 || [105038.0, 99401.0, 5.670969104938582] || [105038.0, 99401.0, 99401.0] || True >>
# 12c96773a28e7443eb18764411eaef50
# What is the percentage change in capitalized interest in 2019? Success: -11.76
# << ((45-51)/51) * 100 || [45.0, 51.0, -11.76470588235294] || [45.0, 51.0, 51.0] || True >>
# 2e7d0e6099ef5431e0ce2ca15d0cc9d9
# What is the company's total operating lease obligations between 2020 to 2022? Success: 55746.0
# << 19,373 + 36,373  || [55746.0] || [19373.0, 36373.0] || False >>
# 75022367778142d287da9236724aad8d
# What is the percentage constitution of purchase obligations among the total contractual obligations in 2020? Success: 54.0
# << (24,800/45,927) * 100 || [45927.0, 24800.0, 53.99873712630914] || [24800.0, 45927.0] || True >>
# 5b8b422ea976902a5f10dbb8bb17179e
# What is the value of the company's 2023-2024 purchase obligations as a percentage of its total payment due in the 2023-2024 period? Success: 2.18
# << (438/20,121 ) * 100 || [438.0, 20121.0, 2.1768301774265693] || [438.0, 20121.0] || True >>
# 76fcf6b0bf227d2e506aee1910f497cf
# What is the difference in the total franchise revenues between 2018 and 2019? Success: 191668.0
# << $613,300 - $421,632  || [613300.0, 421632.0, 191668.0] || [613300.0, 421632.0] || True >>
# *** Overall EM:  0.875 / 60
# 23fe1be9117b398035a9ead824b331a8
# What is the average in total franchise costs for 2018 and 2019? Success: 263349.5
# << ($356,787 + $169,912)/2  || [356787.0, 169912.0, 263349.5] || [356787.0, 169912.0] || True >>
# *** Overall EM:  0.8787878787878788 / 60
# dca2866a67dde74f8acfb646e68e7592
# What is the percentage constitution of franchise rental revenues among the total franchise revenues in 2019? Success: 44.48
# << ($272,815/$613,300 ) * 100 || [272815.0, 613300.0, 44.483124082830585] || [272815.0, 613300.0] || True >>
# *** Overall EM:  0.8823529411764706 / 60
# 40acacac7f638d5cfdff96a4b1c0995d
# What is the average year-on-year change in Weighted average grant date fair value from 2017 to 2019?  Success: 15.77
# << (((4.72-3.36)/3.36+(3.36-3.69)/3.69)/2) * 100 || [3.69, 3.36, 4.72, -8.943089430894311, 40.476190476190474, 15.766550522648082] || [4.72, 3.36, 3.36, 3.36, 3.69, 3.69] || True >>
# f7e00028b6447875f8005ab8c18639a4
# What was the percentage increase / (decrease) in Weighted average grant date fair value from 2018 to 2019? Success: 40.48
# << (4.72 / 3.36 - 1) * 100 || [3.36, 4.72, 40.476190476190474] || [4.72, 3.36] || True >>
# 586b24199ab25b1747ae3573492f1ccb
# What was the increase / (decrease) in the Weighted average grant date fair value from 2018 to 2019? Success: 1.36
# << 4.72 - 3.36 || [4.72, 3.36, 1.3599999999999999] || [4.72, 3.36] || True >>
# 75e012945b2e63911c3bc4376b042c0d
# What is the percentage change in the net operating loss carry forward from 2018 to 2019? Success: 8.45
# << ((27,907 - 25,733)/25,733 ) * 100 || [27907.0, 25733.0, 8.448295962382932] || [27907.0, 25733.0, 25733.0] || True >>
# 128c698b8fad151bf8516c2d51f1760b
# What is the change in Reserves and accruals between 2018 and 2019? Success: 17.0
# << 62 - 45  || [62.0, 45.0, 17.0] || [62.0, 45.0] || True >>
# 90fe2b41c9523249f82744554c978991
# What was the percentage change in Total cash, cash equivalents and restricted cash between 2018 and 2019? Success: 20.93
# << (($1,578.0-$1,304.9)/$1,304.9) * 100 || [1578.0, 1304.9, 20.92880680511916] || [1578.0, 1304.9, 1304.9] || True >>
# b2d5e2512b0988dd701480c344fb82bf
# What is the change in Item reclassified from freehold investment property from 2018 to 2019? Success: -2332.0
# << 2,068-4,400 || [4400.0, 2068.0, -2332.0] || [2068.0, 4400.0] || True >>
# 03b8194d47511d07e1e1aa58aa721957
# What is the change in Disposals during the year from 2018 to 2019? Success: 3439.0
# << 961-4,400 || [-961.0, -4400.0, 3439.0] || [4400.0] || False >>
# 4478c71ff25482f914636301d4c2413a
# What is the change in Other intangible assets Amortisation 2018 to 2019? Success: 0.0
# << 1,107-5,713 || [] || [1107.0, 5713.0] || False >>
# 715c9dd9b0dc4720ea3ba7ad4e436ee8
# What was the change in the amount for contracts within one year? Success: 2.8
# << 18.3-15.5 || [18.3, 15.5, 2.8000000000000007] || [18.3, 15.5] || True >>
# 25c53226518b6687085500e468d8cdfa
# What was the percentage change in the amount for contracts within one year? Success: 18.06
# << ((18.3-15.5)/15.5) * 100 || [18.3, 15.5, 18.064516129032263] || [18.3, 15.5, 15.5] || True >>
# 85c74755d4ccf8eb9167000284c818a9
# What is the revenue from Canada in 2019 as a percentage of the total revenue in 2019? Success: 1.35
# << ((9,815/363,800)) * 100 || [9815.0, 727600.0, 1.3489554700384827] || [9815.0, 363800.0] || False >>
# 276815a7f82a8c5eb1a4991d98fe253b
# What is the change in the number of IPTV retail subscribers in 2019? Success: -19314.0
# << 1,767,182-1,675,706 || [] || [1767182.0, 1675706.0] || False >>
# 34e05c377aa4cec6cc7ab6feedb0812c
# What is the percentage of Satellite subscribers out of the total retail subscribers in 2019? Success: -3.08
# << (1,005,282/2,772,464) * 100 || [-85423.0, 2772464.0, -3.081122063262138] || [1005282.0, 2772464.0] || False >>
# 587984b897fac513f24769a16342c523
# What is the percentage of IPTV subscribers out of the total retail subscribers in 2019? Success: 3.3
# << (1,767,182/2,772,464) * 100 || [3.29944771149418] || [1767182.0, 2772464.0] || False >>
# 653f0628622f8a654b56e21f1d58d1f8
# What is the change in Interest income from 2018 to 2019? Success: 27.0
# << 121-94 || [121.0, 94.0, 27.0] || [121.0, 94.0] || True >>
# e25f7d33f913085e05d33e04acedf950
# What is the change in Other components of net periodic benefit cost from 2018 to 2019? Success: -2441.0
# << 627-3,068 || [] || [627.0, 3068.0] || False >>
# 5c54743f6de457f4d0af525fc5ba37ed
# What is the change in Early debt extinguishment costs from 2018 to 2019? Success: -2879.0
# << 3,604-725 || [] || [] || True >>
# ab007d8a4c643492a9312c096956dffe
# What was the change in PSP payments for the Group in 2019 from 2018? Success: 0.3
# << 2.1-1.8 || [2.1, 1.8, 0.30000000000000004] || [2.1, 1.8] || True >>
# b78a785338a7b71fdc0668c0faf22fbe
# What was the percentage change in PSP payments for the Group in 2019 from 2018? Success: 16.67
# << ((2.1-1.8)/1.8) * 100 || [1.8, 2.1, 16.666666666666668] || [2.1, 1.8, 1.8] || True >>
# 25d2e81cd8e2d8ab81c5796d6e89c4ec
# What was the change in gross profit between May 2019 and August 2019? Success: 51279.0
# << 495,078-443,799 || [443799.0, 495078.0, 51279.0] || [495078.0, 443799.0] || True >>
# 8f23d52beaedf5e030daa78043e721cc
# What was the change in basic earnings per share attributable to the stockholders of Jabil Inc. between May 2019 and August 2019?[Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType'
# [Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType'
#  Success: [Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType'
# << $0.34-$0.28 || [] || [0.34, 0.28] || False >>
# 27f1a9c7a554b928ab4da0afb589b3f6
# What was the percentage change in net revenue between November 2018 and February 2019? Success: -6.75
# << (($6,066,990-$6,506,275)/$6,506,275) * 100 || [6506275.0, 6066990.0, -6.751712769595505] || [6066990.0, 6506275.0, 6506275.0] || True >>
# a4778f6baf7fbc47c36e2df4f39aff7e
# What was the change in the total compensation in 2019 from 2018? Success: 1.2000000000000002
# << 9.0-7.8 || [9.0, 7.8, 1.2000000000000002] || [9.0, 7.8] || True >>
# fd96beba233f4b2ec8b7e5d2cf1c7aed
# What was the percentage change in the total compensation in 2019 from 2018? Success: 15.38
# << ((9.0-7.8)/7.8) * 100 || [9.0, 7.8, 15.384615384615389] || [9.0, 7.8, 7.8] || True >>
# c148020f43b4ba93d6dc65235e69e7cc
# What proportion of the total cost does the acquisition related cost form part of in 2019? Success: 11.87
# << ($1,696 / $14,290) * 100 || [14290.0, 1696.0, 11.86843946815955] || [1696.0, 14290.0] || True >>
# 1d568952985d546e1035c7b8311c07cf
# What was the percentage change in non-current assets in Asia Pacific? Success: 68.18
# << ((7.4-4.4)/4.4) * 100 || [7.4, 4.4, 68.18181818181817] || [7.4, 4.4, 4.4] || True >>
# 11f94da9b4b3b0eb8e771898f7cb3b5c
# In 2019, what is the percentage constitution of nonvested stock units among the total share-based compensation expense? Success: 67.6
# << (5,458/8,074) * 100 || [5458.0, 8074.0, 67.59970274956652] || [5458.0, 8074.0] || True >>
# d82ccbf862bbea0c2a60bf0f08df9c5d
# What was the difference between the 2019 actual group cash generation compared with the 2019 target group cash generation? Success: -11.399999999999977
# << 296.4-285.0 || [296.4, 285.0, -11.399999999999977] || [296.4, 285.0] || True >>
# 3bff27eb2944cb199f863d6eb50bb06d
# What is the 2019 actual group operating profit expressed as a ratio of the 2019 target group operating profit? Success: 1.03
# << 277.3/270.3 || [277.3, 270.3, 1.0258971513133555] || [277.3, 270.3] || True >>
# 7d26ba6ef5c6202999c0593a1ec5c6d6
# What is the year-on-year change in VAS Business revenue? Success: -5.36
# << 199,991-176,646 || [53.0, 56.0, -5.357142857142857] || [199991.0, 176646.0] || False >>
# 929018fca125b27facecdc3b42edbe47
# What is the year-on-year change in FinTech and Business Services revenue? Success: 17.39
# << 101,355-73,138 || [27.0, 23.0, 17.391304347826086] || [101355.0, 73138.0] || False >>
# df27c6c6567c0b93f2a4b3702d885835
# What is the year-on-year change in Online Advertising Business revenue? Success: -5.26
# << 68,377-58,079 || [18.0, 19.0, -5.263157894736842] || [68377.0, 58079.0] || False >>
# b5572f9f8b64c1e860b7c4dcdcf272de
# What was the change in personnel expenses in 2018/2019 from 2017/2018? Success: 91.0
# << 2,816-2,725 || [2173.0, 2264.0, 91.0] || [2816.0, 2725.0] || False >>
# 2df5086d76d9cb82d007d208a95e03bf
# What was the percentage change in personnel expenses in 2018/2019 from 2017/2018? Success: 4.19
# << ((2,816-2,725)/2,725) * 100 || [2173.0, 2264.0, 4.187758858720662] || [2816.0, 2725.0, 2725.0] || False >>
# 4cc89377aa421d8d6eece5a7dce4de2d
# What is the average cash dividends declared per share for fiscal years 2017 to 2019?[Error]
# [Error]
#  Success: [Error]
# << (1.28+ 1.28+ 2.04)/3 || [] || [1.28, 1.28, 2.04] || False >>
# a070ac129ffad54615cd45118c9aea75
# What is the change in operating income between fiscal years 2019 and 2018? Success: 38294.0
# << 67,994-29,700 || [67994.0, 29700.0, 38294.0] || [67994.0, 29700.0] || True >>
# 27f6efd18696c43720f1ca2e94c0f7e5
# What is the average basic earnings per share for fiscal years 2017 to 2019?[Error]
# [Error]
#  Success: [Error]
# << (2.41+ 2.70+ 12.30)/3 || [] || [2.41, 2.7, 12.3] || False >>
# 2c0e0e756168b45e92978a151a7fb2ab
# What is the amount of total commission as a percentage of the Ceiling as per Section 198 of the Companies Act? Success: 108.98
# << (1,210.00/40,434.81 ) * 100 || [44064.81, 40434.81, 108.97741327336522] || [1210.0, 40434.81, 100.0] || False >>
# f0b2fe06c1b53072f911666f3c4fc564
# What is the amount of total Sitting Fees as a percentage of Total Managerial Remuneration? Success: 6.36
# << (33.60/1,243.60 ) * 100 || [2573.0, 40434.81, 6.363329022691093] || [33.6, 1243.6, 100.0] || False >>
# f585885778f95bf1dbb2a00151125624
# What was the change in revenue in Ireland in 2019 from 2018? Success: 0.0
# << 5.2-5.2 || [5.2, 5.2] || [5.2, 5.2] || True >>
# acf5fdb8be289c36f97930c4fcf72942
# What was the percentage change in revenue in Ireland in 2019 from 2018? Success: 0.0
# << (5.2-5.2)/5.2 || [5.2, 5.2, 0.0] || [5.2, 5.2, 5.2] || True >>
# ee85b9ce062cb99f0861b9c43d6f6eed
# What is the ratio of Darcy Antonellis’ total compensation to David C. Habiger’s total compensation? Success: 0.93
# << 205,320/219,987  || [205320.0, 219987.0, 0.9333278784655457] || [205320.0, 219987.0] || True >>
# bf0f732e7286dad472c3a7a3848415a2
# What is the average fee earned or paid in cash compensation for all non-employee directors? Success: 77111.0
# << (106,000+55,333+70,000+81,000+68,333+82,000)/6  || [462666.0, 77111.0] || [106000.0, 55333.0, 70000.0, 81000.0, 68333.0, 82000.0] || False >>
# 48f4cafcd78061339d631d6490c055e0
# What was the change in Other in FY2019 from FY2018? Success: 0.0
# << 1-1 || [1.0, 1.0, 0.0] || [1.0, 1.0] || True >>
# 5bbcaeb1ebcedc949361aba4d6559771
# What was the percentage change in Other in FY2019 from FY2018? Success: 0.0
# << (1-1)/1 || [1.0, 1.0, 0.0] || [1.0, 1.0, 1.0] || True >>
# 0f782fc4163163785b2e178515809eaf
# What was the change in the Expected volatility from 2017 to 2018? Success: -6.69
# << 25.37 - 27.19 || [27.19, 25.37, -6.693637366678927] || [25.37, 27.19] || True >>
# 337883b1c9a3f437f0667434c832a52e
# What was the change in Weighted average grant date stock price from 2017 to 2018? Success: 11.27
# << 65 - 53.73 || [53.73, 65.0, 11.270000000000003] || [65.0, 53.73] || True >>
# ba05732dd03e71da5b0e02ba9b16447d
# What was the change in the amount of surcharge revenue from 2018 to 2019? Success: 72.70000000000005
# << 438.1-365.4 || [438.1, 365.4, 72.70000000000005] || [438.1, 365.4] || True >>
# *** Overall EM:  0.7228915662650602 / 90
# e395e9f47dbe3fd712e7ab4f42fe0eec
# What was the percentage change in the amount of surcharge revenue from 2018 to 2019? Success: 19.9
# << ((438.1-365.4)/365.4) * 100 || [438.1, 365.4, 19.896004378763013] || [438.1, 365.4, 365.4] || True >>
# *** Overall EM:  0.7261904761904762 / 90
# 844c4d74af9231f62c7c193d54c0549e
# What is the average sales and marketing expenses for 2018 and 2019? Success: 411455.0
# << (472,841+350,069)/2 || [472841.0, 350069.0, 411455.0] || [472841.0, 350069.0] || True >>
# 9d8a4bd1a58a100ae2c3fd8b605a490b
# What is the difference between the Ending balance of unrecognized tax benefits of 2019 against 2017? Success: 176.0
# << 390.3-214.3 || [390.3, 214.3, 176.0] || [390.3, 214.3] || True >>
# *** Overall EM:  0.7325581395348837 / 260
# 2a7951420ed77b8b40366a4d53a2f5d3
# What is the Beginning balance of unrecognized tax benefits expressed as a percentage of Ending balance of unrecognized tax benefits for 2019? Success: 91.31
# << (356.4/390.3) * 100 || [356.4, 390.3, 91.31437355880091] || [356.4, 390.3] || True >>
# *** Overall EM:  0.735632183908046 / 260
# 557c1e6b072d90960071e39e584e404e
# What is the average annual Ending balance of unrecognized tax benefits?  Success: 320.33
# << (390.3+356.4+214.3)/3 || [320.3333333333333] || [390.3, 356.4, 214.3] || False >>
# *** Overall EM:  0.7386363636363636 / 260
# e2164a95603660da8e3b21396f51c71d
# What was the change in the amount of Accruals? Success: 6.1
# << 49.3-43.2 || [49.3, 43.2, 6.099999999999994] || [49.3, 43.2] || True >>
# 44caa96068a5c3f6e3584d1b363568f9
# What was the percentage change in the amount of Accruals? Success: 14.12
# << ((49.3-43.2)/43.2) * 100 || [49.3, 43.2, 14.120370370370356] || [49.3, 43.2, 43.2] || True >>
# 922ce7104fc57e4abeefb7ece1532a8f
# What was the percentage change in interest expense from 2018 to 2019? Success: -50.6
# << ((53,353 - 108,011)/108,011 ) * 100 || [-108011.0, -53353.0, -50.6041051374397] || [] || True >>
# 1770227341.554161 140.03759932518005
# cnt: 91

# %%
annotated_results = cga_utils.annotate_results(res)
cga_utils.calc_overall_em(annotated_results)
# Out:
# 0.7472527472527473

# %%
import pandas as pd
messages = prompt_versions.prompt_versions['V31']
#messages = [(a, t.replace('/no_think','')) for (a,t)  in messages]
#messages[-1] = ( messages[-1][0],  messages[-1][1] + "/no_think" ) 

res = cga_utils.execute_dataset_predictions(llm, messages, dataset=sample_df)
# Out:
# 1770227410.89154
# 0it [00:00, ?it/s]
# 7e2290f656cbeef6d9a61c02767b752c
# What was the percentage change in adjusted EBITDA between 2018 and 2019? failure: 16.36 good answer:  16.36
# << ((108,307-93,081)/93,081) * 100 || [108307.0, 93081.0, 16.357795898196194] || [108307.0, 93081.0, 93081.0, 100.0] || False >>
# *** Overall EM:  1.0 / 30
# d2fca279eeba2f76f54127d5884fc542
# What is the change in revenue growth between 2019 and 2018? Success: -4.3999999999999995
# << ((7.2%-11.6%)) * 100 || [7.2, 11.6, -4.3999999999999995] || [7.2, 11.6] || True >>
# 15c13aff533786d03238eb3e6f433c1f
# What are leasehold improvements in 2019 as a percentage of the total property equipment before depreciation, amortization and fixed assets not in service? Success: 3.26
# << ((3,522/79,828)) * 100 || [3522.0, 107962.0, 3.262258942961412] || [3522.0, 79828.0] || False >>
# *** Overall EM:  0.6666666666666666 / 220
# a232d237c226f8bcfdabfd8daad919fc
# What was the change in Property and equipment, net in 2018 from 2017? Success: -3991.0
# << -$9,401-(-$5,410) || [-9401.0, -5410.0, -3991.0] || [] || True >>
# 60fc4cb62e02f1bc47519bc34b2cd6b1
# What was the percentage change in Property and equipment, net in 2018 from 2017? Success: 73.77
# << ((-$9,401-(-$5,410))/-$5,410) * 100 || [73.77079482439926] || [] || True >>
# a30c0da091bbd33f665ab11a25117074
# What was the percentage change in Interest expense between 2015 and 2016? Success: 20.3
# << ((717-596)/596) * 100 || [596.0, 717.0, 20.302013422818792] || [717.0, 596.0, 596.0] || True >>
# eeef320a4199b74356c5e18e58c33fb4
# What was the average Research and development expense for 2018 and 2019? Success: 45664.5
# << (50,024 + 41,305) / 2 || [50024.0, 41305.0, 45664.5] || [50024.0, 41305.0] || True >>
# 36453309f798d54fba67e60cac4490e2
# What is the change in the % of revenue from 2018 to 2019? Success: -3.0
# << 25 - 28 || [25.0, 28.0, -3.0] || [25.0, 28.0] || True >>
# 7645f09642d6f2db485e05ac58013f26
# What is the change of expenses for facilities from fiscal year 2017 to 2019?  Success: 3059.0
# << 7,834-4,775 || [-4775.0, 7834.0, 3059.0] || [7834.0] || True >>
# a23b3dcb820703a1d9aea7dc33091afb
# What is the difference between the Change between Fiscal increase for 2019 and 2018 and 2018 and 2017 for Payroll and payroll-related benefits? Success: -26490.0
# << 39,119-12,629 || [12629.0, 39119.0, -26490.0] || [39119.0, 12629.0] || True >>
# 6d046c35f507c818158760c49dae5e23
# What is the Total change in research and development expenses from 2017 to 2019? Success: 40621.0
# << 41,694-1,073 || [-1073.0, 41694.0, 40621.0] || [41694.0] || True >>
# 640faac1ccb705ef422bfaa0f72e84f1
# What was the percentage change in Dividend and interest income in 2018 from 2017? Success: 50.47
# << ((635-422)/422) * 100 || [635.0, 422.0, 50.4739336492891] || [635.0, 422.0, 422.0] || True >>
# 50d6a01be8a0986d1b43bdb3a32e3446
# What was the change in the Loss from discontinued operations from 2017 to 2018? Success: -60921.0
# << -72,836 - (-11,915) || [-11915.0, -72836.0, -60921.0] || [] || True >>
# 679f03324e62ac16d07bc3e09c8e2376
# What is the average Gain on sale of Netsmart between 2017-2019? Success: 166823.67
# << (0 + 500,471 + 0) / 3 || [166823.66666666666] || [0.0, 500471.0, 0.0] || False >>
# 0cc2a888dd2540ce9991a759eb85bbaf
# What was the average Income tax effect on discontinued operations between 2017-2019? Success: 3255.33
# << (0 - 32,497 + 42,263) / 3 || [3255.3333333333335] || [0.0, 42263.0] || False >>
# 56d9aa6afc1e09a1727aacc4c0435d45
# What was the 2019 percentage change in accrued revenue? Success: 377.63
# << ((27,817 - 5,824) / 5,824 ) * 100 || [27817.0, 5824.0, 377.62706043956047] || [27817.0, 5824.0, 5824.0] || True >>
# 247b29ff672119850a618a5e59edf29e
# What was the average accrued revenue between 2018 and 2019? Success: 16820.5
# << (27,817 + 5,824) / 2  || [27817.0, 5824.0, 16820.5] || [27817.0, 5824.0] || True >>
# 6f1652507bcbc0845aa582d579321209
# How much was the difference in unearned revenue and accrued revenue in 2019? Success: -748.0
# << 27,817 - 27,069  || [27817.0, 27069.0, -748.0] || [27817.0, 27069.0] || True >>
# 0360296840de0645325b8cb6306101ff
# What is the net value of the unrealized gains and losses of the company's municipal bonds? Success: -97.0
# << 13 + (110)  || [13.0, -110.0, -97.0] || [13.0] || True >>
# 8039ea4c8f281b490be3e64dd7aef8e7
# What is the value of the amortized costs of  the municipal bonds as a percentage of the total amortized cost? Success: 24.01
# << (44,802/93,301 ) * 100 || [44802.0, 186602.0, 24.0093889668921] || [44802.0, 93301.0] || False >>
# afe196e1ac486bdab48cad41046bcf08
# What is the value of the amortized costs of  the corporate bonds as a percentage of the total amortized cost? Success: 25.99
# << (48,499/93,301 ) * 100 || [48499.0, 186602.0, 25.990611033107896] || [48499.0, 93301.0] || False >>
# 9c0a92f33095574b70f992e3ac68715a
# What is the total amount of all other compensation by all the directors in the table? Success: 41386.0
# << $4,000+$17,000+$15,950+$4,436 || [41386.0] || [4000.0, 17000.0, 15950.0, 4436.0] || False >>
# *** Overall EM:  0.7727272727272727 / 230
# 87192af423506160cd1df8fc628706e4
# What is the average amount of total compensation for each non-returning director? Success: 330267.33
# << ($259,472+$471,422+$259,908)/3 || [330267.3333333333] || [259472.0, 471422.0, 259908.0] || False >>
# *** Overall EM:  0.782608695652174 / 230
# ffe60dd9dae69ba85ea4fae7ee10ebae
# What is the increase/ (decrease) in Wireless devices and accessories from 2018 to 2019? Success: -19.0
# << 380-399 || [380.0, 399.0, -19.0] || [380.0, 399.0] || True >>
# 80f4540b447fc62c20f332f34250dc94
# What is the increase/ (decrease) in Other finished goods and merchandise from 2018 to 2019? Success: 13.0
# << 80-67 || [80.0, 67.0, 13.0] || [80.0, 67.0] || True >>
# b9052616463aee5ec89dd6da25bc73a2
# What is the increase/ (decrease) in Total inventories from 2018 to 2019? Success: -6.0
# << 460-466 || [460.0, 466.0, -6.0] || [460.0, 466.0] || True >>
# cf42ab5eb0e02d2fa26ecbd6f525fb13
# What was the percentage change in the the total net property, plant and equipment between 2018 and 2019? Success: 5.67
# << ((105,038-99,401)/99,401) * 100 || [105038.0, 99401.0, 5.67] || [105038.0, 99401.0, 99401.0] || True >>
# 12c96773a28e7443eb18764411eaef50
# What is the percentage change in capitalized interest in 2019? Success: -11.76
# << ((45-51)/51) * 100 || [45.0, 51.0, -11.76470588235294] || [45.0, 51.0, 51.0] || True >>
# 2e7d0e6099ef5431e0ce2ca15d0cc9d9
# What is the company's total operating lease obligations between 2020 to 2022? Success: 55746.0
# << 19,373 + 36,373  || [55746.0] || [19373.0, 36373.0] || False >>
# 75022367778142d287da9236724aad8d
# What is the percentage constitution of purchase obligations among the total contractual obligations in 2020? Success: 21.05
# << (24,800/45,927) * 100 || [24800.0, 117807.0, 21.051380648009033] || [24800.0, 45927.0] || False >>
# 5b8b422ea976902a5f10dbb8bb17179e
# What is the value of the company's 2023-2024 purchase obligations as a percentage of its total payment due in the 2023-2024 period? Success: 2.18
# << (438/20,121 ) * 100 || [438.0, 20121.0, 2.1768301774265693] || [438.0, 20121.0] || True >>
# 76fcf6b0bf227d2e506aee1910f497cf
# What is the difference in the total franchise revenues between 2018 and 2019? Success: 191668.0
# << $613,300 - $421,632  || [613300.0, 421632.0, 191668.0] || [613300.0, 421632.0] || True >>
# *** Overall EM:  0.8125 / 60
# 23fe1be9117b398035a9ead824b331a8
# What is the average in total franchise costs for 2018 and 2019? Success: 263349.5
# << ($356,787 + $169,912)/2  || [169912.0, 356787.0, 263349.5] || [356787.0, 169912.0] || True >>
# *** Overall EM:  0.8181818181818182 / 60
# dca2866a67dde74f8acfb646e68e7592
# What is the percentage constitution of franchise rental revenues among the total franchise revenues in 2019? Success: 44.48
# << ($272,815/$613,300 ) * 100 || [272815.0, 613300.0, 44.483124082830585] || [272815.0, 613300.0] || True >>
# *** Overall EM:  0.8235294117647058 / 60
# 40acacac7f638d5cfdff96a4b1c0995d
# What is the average year-on-year change in Weighted average grant date fair value from 2017 to 2019?  Success: 15.77
# << (((4.72-3.36)/3.36+(3.36-3.69)/3.69)/2) * 100 || [3.69, -8.943089430894311, 40.476190476190474, 15.766550522648082] || [4.72, 3.36, 3.36, 3.36, 3.69, 3.69] || False >>
# f7e00028b6447875f8005ab8c18639a4
# What was the percentage increase / (decrease) in Weighted average grant date fair value from 2018 to 2019? Success: 40.48
# << (4.72 / 3.36 - 1) * 100 || [3.36, 4.72, 40.476190476190474] || [4.72, 3.36] || True >>
# 586b24199ab25b1747ae3573492f1ccb
# What was the increase / (decrease) in the Weighted average grant date fair value from 2018 to 2019? Success: 1.36
# << 4.72 - 3.36 || [4.72, 3.36, 1.3599999999999999] || [4.72, 3.36] || True >>
# 75e012945b2e63911c3bc4376b042c0d
# What is the percentage change in the net operating loss carry forward from 2018 to 2019? Success: 8.45
# << ((27,907 - 25,733)/25,733 ) * 100 || [27907.0, 25733.0, 8.448295962382932] || [27907.0, 25733.0, 25733.0] || True >>
# 128c698b8fad151bf8516c2d51f1760b
# What is the change in Reserves and accruals between 2018 and 2019? Success: 17.0
# << 62 - 45  || [45.0, 62.0, 17.0] || [62.0, 45.0] || True >>
# 90fe2b41c9523249f82744554c978991
# What was the percentage change in Total cash, cash equivalents and restricted cash between 2018 and 2019? Success: 20.93
# << (($1,578.0-$1,304.9)/$1,304.9) * 100 || [1578.0, 1304.9, 20.92880680511916] || [1578.0, 1304.9, 1304.9] || True >>
# b2d5e2512b0988dd701480c344fb82bf
# What is the change in Item reclassified from freehold investment property from 2018 to 2019? Success: -2332.0
# << 2,068-4,400 || [4400.0, 2068.0, -2332.0] || [2068.0, 4400.0] || True >>
# 03b8194d47511d07e1e1aa58aa721957
# What is the change in Disposals during the year from 2018 to 2019? Success: 3439.0
# << 961-4,400 || [-4400.0, -961.0, 3439.0] || [4400.0] || False >>
# 4478c71ff25482f914636301d4c2413a
# What is the change in Other intangible assets Amortisation 2018 to 2019? Success: 0.0
# << 1,107-5,713 || [] || [1107.0, 5713.0] || False >>
# 715c9dd9b0dc4720ea3ba7ad4e436ee8
# What was the change in the amount for contracts within one year? Success: 2.8
# << 18.3-15.5 || [2.8000000000000007] || [18.3, 15.5] || False >>
# 25c53226518b6687085500e468d8cdfa
# What was the percentage change in the amount for contracts within one year? Success: 18.06
# << ((18.3-15.5)/15.5) * 100 || [18.3, 15.5, 18.3, 15.5, 18.064516129032263] || [18.3, 15.5, 15.5] || True >>
# 85c74755d4ccf8eb9167000284c818a9
# What is the revenue from Canada in 2019 as a percentage of the total revenue in 2019? Success: 1.35
# << ((9,815/363,800)) * 100 || [9815.0, 727600.0, 1.3489554700384827] || [9815.0, 363800.0] || False >>
# 276815a7f82a8c5eb1a4991d98fe253b
# What is the change in the number of IPTV retail subscribers in 2019? Success: -19314.0
# << 1,767,182-1,675,706 || [] || [1767182.0, 1675706.0] || False >>
# 34e05c377aa4cec6cc7ab6feedb0812c
# What is the percentage of Satellite subscribers out of the total retail subscribers in 2019? Success: -3.08
# << (1,005,282/2,772,464) * 100 || [-85423.0, 2772464.0, -3.081122063262138] || [1005282.0, 2772464.0] || False >>
# 587984b897fac513f24769a16342c523
# What is the percentage of IPTV subscribers out of the total retail subscribers in 2019? Success: 63.74
# << (1,767,182/2,772,464) * 100 || [1767182.0, 2772464.0, 63.740484998182126] || [1767182.0, 2772464.0] || True >>
# 653f0628622f8a654b56e21f1d58d1f8
# What is the change in Interest income from 2018 to 2019? Success: 27.0
# << 121-94 || [121.0, 94.0, 27.0] || [121.0, 94.0] || True >>
# e25f7d33f913085e05d33e04acedf950
# What is the change in Other components of net periodic benefit cost from 2018 to 2019? Success: -2441.0
# << 627-3,068 || [] || [627.0, 3068.0] || False >>
# 5c54743f6de457f4d0af525fc5ba37ed
# What is the change in Early debt extinguishment costs from 2018 to 2019? Success: -2879.0
# << 3,604-725 || [] || [] || True >>
# ab007d8a4c643492a9312c096956dffe
# What was the change in PSP payments for the Group in 2019 from 2018? Success: 0.3
# << 2.1-1.8 || [2.1, 1.8, 0.30000000000000004] || [2.1, 1.8] || True >>
# b78a785338a7b71fdc0668c0faf22fbe
# What was the percentage change in PSP payments for the Group in 2019 from 2018? Success: 16.67
# << ((2.1-1.8)/1.8) * 100 || [1.8, 2.1, 16.666666666666668] || [2.1, 1.8, 1.8] || True >>
# 25d2e81cd8e2d8ab81c5796d6e89c4ec
# What was the change in gross profit between May 2019 and August 2019? Success: 51279.0
# << 495,078-443,799 || [443799.0, 495078.0, 51279.0] || [495078.0, 443799.0] || True >>
# 8f23d52beaedf5e030daa78043e721cc
# What was the change in basic earnings per share attributable to the stockholders of Jabil Inc. between May 2019 and August 2019?[Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType'
# [Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType'
#  Success: [Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType'
# << $0.34-$0.28 || [] || [0.34, 0.28] || False >>
# 27f1a9c7a554b928ab4da0afb589b3f6
# What was the percentage change in net revenue between November 2018 and February 2019? Success: -6.75
# << (($6,066,990-$6,506,275)/$6,506,275) * 100 || [6506275.0, 6066990.0, -6.751712769595505] || [6066990.0, 6506275.0, 6506275.0] || True >>
# a4778f6baf7fbc47c36e2df4f39aff7e
# What was the change in the total compensation in 2019 from 2018? Success: 1.2
# << 9.0-7.8 || [9.0, 7.8, 1.2000000000000002] || [9.0, 7.8] || True >>
# fd96beba233f4b2ec8b7e5d2cf1c7aed
# What was the percentage change in the total compensation in 2019 from 2018? Success: 15.38
# << ((9.0-7.8)/7.8) * 100 || [9.0, 7.8, 15.384615384615389] || [9.0, 7.8, 7.8] || True >>
# c148020f43b4ba93d6dc65235e69e7cc
# What proportion of the total cost does the acquisition related cost form part of in 2019? Success: 0.12
# << ($1,696 / $14,290) * 100 || [14290.0, 1696.0, 0.11868439468159551] || [1696.0, 14290.0] || True >>
# 1d568952985d546e1035c7b8311c07cf
# What was the percentage change in non-current assets in Asia Pacific? Success: 68.18
# << ((7.4-4.4)/4.4) * 100 || [7.4, 4.4, 68.18181818181817] || [7.4, 4.4, 4.4] || True >>
# 11f94da9b4b3b0eb8e771898f7cb3b5c
# In 2019, what is the percentage constitution of nonvested stock units among the total share-based compensation expense? Success: 67.6
# << (5,458/8,074) * 100 || [5458.0, 8074.0, 67.59970274956652] || [5458.0, 8074.0] || True >>
# d82ccbf862bbea0c2a60bf0f08df9c5d
# What was the difference between the 2019 actual group cash generation compared with the 2019 target group cash generation? Success: 11.399999999999977
# << 296.4-285.0 || [296.4, 285.0, 11.399999999999977] || [296.4, 285.0] || True >>
# 3bff27eb2944cb199f863d6eb50bb06d
# What is the 2019 actual group operating profit expressed as a ratio of the 2019 target group operating profit? Success: 1.03
# << 277.3/270.3 || [277.3, 270.3, 1.0258971513133555] || [277.3, 270.3] || True >>
# 7d26ba6ef5c6202999c0593a1ec5c6d6
# What is the year-on-year change in VAS Business revenue? Success: -5.36
# << 199,991-176,646 || [53.0, 56.0, -5.357142857142857] || [199991.0, 176646.0] || False >>
# 929018fca125b27facecdc3b42edbe47
# What is the year-on-year change in FinTech and Business Services revenue? Success: 17.39
# << 101,355-73,138 || [27.0, 23.0, 17.391304347826086] || [101355.0, 73138.0] || False >>
# df27c6c6567c0b93f2a4b3702d885835
# What is the year-on-year change in Online Advertising Business revenue? Success: -5.26
# << 68,377-58,079 || [18.0, 19.0, -5.263157894736842] || [68377.0, 58079.0] || False >>
# b5572f9f8b64c1e860b7c4dcdcf272de
# What was the change in personnel expenses in 2018/2019 from 2017/2018? Success: 91.0
# << 2,816-2,725 || [2173.0, 2264.0, 552.0, 552.0, 2725.0, 2816.0, 91.0] || [2816.0, 2725.0] || True >>
# 2df5086d76d9cb82d007d208a95e03bf
# What was the percentage change in personnel expenses in 2018/2019 from 2017/2018? Success: 0.39
# << ((2,816-2,725)/2,725) * 100 || [509.0, 511.0, 0.3929273084479371] || [2816.0, 2725.0, 2725.0] || False >>
# 4cc89377aa421d8d6eece5a7dce4de2d
# What is the average cash dividends declared per share for fiscal years 2017 to 2019?[Error]unsupported operand type(s) for +: 'NoneType' and 'NoneType'
# [Error]unsupported operand type(s) for +: 'NoneType' and 'NoneType'
#  Success: [Error]unsupported operand type(s) for +: 'NoneType' and 'NoneType'
# << (1.28+ 1.28+ 2.04)/3 || [] || [1.28, 1.28, 2.04] || False >>
# a070ac129ffad54615cd45118c9aea75
# What is the change in operating income between fiscal years 2019 and 2018? Success: 38294.0
# << 67,994-29,700 || [67994.0, 29700.0, 38294.0] || [67994.0, 29700.0] || True >>
# 27f6efd18696c43720f1ca2e94c0f7e5
# What is the average basic earnings per share for fiscal years 2017 to 2019? Success: 5.8
# << (2.41+ 2.70+ 12.30)/3 || [5.803333333333334] || [2.41, 2.7, 12.3] || False >>
# 2c0e0e756168b45e92978a151a7fb2ab
# What is the amount of total commission as a percentage of the Ceiling as per Section 198 of the Companies Act? Success: 108.98
# << (1,210.00/40,434.81 ) * 100 || [44064.81, 40434.81, 108.97741327336522] || [1210.0, 40434.81, 100.0] || False >>
# f0b2fe06c1b53072f911666f3c4fc564
# What is the amount of total Sitting Fees as a percentage of Total Managerial Remuneration? Success: 0.06
# << (33.60/1,243.60 ) * 100 || [24.3, 40434.81, 0.06009673348285797] || [33.6, 1243.6, 100.0] || False >>
# f585885778f95bf1dbb2a00151125624
# What was the change in revenue in Ireland in 2019 from 2018? Success: 0.0
# << 5.2-5.2 || [5.2, 5.2, 0.0] || [5.2, 5.2] || True >>
# acf5fdb8be289c36f97930c4fcf72942
# What was the percentage change in revenue in Ireland in 2019 from 2018? Success: 0.0
# << (5.2-5.2)/5.2 || [5.2, 5.2, 0.0] || [5.2, 5.2, 5.2] || True >>
# ee85b9ce062cb99f0861b9c43d6f6eed
# What is the ratio of Darcy Antonellis’ total compensation to David C. Habiger’s total compensation? Success: 0.93
# << 205,320/219,987  || [205320.0, 219987.0, 0.9333278784655457] || [205320.0, 219987.0] || True >>
# bf0f732e7286dad472c3a7a3848415a2
# What is the average fee earned or paid in cash compensation for all non-employee directors? Success: 77111.0
# << (106,000+55,333+70,000+81,000+68,333+82,000)/6  || [77111.0] || [106000.0, 55333.0, 70000.0, 81000.0, 68333.0, 82000.0] || False >>
# 48f4cafcd78061339d631d6490c055e0
# What was the change in Other in FY2019 from FY2018? Success: 0.0
# << 1-1 || [1.0, 1.0, 0.0] || [1.0, 1.0] || True >>
# 5bbcaeb1ebcedc949361aba4d6559771
# What was the percentage change in Other in FY2019 from FY2018? Success: 0.0
# << (1-1)/1 || [1.0, 1.0, 0.0] || [1.0, 1.0, 1.0] || True >>
# 0f782fc4163163785b2e178515809eaf
# What was the change in the Expected volatility from 2017 to 2018? Success: -1.8200000000000003
# << 25.37 - 27.19 || [27.19, 25.37, -1.8200000000000003] || [25.37, 27.19] || True >>
# 337883b1c9a3f437f0667434c832a52e
# What was the change in Weighted average grant date stock price from 2017 to 2018? Success: 11.27
# << 65 - 53.73 || [53.73, 65.0, 11.270000000000003] || [65.0, 53.73] || True >>
# ba05732dd03e71da5b0e02ba9b16447d
# What was the change in the amount of surcharge revenue from 2018 to 2019? Success: 72.7
# << 438.1-365.4 || [438.1, 365.4, 72.70000000000005] || [438.1, 365.4] || True >>
# *** Overall EM:  0.7108433734939759 / 90
# e395e9f47dbe3fd712e7ab4f42fe0eec
# What was the percentage change in the amount of surcharge revenue from 2018 to 2019? Success: 19.9
# << ((438.1-365.4)/365.4) * 100 || [365.4, 438.1, 19.896004378763013] || [438.1, 365.4, 365.4] || True >>
# *** Overall EM:  0.7142857142857143 / 90
# 844c4d74af9231f62c7c193d54c0549e
# What is the average sales and marketing expenses for 2018 and 2019? Success: 411455.0
# << (472,841+350,069)/2 || [472841.0, 350069.0, 411455.0] || [472841.0, 350069.0] || True >>
# 9d8a4bd1a58a100ae2c3fd8b605a490b
# What is the difference between the Ending balance of unrecognized tax benefits of 2019 against 2017? Success: 176.0
# << 390.3-214.3 || [390.3, 214.3, 176.0] || [390.3, 214.3] || True >>
# *** Overall EM:  0.7209302325581395 / 260
# 2a7951420ed77b8b40366a4d53a2f5d3
# What is the Beginning balance of unrecognized tax benefits expressed as a percentage of Ending balance of unrecognized tax benefits for 2019? Success: 91.31
# << (356.4/390.3) * 100 || [356.4, 390.3, 91.31437355880091] || [356.4, 390.3] || True >>
# *** Overall EM:  0.7241379310344828 / 260
# 557c1e6b072d90960071e39e584e404e
# What is the average annual Ending balance of unrecognized tax benefits?  Success: 320.33
# << (390.3+356.4+214.3)/3 || [320.3333333333333] || [390.3, 356.4, 214.3] || False >>
# *** Overall EM:  0.7272727272727273 / 260
# e2164a95603660da8e3b21396f51c71d
# What was the change in the amount of Accruals? Success: 6.1
# << 49.3-43.2 || [49.3, 43.2, 6.099999999999994] || [49.3, 43.2] || True >>
# 44caa96068a5c3f6e3584d1b363568f9
# What was the percentage change in the amount of Accruals? Success: 14.12
# << ((49.3-43.2)/43.2) * 100 || [49.3, 43.2, 14.120370370370356] || [49.3, 43.2, 43.2] || True >>
# 922ce7104fc57e4abeefb7ece1532a8f
# What was the percentage change in interest expense from 2018 to 2019? Success: -50.6
# << ((53,353 - 108,011)/108,011 ) * 100 || [-108011.0, -53353.0, -50.6041051374397] || [] || True >>
# 1770227556.2809124 145.3893723487854
# cnt: 91

# %%
annotated_results = cga_utils.annotate_results(res)
cga_utils.calc_overall_em(annotated_results)
# Out:
# 0.7362637362637363

# %%
import pandas as pd
messages = prompt_versions.prompt_versions['V44b']
#messages = [(a, t.replace('/no_think','')) for (a,t)  in messages]
#messages[-1] = ( messages[-1][0],  messages[-1][1] + "/no_think" ) 

res = cga_utils.execute_dataset_predictions(llm, messages, dataset=sample_df)
# Out:
# 1770227556.3287506
# 0it [00:00, ?it/s]
# 7e2290f656cbeef6d9a61c02767b752c
# What was the percentage change in adjusted EBITDA between 2018 and 2019? failure: 16.36 good answer:  16.36
# << ((108,307-93,081)/93,081) * 100 || [108307.0, 93081.0, 16.357795898196194] || [108307.0, 93081.0, 93081.0, 100.0] || False >>
# *** Overall EM:  1.0 / 30
# d2fca279eeba2f76f54127d5884fc542
# What is the change in revenue growth between 2019 and 2018? Success: -4.3999999999999995
# << ((7.2%-11.6%)) * 100 || [7.2, 11.6, -4.3999999999999995] || [7.2, 11.6] || True >>
# 15c13aff533786d03238eb3e6f433c1f
# What are leasehold improvements in 2019 as a percentage of the total property equipment before depreciation, amortization and fixed assets not in service? Success: 2.97
# << ((3,522/79,828)) * 100 || [3522.0, 118455.0, 2.973280992782069] || [3522.0, 79828.0] || False >>
# *** Overall EM:  0.6666666666666666 / 220
# a232d237c226f8bcfdabfd8daad919fc
# What was the change in Property and equipment, net in 2018 from 2017? Success: -3991.0
# << -$9,401-(-$5,410) || [-9401.0, -5410.0, -3991.0] || [] || True >>
# 60fc4cb62e02f1bc47519bc34b2cd6b1
# What was the percentage change in Property and equipment, net in 2018 from 2017? Success: 73.77
# << ((-$9,401-(-$5,410))/-$5,410) * 100 || [-9401.0, -5410.0, 73.77079482439926] || [] || True >>
# a30c0da091bbd33f665ab11a25117074
# What was the percentage change in Interest expense between 2015 and 2016? Success: 20.3
# << ((717-596)/596) * 100 || [596.0, 717.0, 20.302013422818792] || [717.0, 596.0, 596.0] || True >>
# eeef320a4199b74356c5e18e58c33fb4
# What was the average Research and development expense for 2018 and 2019? Success: 45664.5
# << (50,024 + 41,305) / 2 || [50024.0, 41305.0, 45664.5] || [50024.0, 41305.0] || True >>
# 36453309f798d54fba67e60cac4490e2
# What is the change in the % of revenue from 2018 to 2019? Success: -3.0
# << 25 - 28 || [25.0, 28.0, -3.0] || [25.0, 28.0] || True >>
# 7645f09642d6f2db485e05ac58013f26
# What is the change of expenses for facilities from fiscal year 2017 to 2019?  Success: 3059.0
# << 7,834-4,775 || [7834.0, -4775.0, 3059.0] || [7834.0] || True >>
# a23b3dcb820703a1d9aea7dc33091afb
# What is the difference between the Change between Fiscal increase for 2019 and 2018 and 2018 and 2017 for Payroll and payroll-related benefits? Success: -26490.0
# << 39,119-12,629 || [12629.0, 39119.0, -26490.0] || [39119.0, 12629.0] || True >>
# 6d046c35f507c818158760c49dae5e23
# What is the Total change in research and development expenses from 2017 to 2019? Success: 40621.0
# << 41,694-1,073 || [-1073.0, 41694.0, 40621.0] || [41694.0] || True >>
# 640faac1ccb705ef422bfaa0f72e84f1
# What was the percentage change in Dividend and interest income in 2018 from 2017? Success: 50.47
# << ((635-422)/422) * 100 || [635.0, 422.0, 50.4739336492891] || [635.0, 422.0, 422.0] || True >>
# 50d6a01be8a0986d1b43bdb3a32e3446
# What was the change in the Loss from discontinued operations from 2017 to 2018? Success: -60921.0
# << -72,836 - (-11,915) || [-11915.0, -72836.0, -60921.0] || [] || True >>
# 679f03324e62ac16d07bc3e09c8e2376
# What is the average Gain on sale of Netsmart between 2017-2019? Success: 166823.67
# << (0 + 500,471 + 0) / 3 || [166823.66666666666] || [0.0, 500471.0, 0.0] || False >>
# 0cc2a888dd2540ce9991a759eb85bbaf
# What was the average Income tax effect on discontinued operations between 2017-2019? Success: 3255.33
# << (0 - 32,497 + 42,263) / 3 || [3255.3333333333335] || [0.0, 42263.0] || False >>
# 56d9aa6afc1e09a1727aacc4c0435d45
# What was the 2019 percentage change in accrued revenue? Success: 377.63
# << ((27,817 - 5,824) / 5,824 ) * 100 || [27817.0, 5824.0, 377.62706043956047] || [27817.0, 5824.0, 5824.0] || True >>
# 247b29ff672119850a618a5e59edf29e
# What was the average accrued revenue between 2018 and 2019? Success: 16820.5
# << (27,817 + 5,824) / 2  || [27817.0, 5824.0, 16820.5] || [27817.0, 5824.0] || True >>
# 6f1652507bcbc0845aa582d579321209
# How much was the difference in unearned revenue and accrued revenue in 2019? Success: -748.0
# << 27,817 - 27,069  || [27817.0, 27069.0, -748.0] || [27817.0, 27069.0] || True >>
# 0360296840de0645325b8cb6306101ff
# What is the net value of the unrealized gains and losses of the company's municipal bonds? Success: -97.0
# << 13 + (110)  || [13.0, -110.0, -97.0] || [13.0] || True >>
# 8039ea4c8f281b490be3e64dd7aef8e7
# What is the value of the amortized costs of  the municipal bonds as a percentage of the total amortized cost? Success: 24.01
# << (44,802/93,301 ) * 100 || [44802.0, 186602.0, 24.0093889668921] || [44802.0, 93301.0] || False >>
# afe196e1ac486bdab48cad41046bcf08
# What is the value of the amortized costs of  the corporate bonds as a percentage of the total amortized cost? Success: 25.99
# << (48,499/93,301 ) * 100 || [48499.0, 186602.0, 25.990611033107896] || [48499.0, 93301.0] || False >>
# 9c0a92f33095574b70f992e3ac68715a
# What is the total amount of all other compensation by all the directors in the table? Success: 41386.0
# << $4,000+$17,000+$15,950+$4,436 || [41386.0] || [4000.0, 17000.0, 15950.0, 4436.0] || False >>
# *** Overall EM:  0.7727272727272727 / 230
# 87192af423506160cd1df8fc628706e4
# What is the average amount of total compensation for each non-returning director? Success: 330267.33
# << ($259,472+$471,422+$259,908)/3 || [330267.3333333333] || [259472.0, 471422.0, 259908.0] || False >>
# *** Overall EM:  0.782608695652174 / 230
# ffe60dd9dae69ba85ea4fae7ee10ebae
# What is the increase/ (decrease) in Wireless devices and accessories from 2018 to 2019? Success: -19.0
# << 380-399 || [380.0, 399.0, -19.0] || [380.0, 399.0] || True >>
# 80f4540b447fc62c20f332f34250dc94
# What is the increase/ (decrease) in Other finished goods and merchandise from 2018 to 2019? Success: 13.0
# << 80-67 || [80.0, 67.0, 13.0] || [80.0, 67.0] || True >>
# b9052616463aee5ec89dd6da25bc73a2
# What is the increase/ (decrease) in Total inventories from 2018 to 2019? Success: -6.0
# << 460-466 || [460.0, 466.0, -6.0] || [460.0, 466.0] || True >>
# cf42ab5eb0e02d2fa26ecbd6f525fb13
# What was the percentage change in the the total net property, plant and equipment between 2018 and 2019? Success: 5.67
# << ((105,038-99,401)/99,401) * 100 || [105038.0, 99401.0, 5.670969104938582] || [105038.0, 99401.0, 99401.0] || True >>
# 12c96773a28e7443eb18764411eaef50
# What is the percentage change in capitalized interest in 2019? Success: -11.76
# << ((45-51)/51) * 100 || [45.0, 51.0, -11.76470588235294] || [45.0, 51.0, 51.0] || True >>
# 2e7d0e6099ef5431e0ce2ca15d0cc9d9
# What is the company's total operating lease obligations between 2020 to 2022? Success: 55746.0
# << 19,373 + 36,373  || [55746.0] || [19373.0, 36373.0] || False >>
# 75022367778142d287da9236724aad8d
# What is the percentage constitution of purchase obligations among the total contractual obligations in 2020? Success: 54.0
# << (24,800/45,927) * 100 || [24800.0, 45927.0, 53.99873712630914] || [24800.0, 45927.0] || True >>
# 5b8b422ea976902a5f10dbb8bb17179e
# What is the value of the company's 2023-2024 purchase obligations as a percentage of its total payment due in the 2023-2024 period? Success: 2.18
# << (438/20,121 ) * 100 || [438.0, 20121.0, 2.1768301774265693] || [438.0, 20121.0] || True >>
# 76fcf6b0bf227d2e506aee1910f497cf
# What is the difference in the total franchise revenues between 2018 and 2019? Success: 191668.0
# << $613,300 - $421,632  || [613300.0, 421632.0, 191668.0] || [613300.0, 421632.0] || True >>
# *** Overall EM:  0.84375 / 60
# 23fe1be9117b398035a9ead824b331a8
# What is the average in total franchise costs for 2018 and 2019? Success: 263349.5
# << ($356,787 + $169,912)/2  || [169912.0, 356787.0, 263349.5] || [356787.0, 169912.0] || True >>
# *** Overall EM:  0.8484848484848485 / 60
# dca2866a67dde74f8acfb646e68e7592
# What is the percentage constitution of franchise rental revenues among the total franchise revenues in 2019? Success: 44.48
# << ($272,815/$613,300 ) * 100 || [272815.0, 613300.0, 44.483124082830585] || [272815.0, 613300.0] || True >>
# *** Overall EM:  0.8529411764705882 / 60
# 40acacac7f638d5cfdff96a4b1c0995d
# What is the average year-on-year change in Weighted average grant date fair value from 2017 to 2019?  Success: 15.77
# << (((4.72-3.36)/3.36+(3.36-3.69)/3.69)/2) * 100 || [3.69, 3.36, 4.72, -8.943089430894311, 40.476190476190474, 15.766550522648082] || [4.72, 3.36, 3.36, 3.36, 3.69, 3.69] || True >>
# f7e00028b6447875f8005ab8c18639a4
# What was the percentage increase / (decrease) in Weighted average grant date fair value from 2018 to 2019? Success: 40.48
# << (4.72 / 3.36 - 1) * 100 || [3.36, 4.72, 40.476190476190474] || [4.72, 3.36] || True >>
# 586b24199ab25b1747ae3573492f1ccb
# What was the increase / (decrease) in the Weighted average grant date fair value from 2018 to 2019? Success: 1.36
# << 4.72 - 3.36 || [4.72, 3.36, 1.3599999999999999] || [4.72, 3.36] || True >>
# 75e012945b2e63911c3bc4376b042c0d
# What is the percentage change in the net operating loss carry forward from 2018 to 2019? Success: 8.45
# << ((27,907 - 25,733)/25,733 ) * 100 || [27907.0, 25733.0, 8.448295962382932] || [27907.0, 25733.0, 25733.0] || True >>
# 128c698b8fad151bf8516c2d51f1760b
# What is the change in Reserves and accruals between 2018 and 2019? Success: 17.0
# << 62 - 45  || [62.0, 45.0, 17.0] || [62.0, 45.0] || True >>
# 90fe2b41c9523249f82744554c978991
# What was the percentage change in Total cash, cash equivalents and restricted cash between 2018 and 2019? Success: 20.93
# << (($1,578.0-$1,304.9)/$1,304.9) * 100 || [1578.0, 1304.9, 20.92880680511916] || [1578.0, 1304.9, 1304.9] || True >>
# b2d5e2512b0988dd701480c344fb82bf
# What is the change in Item reclassified from freehold investment property from 2018 to 2019? Success: -2332.0
# << 2,068-4,400 || [4400.0, 2068.0, -2332.0] || [2068.0, 4400.0] || True >>
# 03b8194d47511d07e1e1aa58aa721957
# What is the change in Disposals during the year from 2018 to 2019? Success: 3439.0
# << 961-4,400 || [-4400.0, -961.0, 3439.0] || [4400.0] || False >>
# 4478c71ff25482f914636301d4c2413a
# What is the change in Other intangible assets Amortisation 2018 to 2019? Success: 0.0
# << 1,107-5,713 || [] || [1107.0, 5713.0] || False >>
# 715c9dd9b0dc4720ea3ba7ad4e436ee8
# What was the change in the amount for contracts within one year? Success: 2.8
# << 18.3-15.5 || [18.3, 15.5, 2.8000000000000007] || [18.3, 15.5] || True >>
# 25c53226518b6687085500e468d8cdfa
# What was the percentage change in the amount for contracts within one year? Success: 18.06
# << ((18.3-15.5)/15.5) * 100 || [18.3, 15.5, 18.064516129032263] || [18.3, 15.5, 15.5] || True >>
# 85c74755d4ccf8eb9167000284c818a9
# What is the revenue from Canada in 2019 as a percentage of the total revenue in 2019? Success: 1.35
# << ((9,815/363,800)) * 100 || [9815.0, 727600.0, 1.3489554700384827] || [9815.0, 363800.0] || False >>
# 276815a7f82a8c5eb1a4991d98fe253b
# What is the change in the number of IPTV retail subscribers in 2019? Success: -19314.0
# << 1,767,182-1,675,706 || [] || [1767182.0, 1675706.0] || False >>
# 34e05c377aa4cec6cc7ab6feedb0812c
# What is the percentage of Satellite subscribers out of the total retail subscribers in 2019? Success: -3.08
# << (1,005,282/2,772,464) * 100 || [-85423.0, 2772464.0, -3.081122063262138] || [1005282.0, 2772464.0] || False >>
# 587984b897fac513f24769a16342c523
# What is the percentage of IPTV subscribers out of the total retail subscribers in 2019? Success: 3.3
# << (1,767,182/2,772,464) * 100 || [91476.0, 2772464.0, 3.29944771149418] || [1767182.0, 2772464.0] || False >>
# 653f0628622f8a654b56e21f1d58d1f8
# What is the change in Interest income from 2018 to 2019? Success: 27.0
# << 121-94 || [] || [121.0, 94.0] || False >>
# e25f7d33f913085e05d33e04acedf950
# What is the change in Other components of net periodic benefit cost from 2018 to 2019? Success: -2441.0
# << 627-3,068 || [] || [627.0, 3068.0] || False >>
# 5c54743f6de457f4d0af525fc5ba37ed
# What is the change in Early debt extinguishment costs from 2018 to 2019? Success: -2879.0
# << 3,604-725 || [] || [] || True >>
# ab007d8a4c643492a9312c096956dffe
# What was the change in PSP payments for the Group in 2019 from 2018? Success: 0.3
# << 2.1-1.8 || [2.1, 1.8, 0.30000000000000004] || [2.1, 1.8] || True >>
# b78a785338a7b71fdc0668c0faf22fbe
# What was the percentage change in PSP payments for the Group in 2019 from 2018? Success: 16.67
# << ((2.1-1.8)/1.8) * 100 || [1.8, 2.1, 16.666666666666668] || [2.1, 1.8, 1.8] || True >>
# 25d2e81cd8e2d8ab81c5796d6e89c4ec
# What was the change in gross profit between May 2019 and August 2019? Success: 51279.0
# << 495,078-443,799 || [443799.0, 495078.0, 51279.0] || [495078.0, 443799.0] || True >>
# 8f23d52beaedf5e030daa78043e721cc
# What was the change in basic earnings per share attributable to the stockholders of Jabil Inc. between May 2019 and August 2019?[Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType'
# [Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType'
#  Success: [Error]unsupported operand type(s) for -: 'NoneType' and 'NoneType'
# << $0.34-$0.28 || [] || [0.34, 0.28] || False >>
# 27f1a9c7a554b928ab4da0afb589b3f6
# What was the percentage change in net revenue between November 2018 and February 2019? Success: -6.75
# << (($6,066,990-$6,506,275)/$6,506,275) * 100 || [6506275.0, 6066990.0, -6.751712769595505] || [6066990.0, 6506275.0, 6506275.0] || True >>
# a4778f6baf7fbc47c36e2df4f39aff7e
# What was the change in the total compensation in 2019 from 2018? Success: 1.2
# << 9.0-7.8 || [9.0, 7.8, 1.2000000000000002] || [9.0, 7.8] || True >>
# fd96beba233f4b2ec8b7e5d2cf1c7aed
# What was the percentage change in the total compensation in 2019 from 2018? Success: 15.38
# << ((9.0-7.8)/7.8) * 100 || [9.0, 7.8, 15.384615384615389] || [9.0, 7.8, 7.8] || True >>
# c148020f43b4ba93d6dc65235e69e7cc
# What proportion of the total cost does the acquisition related cost form part of in 2019? Success: 0.12
# << ($1,696 / $14,290) * 100 || [14290.0, 1696.0, 0.11868439468159551] || [1696.0, 14290.0] || True >>
# 1d568952985d546e1035c7b8311c07cf
# What was the percentage change in non-current assets in Asia Pacific? Success: 68.18
# << ((7.4-4.4)/4.4) * 100 || [7.4, 4.4, 68.18181818181817] || [7.4, 4.4, 4.4] || True >>
# 11f94da9b4b3b0eb8e771898f7cb3b5c
# In 2019, what is the percentage constitution of nonvested stock units among the total share-based compensation expense? Success: 67.6
# << (5,458/8,074) * 100 || [5458.0, 8074.0, 67.59970274956652] || [5458.0, 8074.0] || True >>
# d82ccbf862bbea0c2a60bf0f08df9c5d
# What was the difference between the 2019 actual group cash generation compared with the 2019 target group cash generation? Success: 11.399999999999977
# << 296.4-285.0 || [296.4, 285.0, 11.399999999999977] || [296.4, 285.0] || True >>
# 3bff27eb2944cb199f863d6eb50bb06d
# What is the 2019 actual group operating profit expressed as a ratio of the 2019 target group operating profit? Success: 1.03
# << 277.3/270.3 || [277.3, 270.3, 1.0258971513133555] || [277.3, 270.3] || True >>
# 7d26ba6ef5c6202999c0593a1ec5c6d6
# What is the year-on-year change in VAS Business revenue? Success: -5.36
# << 199,991-176,646 || [53.0, 56.0, -5.357142857142857] || [199991.0, 176646.0] || False >>
# 929018fca125b27facecdc3b42edbe47
# What is the year-on-year change in FinTech and Business Services revenue? Success: 17.39
# << 101,355-73,138 || [27.0, 23.0, 17.391304347826086] || [101355.0, 73138.0] || False >>
# df27c6c6567c0b93f2a4b3702d885835
# What is the year-on-year change in Online Advertising Business revenue? Success: -5.26
# << 68,377-58,079 || [18.0, 19.0, -5.263157894736842] || [68377.0, 58079.0] || False >>
# b5572f9f8b64c1e860b7c4dcdcf272de
# What was the change in personnel expenses in 2018/2019 from 2017/2018? Success: 91.0
# << 2,816-2,725 || [2173.0, 2264.0, 91.0] || [2816.0, 2725.0] || False >>
# 2df5086d76d9cb82d007d208a95e03bf
# What was the percentage change in personnel expenses in 2018/2019 from 2017/2018? Success: 4.19
# << ((2,816-2,725)/2,725) * 100 || [2173.0, 2264.0, 4.187758858720662] || [2816.0, 2725.0, 2725.0] || False >>
# 4cc89377aa421d8d6eece5a7dce4de2d
# What is the average cash dividends declared per share for fiscal years 2017 to 2019?[Error]unsupported operand type(s) for +: 'NoneType' and 'NoneType'
# [Error]unsupported operand type(s) for +: 'NoneType' and 'NoneType'
#  Success: [Error]unsupported operand type(s) for +: 'NoneType' and 'NoneType'
# << (1.28+ 1.28+ 2.04)/3 || [] || [1.28, 1.28, 2.04] || False >>
# a070ac129ffad54615cd45118c9aea75
# What is the change in operating income between fiscal years 2019 and 2018? Success: 38294.0
# << 67,994-29,700 || [67994.0, 29700.0, 38294.0] || [67994.0, 29700.0] || True >>
# 27f6efd18696c43720f1ca2e94c0f7e5
# What is the average basic earnings per share for fiscal years 2017 to 2019? Success: 5.803333333333334
# << (2.41+ 2.70+ 12.30)/3 || [5.803333333333334] || [2.41, 2.7, 12.3] || False >>
# 2c0e0e756168b45e92978a151a7fb2ab
# What is the amount of total commission as a percentage of the Ceiling as per Section 198 of the Companies Act? Success: 8.98
# << (1,210.00/40,434.81 ) * 100 || [3630.0, 40434.81, 8.977413273365203] || [1210.0, 40434.81, 100.0] || False >>
# f0b2fe06c1b53072f911666f3c4fc564
# What is the amount of total Sitting Fees as a percentage of Total Managerial Remuneration? Success: 0.17
# << (33.60/1,243.60 ) * 100 || [67.20000000000002, 40434.81, 0.16619343580444676] || [33.6, 1243.6, 100.0] || False >>
# f585885778f95bf1dbb2a00151125624
# What was the change in revenue in Ireland in 2019 from 2018? Success: 0.0
# << 5.2-5.2 || [5.2, 5.2, 0.0] || [5.2, 5.2] || True >>
# acf5fdb8be289c36f97930c4fcf72942
# What was the percentage change in revenue in Ireland in 2019 from 2018? Success: 0.0
# << (5.2-5.2)/5.2 || [5.2, 5.2, 0.0] || [5.2, 5.2, 5.2] || True >>
# ee85b9ce062cb99f0861b9c43d6f6eed
# What is the ratio of Darcy Antonellis’ total compensation to David C. Habiger’s total compensation? Success: 0.93
# << 205,320/219,987  || [205320.0, 219987.0, 0.9333278784655457] || [205320.0, 219987.0] || True >>
# bf0f732e7286dad472c3a7a3848415a2
# What is the average fee earned or paid in cash compensation for all non-employee directors? Success: 77111.0
# << (106,000+55,333+70,000+81,000+68,333+82,000)/6  || [77111.0] || [106000.0, 55333.0, 70000.0, 81000.0, 68333.0, 82000.0] || False >>
# 48f4cafcd78061339d631d6490c055e0
# What was the change in Other in FY2019 from FY2018? Success: 0.0
# << 1-1 || [1.0, 1.0, 0.0] || [1.0, 1.0] || True >>
# 5bbcaeb1ebcedc949361aba4d6559771
# What was the percentage change in Other in FY2019 from FY2018? Success: 0.0
# << (1-1)/1 || [1.0, 1.0, 0.0] || [1.0, 1.0, 1.0] || True >>
# 0f782fc4163163785b2e178515809eaf
# What was the change in the Expected volatility from 2017 to 2018? Success: -1.82
# << 25.37 - 27.19 || [27.19, 25.37, -1.8200000000000003] || [25.37, 27.19] || True >>
# 337883b1c9a3f437f0667434c832a52e
# What was the change in Weighted average grant date stock price from 2017 to 2018? Success: 11.27
# << 65 - 53.73 || [53.73, 65.0, 11.270000000000003] || [65.0, 53.73] || True >>
# ba05732dd03e71da5b0e02ba9b16447d
# What was the change in the amount of surcharge revenue from 2018 to 2019? Success: 72.70000000000005
# << 438.1-365.4 || [438.1, 365.4, 72.70000000000005] || [438.1, 365.4] || True >>
# *** Overall EM:  0.6867469879518072 / 90
# e395e9f47dbe3fd712e7ab4f42fe0eec
# What was the percentage change in the amount of surcharge revenue from 2018 to 2019? Success: 19.9
# << ((438.1-365.4)/365.4) * 100 || [438.1, 365.4, 19.896004378763013] || [438.1, 365.4, 365.4] || True >>
# *** Overall EM:  0.6904761904761905 / 90
# 844c4d74af9231f62c7c193d54c0549e
# What is the average sales and marketing expenses for 2018 and 2019? Success: 411455.0
# << (472,841+350,069)/2 || [472841.0, 350069.0, 411455.0] || [472841.0, 350069.0] || True >>
# 9d8a4bd1a58a100ae2c3fd8b605a490b
# What is the difference between the Ending balance of unrecognized tax benefits of 2019 against 2017? Success: 176.0
# << 390.3-214.3 || [390.3, 214.3, 176.0] || [390.3, 214.3] || True >>
# *** Overall EM:  0.6976744186046512 / 260
# 2a7951420ed77b8b40366a4d53a2f5d3
# What is the Beginning balance of unrecognized tax benefits expressed as a percentage of Ending balance of unrecognized tax benefits for 2019? Success: 91.31
# << (356.4/390.3) * 100 || [356.4, 390.3, 91.31437355880091] || [356.4, 390.3] || True >>
# *** Overall EM:  0.7011494252873564 / 260
# 557c1e6b072d90960071e39e584e404e
# What is the average annual Ending balance of unrecognized tax benefits?  Success: 320.33
# << (390.3+356.4+214.3)/3 || [320.3333333333333] || [390.3, 356.4, 214.3] || False >>
# *** Overall EM:  0.7045454545454546 / 260
# e2164a95603660da8e3b21396f51c71d
# What was the change in the amount of Accruals? Success: 6.1
# << 49.3-43.2 || [49.3, 43.2, 6.099999999999994] || [49.3, 43.2] || True >>
# 44caa96068a5c3f6e3584d1b363568f9
# What was the percentage change in the amount of Accruals? Success: 14.12
# << ((49.3-43.2)/43.2) * 100 || [49.3, 43.2, 14.120370370370356] || [49.3, 43.2, 43.2] || True >>
# 922ce7104fc57e4abeefb7ece1532a8f
# What was the percentage change in interest expense from 2018 to 2019? Success: -50.6
# << ((53,353 - 108,011)/108,011 ) * 100 || [-108011.0, -53353.0, -50.6041051374397] || [] || True >>
# 1770227696.189469 139.86071848869324
# cnt: 91

# %%
annotated_results = cga_utils.annotate_results(res)
cga_utils.calc_overall_em(annotated_results)
# Out:
# 0.7142857142857143
